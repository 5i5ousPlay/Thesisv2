# %% [markdown]
# ## Setup in Local Machine (all)

# %%
#Install
# %pip install worker
# %pip install pandas
# %pip install numpy
# %pip install networkx
# %pip install matplotlib
# %pip install music21
# %pip install musescore
# %pip install tslearn
# %pip install sklearn
# %pip install multiprocessing
# %pip install pyvis
# Out:
# Requirement already satisfied: worker in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (2018.4.1)
# Requirement already satisfied: termcc in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from worker) (2019.8.2)
# Requirement already satisfied: loader in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from worker) (2017.9.11)
# Requirement already satisfied: async-timeout in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from worker) (4.0.3)
# Requirement already satisfied: aiohttp in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from worker) (3.9.5)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->worker) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->worker) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->worker) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->worker) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->worker) (1.9.4)
# Requirement already satisfied: bs4 in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from loader->worker) (0.0.2)
# Requirement already satisfied: logbook in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from termcc->worker) (1.7.0.post0)
# Requirement already satisfied: pendulum in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from termcc->worker) (3.0.0)
# Requirement already satisfied: terminaltables in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from termcc->worker) (3.1.10)
# Requirement already satisfied: idna>=2.0 in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from yarl<2.0,>=1.0->aiohttp->worker) (3.7)
# Requirement already satisfied: beautifulsoup4 in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from bs4->loader->worker) (4.12.3)
# Requirement already satisfied: python-dateutil>=2.6 in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from pendulum->termcc->worker) (2.8.2)
# Requirement already satisfied: tzdata>=2020.1 in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from pendulum->termcc->worker) (2023.3)
# Requirement already satisfied: time-machine>=2.6.0 in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from pendulum->termcc->worker) (2.14.1)
# Requirement already satisfied: six>=1.5 in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.6->pendulum->termcc->worker) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4->bs4->loader->worker) (2.5)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pandas in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (2.1.3)
# Requirement already satisfied: numpy<2,>=1.26.0 in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from pandas) (1.26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (1.26.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: networkx in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (3.3)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.21 in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.26.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\al\appdata\roaming\python\python312\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: music21 in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (9.1.0)
# Requirement already satisfied: chardet in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from music21) (5.2.0)
# Requirement already satisfied: joblib in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from music21) (1.4.0)
# Requirement already satisfied: jsonpickle in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from music21) (3.0.4)
# Requirement already satisfied: matplotlib in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from music21) (3.8.4)
# Requirement already satisfied: more-itertools in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from music21) (10.2.0)
# Requirement already satisfied: numpy in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from music21) (1.26.2)
# Requirement already satisfied: requests in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from music21) (2.31.0)
# Requirement already satisfied: webcolors>=1.5 in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from music21) (1.13)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->music21) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->music21) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->music21) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->music21) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\al\appdata\roaming\python\python312\site-packages (from matplotlib->music21) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->music21) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->music21) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->music21) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from requests->music21) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from requests->music21) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from requests->music21) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from requests->music21) (2024.2.2)
# Requirement already satisfied: six>=1.5 in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib->music21) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: musescore in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (0.0.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: tslearn in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (0.6.3)
# Requirement already satisfied: numpy in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from tslearn) (1.26.2)
# Requirement already satisfied: scipy in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from tslearn) (1.13.0)
# Requirement already satisfied: scikit-learn in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from tslearn) (1.4.2)
# Requirement already satisfied: numba in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from tslearn) (0.59.1)
# Requirement already satisfied: joblib in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from tslearn) (1.4.0)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from numba->tslearn) (0.42.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->tslearn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting sklearn
#   Using cached sklearn-0.0.post12.tar.gz (2.6 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [15 lines of output]
#       The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#       rather than 'sklearn' for pip commands.
#
#       Here is how to fix this error in the main use cases:
#       - use 'pip install scikit-learn' rather than 'pip install sklearn'
#       - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#         (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#       - if the 'sklearn' package is used by one of your dependencies,
#         it would be great if you take some time to track which package uses
#         'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#       - as a last resort, set the environment variable
#         SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#       More information is available at
#       https://github.com/scikit-learn/sklearn-pypi-package
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.Collecting multiprocessing
#   Using cached multiprocessing-2.6.2.1.tar.gz (108 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [22 lines of output]
#       Traceback (most recent call last):
#         File "c:\Users\AL\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 353, in <module>
#           main()
#         File "c:\Users\AL\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 335, in main
#           json_out['return_val'] = hook(**hook_input['kwargs'])
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "c:\Users\AL\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 118, in get_requires_for_build_wheel
#           return hook(config_settings)
#                  ^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\AL\AppData\Local\Temp\pip-build-env-s7z2uk8m\overlay\Lib\site-packages\setuptools\build_meta.py", line 325, in get_requires_for_build_wheel
#           return self._get_build_requires(config_settings, requirements=['wheel'])
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\AL\AppData\Local\Temp\pip-build-env-s7z2uk8m\overlay\Lib\site-packages\setuptools\build_meta.py", line 295, in _get_build_requires
#           self.run_setup()
#         File "C:\Users\AL\AppData\Local\Temp\pip-build-env-s7z2uk8m\overlay\Lib\site-packages\setuptools\build_meta.py", line 487, in run_setup
#           super().run_setup(setup_script=setup_script)
#         File "C:\Users\AL\AppData\Local\Temp\pip-build-env-s7z2uk8m\overlay\Lib\site-packages\setuptools\build_meta.py", line 311, in run_setup
#           exec(code, locals())
#         File "<string>", line 94
#           print 'Macros:'
#           ^^^^^^^^^^^^^^^
#       SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pyvis in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (0.3.2)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\al\appdata\roaming\python\python312\site-packages (from pyvis) (8.21.0)
# Requirement already satisfied: jinja2>=2.9.6 in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from pyvis) (3.1.2)
# Requirement already satisfied: jsonpickle>=1.4.1 in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from pyvis) (3.0.4)
# Requirement already satisfied: networkx>=1.11 in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from pyvis) (3.3)
# Requirement already satisfied: decorator in c:\users\al\appdata\roaming\python\python312\site-packages (from ipython>=5.3.0->pyvis) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\al\appdata\roaming\python\python312\site-packages (from ipython>=5.3.0->pyvis) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\al\appdata\roaming\python\python312\site-packages (from ipython>=5.3.0->pyvis) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\al\appdata\roaming\python\python312\site-packages (from ipython>=5.3.0->pyvis) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\al\appdata\roaming\python\python312\site-packages (from ipython>=5.3.0->pyvis) (2.17.2)
# Requirement already satisfied: stack-data in c:\users\al\appdata\roaming\python\python312\site-packages (from ipython>=5.3.0->pyvis) (0.6.3)
# Requirement already satisfied: traitlets>=5 in c:\users\al\appdata\roaming\python\python312\site-packages (from ipython>=5.3.0->pyvis) (5.14.1)
# Requirement already satisfied: colorama in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from ipython>=5.3.0->pyvis) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from jinja2>=2.9.6->pyvis) (2.1.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\al\appdata\roaming\python\python312\site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\al\appdata\roaming\python\python312\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->pyvis) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\al\appdata\roaming\python\python312\site-packages (from stack-data->ipython>=5.3.0->pyvis) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\al\appdata\roaming\python\python312\site-packages (from stack-data->ipython>=5.3.0->pyvis) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\al\appdata\roaming\python\python312\site-packages (from stack-data->ipython>=5.3.0->pyvis) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\al\appdata\local\programs\python\python312\lib\site-packages (from asttokens>=2.1.0->stack-data->ipython>=5.3.0->pyvis) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Import
import worker
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

from music21 import *
from music21 import converter, corpus, environment
from tslearn.metrics import dtw
from multiprocessing import Pool, Manager, cpu_count
from sklearn.neighbors import kneighbors_graph
from sklearn.metrics import pairwise_distances
from networkx.algorithms.cuts import conductance
from pyvis.network import Network
from IPython.core.display import display, HTML
# Out:
# C:\Users\AL\AppData\Local\Temp\ipykernel_16392\995332593.py:16: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML

# %%
# Path
env = environment.Environment()
env['musicxmlPath'] = 'C:\\Program Files\\MuseScore 4\\bin\\MuseScore4.exe' # Change if needed
env['musescoreDirectPNGPath'] = 'C:\\Program Files\\MuseScore 4\\bin\\MuseScore4.exe' # Change if needed

# %% [markdown]
# ## Process Sample Music

# %%
# midi to note array function (DEPRECATED)
# def midi_to_narr(midi_file):
#     score = converter.parse(midi_file)
#     narr = []
#     for part in score.parts:
#         for element in part.flatten():
#             narr.append(element)
#     return narr

# %%
# midi to score array function (contains all data needed for score visualization)
def midi_to_sarr(midi_file):
    score = converter.parse(midi_file)
    sarr = []
    for part in score.parts:
        for element in part.flatten():
            sarr.append(element)
    return sarr

# %%
# get notes function (original)
# def get_notes(score):
#     element_array = []
#     for part in score.parts:
#         for element in part.flatten():
#             element_array.append(element)
#     return element_array

# %%
# convert midi into a readable array of elements that forms the score
sarr = midi_to_sarr('bach_846.mid') # this midi was cleaned

# output sarr to a readable .txt file
with open("sarr_output.txt", "w") as f:
    f.write(f"Number of elements: {len(sarr)}\n\n")
    for element in sarr:
        f.write(f"{element}\n")

# %%
# sarr to narr and nmat function (removes all elements except notes, rests and chords then turn it into a matrix )
def narr_to_nmat_and_cnarr(score_array):
  trashed_elements = 0
  narr = []
  nmat = pd.DataFrame(columns=['onset_beats', 'duration_beats', 'midi_pitch'])

  for element in score_array:
    if isinstance(element, chord.Chord):
      row = [element.offset, element.duration.quarterLength, element.root().midi]
      nmat.loc[len(nmat)] = row
      narr.append(element)
    elif isinstance(element, note.Rest):
      row = [element.offset, element.duration.quarterLength, 0]
      nmat.loc[len(nmat)] = row
      narr.append(element)    
    else:
      try:
        row = [element.offset, element.duration.quarterLength, element.pitch.midi]
        nmat.loc[len(nmat)] = row
        narr.append(element)
      except:
        trashed_elements += 1
        # print(f"Trashed element #{trashed_elements}:\n{note}") # for debugging
  return nmat, narr

# %%
# convert score array into a note array and note matrix
nmat, narr = narr_to_nmat_and_cnarr(sarr)

# output nmat to a readable .txt file
with open("nmat_output.txt", "w") as f:
    f.write(f"Number of notes: {len(nmat)}\n\n")
    for note in nmat:
        f.write(f"{note}\n")
    f.write("\n")
    np.savetxt('nmat_output.txt', nmat, delimiter=',', fmt='%s')

# output narr to a readable .txt file
with open("narr_output.txt", "w") as f:
    f.write(f"Number of notes: {len(narr)}\n\n")
    for note in narr:
        f.write(f"{note}\n")

# %%
# narr to nmat function (DEPRECATED)
# def narr_to_nmat(note_array):
#   nmat = pd.DataFrame(columns=['onset_beats', 'duration_beats', 'midi_pitch'])
#   trashed_elements = 0
#   for note in note_array:
#     if isinstance(note, chord.Chord):
#       row = [note.offset, note.duration.quarterLength, note.root().midi]
#       nmat.loc[len(nmat)] = row
#     else:
#       try:
#         row = [note.offset, note.duration.quarterLength, note.pitch.midi]
#         nmat.loc[len(nmat)] = row
#       except:
#         trashed_elements += 1
#         print(f"Trashed element #{trashed_elements}:\n{note}") # for debugging
#   return nmat

# %%
# narr to nmat function (this version also takes rests into account for ir assignment, ABANDONED- fuckit it cant store other details before narr, narr first before this)
# def narr_to_nmat(note_array):
#   nmat = pd.DataFrame(columns=['onset_beats', 'duration_beats', 'midi_pitch'])
#   trashed_elements = 0
#   for note in note_array:
#     if isinstance(note, chord.Chord):
#       row = [note.offset, note.duration.quarterLength, note.root().midi]
#       nmat.loc[len(nmat)] = row
#     elif isinstance(note, note.Rest):
#         row = [note.offset, note.duration.quarterLength, note.root().midi]
#     else:
#       try:
#         row = [note.offset, note.duration.quarterLength, note.pitch.midi]
#         nmat.loc[len(nmat)] = row
#       except:
#         trashed_elements += 1
#         # print(f"Trashed element #{trashed_elements}:\n{note}") # for debugging
#   return nmat

# %%
# note array to note matrix (DEPRECATED)
# nmat = narr_to_nmat(narr)
# nmat.head(len(narr))

# %%
# midi to nmat function (original)
# def midi_to_nmat(midi_file):
#   s = converter.parse(midi_file)
#   nmat = pd.DataFrame(columns=['onset_beats', 'duration_beats', 'midi_pitch'])
#   for el in s.flatten().notes:
#     if isinstance(el, chord.Chord):
#       row = [el.offset, el.duration.quarterLength, el.root().midi]
#     else:
#       row = [el.offset, el.duration.quarterLength, el.pitch.midi]
#     nmat.loc[len(nmat)] = row
#   return nmat

# %%
# convert a sample midi to nmat (original)
# nmat = midi_to_nmat(midi)
# nmat.head(len(narr))

# %% [markdown]
# ## Implication-Realization Ruleset, Assignment and Score Visualization

# %%
# IR symbol calculation function
def calculate_ir_symbol(interval1, interval2, threshold=5):
    direction = interval1 * interval2
    abs_difference = abs(interval2-interval1)
    # Process
    if direction > 0 and (abs(interval2-interval1))<threshold:
        return 'P'  
    # IR2: D (Duplication)
    elif interval1 == interval2 == 0:
        return 'D' 
    # IR3: IP (Intervallic Process)
    elif ((interval1 * interval2)<0) and (-threshold <= (abs(interval2) - abs(interval1)) <= threshold) and (abs(interval2) != abs(interval1)):
        return 'IP' 
    # IR4: ID (Intervallic Duplication)
    elif ((interval1 * interval2) < 0) and (abs(interval2) == abs(interval1)):
        return 'ID'   
    # IR5: VP (Vector Process)
    elif (interval1 * interval2 > 0) and (abs(interval2-interval1) >= threshold) and (abs(interval1) <= threshold):
        return 'VP'
    # IR6: R (Reveral)
    elif (interval1 * interval2 < 0) and (abs(abs(interval2)-abs(interval1)) >= threshold) and (abs(interval1) >= threshold):
        return 'R'
    # IR7: IR (Intervallic Reveral)
    elif (interval1 * interval2 > 0) and (abs(abs(interval2)-abs(interval1)) >= threshold) and (abs(interval1) >= threshold):
        return 'IR' 
    # IR8: VR (Vector Reveral)
    elif (interval1 * interval2 < 0) and (abs(interval2 - interval1) >= threshold) and (abs(interval1) <= threshold):
        return 'VR'
    elif interval2 == 0 and not (interval1 < -5 or interval1 > 5):
        return 'IP'
    elif interval2 == 0 and (interval1 < -5 or interval1 > 5):
        return 'R'
    elif interval1 == 0 and not (interval2 < -5 or interval2 > 5):
        return 'P'
    elif interval1 == 0 and (interval2 < -5 or interval2 > 5):
        return 'VR'

# %%
# assign IR symbol function (original; modified)
def assign_ir_symbols(score_array):
    
    symbols = []
    current_group = [] 
    group_pitches = []
    
    color_map = {
        'P': 'blue',        # IR1: P (Process) 
        'D': 'green',       # IR2: D (Duplication)
        'IP': 'red',        # IR3: IP (Intervallic Process)
        'ID': 'orange',     # IR4: ID (Intervallic Duplication)
        'VP': 'purple',     # IR5: VP (Vector Process)
        'R': 'cyan',        # IR6: R (Reveral)
        'IR': 'magenta',    # IR7: IR (Intervallic Reveral)
        'VR': 'yellow',     # IR8: VR (Vector Reveral)
        'M': 'pink',        # IR9: M (Monad)
        'd': 'lime',        # IR10 d (Dyad)
    }

    def evaluate_current_group():
        if len(current_group) == 3:
            interval1 = group_pitches[1] - group_pitches[0]
            interval2 = group_pitches[2] - group_pitches[1]
            symbol = calculate_ir_symbol(interval1, interval2)
            # symbols.append(symbol)
            color = color_map.get(symbol, 'black')  # Default to black if symbol is not predefined
            symbols.extend((note, symbol, color) for note in current_group)
        elif len(current_group) == 2:
            # symbols.append('d')  # Dyad
            symbols.extend((note, 'd', color_map['d']) for note in current_group)
        elif len(current_group) == 1:
            # symbols.append('M')  # Monad
            symbols.extend((note, 'M', color_map['M']) for note in current_group)
        else:
            symbols.append('Error: Invalid note object')
        current_group.clear()
        group_pitches.clear()

    for element in score_array:
        if isinstance(element, note.Note):
            current_group.append(element)
            group_pitches.append(element.pitch.ps)
            if len(current_group) == 3:
                evaluate_current_group()
        elif isinstance(element, chord.Chord):
            current_group.append(element)
            group_pitches.append(element.root().ps)
            if len(current_group) == 3:
                evaluate_current_group()
        elif isinstance(element, note.Rest):
            # continue
            # Remove continue for visualization
            rest_tuple = (element, 'rest', 'black') 
            evaluate_current_group()
            symbols.append(rest_tuple)
        else:
            if current_group:
                evaluate_current_group()

    # Handle any remaining notes
    if current_group:
        evaluate_current_group()

    return symbols

# %%
# assign IR symbol function (attempt to use nmat instead of narr, ABANDONED cuz nmat cant store styles and colors properly)
# def assign_ir_symbols(note_matrix):
#     elements = []
#     symbols = []
#     current_group = [] 
#     group_pitches = []
    
#     color_map = {
#         'P': 'blue',        # IR1: P (Process) 
#         'D': 'green',       # IR2: D (Duplication)
#         'IP': 'red',        # IR3: IP (Intervallic Process)
#         'ID': 'orange',     # IR4: ID (Intervallic Duplication)
#         'VP': 'purple',     # IR5: VP (Vector Process)
#         'R': 'cyan',        # IR6: R (Reveral)
#         'IR': 'magenta',    # IR7: IR (Intervallic Reveral)
#         'VR': 'yellow',     # IR8: VR (Vector Reveral)
#         'M': 'pink',        # IR9: M (Monad)
#         'd': 'lime',        # IR10 d (Dyad)
#     }

#     def evaluate_current_group():
#         if len(current_group) == 3:
#             interval1 = group_pitches[1] - group_pitches[0]
#             interval2 = group_pitches[2] - group_pitches[1]
#             symbol = calculate_ir_symbol(interval1, interval2)
#             # symbols.append(symbol)
#             color = color_map.get(symbol, 'black')  # Default to black if symbol is not predefined
#             symbols.extend((note, symbol, color) for note in current_group)
#         elif len(current_group) == 2:
#             # symbols.append('d')  # Dyad
#             symbols.extend((note, 'd', color_map['d']) for note in current_group)
#         elif len(current_group) == 1:
#             # symbols.append('M')  # Monad
#             symbols.extend((note, 'M', color_map['M']) for note in current_group)
#         else:
#             symbols.append('Error: Invalid note object')
#         current_group.clear()
#         group_pitches.clear()

#     for index, row in note_matrix.iterrows():
#         if row['col2'] == note:
#             current_group.append(element)
#             group_pitches.append(element.pitch.ps)
#             if len(current_group) == 3:
#                 evaluate_current_group()
#         elif isinstance(element, chord.Chord):
#             current_group.append(element)
#             group_pitches.append(element.root().ps)
#             if len(current_group) == 3:
#                 evaluate_current_group()
#         elif isinstance(element, note.Rest):
#             # continue
#             # Remove continue for visualization
#             rest_tuple = (element, 'rest', 'black') 
#             evaluate_current_group()
#             symbols.append(rest_tuple)
#         else:
#             if current_group:
#                 evaluate_current_group()

#     # Handle any remaining notes
#     if current_group:
#         evaluate_current_group()

#     return symbols

# %%
# assign IR symbol function (original)
# def assign_ir_symbols(elements):
#     symbols = []
#     current_group = [] 
#     group_pitches = []
    
#     color_map = {
#         'P': 'blue',        # IR1: P (Process) 
#         'D': 'green',       # IR2: D (Duplication)
#         'IP': 'red',        # IR3: IP (Intervallic Process)
#         'ID': 'orange',     # IR4: ID (Intervallic Duplication)
#         'VP': 'purple',     # IR5: VP (Vector Process)
#         'R': 'cyan',        # IR6: R (Reveral)
#         'IR': 'magenta',    # IR7: IR (Intervallic Reveral)
#         'VR': 'yellow',     # IR8: VR (Vector Reveral)
#         'M': 'pink',        # IR9: M (Monad)
#         'd': 'lime',        # IR10 d (Dyad)
#     }

#     def evaluate_current_group():
#         if len(current_group) == 3:
#             interval1 = group_pitches[1] - group_pitches[0]
#             interval2 = group_pitches[2] - group_pitches[1]
#             symbol = calculate_ir_symbol(interval1, interval2)
#             # symbols.append(symbol)
#             color = color_map.get(symbol, 'black')  # Default to black if symbol is not predefined
#             symbols.extend((note, symbol, color) for note in current_group)
#         elif len(current_group) == 2:
#             # symbols.append('d')  # Dyad
#             symbols.extend((note, 'd', color_map['d']) for note in current_group)
#         elif len(current_group) == 1:
#             # symbols.append('M')  # Monad
#             symbols.extend((note, 'M', color_map['M']) for note in current_group)
#         else:
#             symbols.append('Error: Invalid note object')
#         current_group.clear()
#         group_pitches.clear()

#     for element in elements:
#         if isinstance(element, note.Note):
#             current_group.append(element)
#             group_pitches.append(element.pitch.ps)
#             if len(current_group) == 3:
#                 evaluate_current_group()
#         elif isinstance(element, chord.Chord):
#             current_group.append(element)
#             group_pitches.append(element.root().ps)
#             if len(current_group) == 3:
#                 evaluate_current_group()
#         elif isinstance(element, note.Rest):
#             continue
#             # # Remove continue for visualization
#             # rest_tuple = (element, 'rest', 'black') 
#             # evaluate_current_group()
#             # symbols.append(rest_tuple)
#         else:
#             if current_group:
#                 evaluate_current_group()

#     # Handle any remaining notes
#     if current_group:
#         evaluate_current_group()

#     return symbols

# %%
# Score visualization function
def visualize_notes_with_symbols(notes_with_symbols):
    s = stream.Score()
    part = stream.Part()
    for note, symbol, color in notes_with_symbols:
        print(note, symbol, color)
        note.style.color = color
        note.lyric = symbol
        part.append(note)
    s.append(part)
    s.show()

# %%
# code block figuring out if theres a way to reference nmat to note array


# matching elements in nmat to narr, narr contains elements not in nmat

# # getting original midi's number of elements
# s = converter.parse(midi)
# nmatcomp = pd.DataFrame(columns=['onset_beats', 'duration_beats', 'midi_pitch'])
# for el in s.flatten().notes:
#     if isinstance(el, chord.Chord):
#         row = [el.offset, el.duration.quarterLength, el.root().midi]
#     else:
#         row = [el.offset, el.duration.quarterLength, el.pitch.midi]
# nmatcomp.loc[len(nmat)] = row
# nmatcomp.head(1098)

# Note Array Testing
# print("\nnumber of elements to take into account:")
# num_notes = len(narr)
# print(num_notes) #  note array length for bach midi is 1098

# print("\nnote array start here")
# for note in narr:
#     print(note)

# # temporary, for narr debugging
# with open("narr_output.txt", "w") as f:
#   for note in narr:
#     f.write(f"{note}\n")

# # Note Matrix Testing
# print("\nnote matrix start here")
# nmat.head(num_notes) # however, nmat only has 546 elements in its matrix, if you ctrl+f "music21.note.Note" there are 544 elements

# # temporary, for nmat debugging
# import sys
# np.set_printoptions(threshold=sys.maxsize)
# np.savetxt('nmat_output.txt', nmat, delimiter=',', fmt='%s')


# extending nmat to account IR

# %%
# Usage of the above functions
test_ir = assign_ir_symbols(sarr)
print(len(test_ir))
for symbol in test_ir:
    print(symbol)

# try: # error when polyphonic
#     visualize_notes_with_symbols(test_ir)
# except:
#     score.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 2
#       1 # Usage of the above functions
# ----> 2 test_ir = assign_ir_symbols(sarr)
#       3 print(len(test_ir))
#       4 for symbol in test_ir:
#
# Cell In[16], line 41, in assign_ir_symbols(score_array)
#      38     group_pitches.clear()
#      40 for element in score_array:
# ---> 41     if isinstance(element, note.Note):
#      42         current_group.append(element)
#      43         group_pitches.append(element.pitch.ps)
#
# AttributeError: 'Rest' object has no attribute 'Note'

# %% [markdown]
# ## Gestalt Based Segmentation (Functions)

# %%
# onset function
def get_onset(notematrix: pd.DataFrame, timetype='beat'):
  if timetype == 'beat':
    return notematrix['onset_beats']
  elif timetype == 'sec':
    return notematrix['onset_sec']
  else:
    ValueError(f"Invalid timetype: {timetype}. Choices are only 'beat' and 'sec'")

# %%
# duration function
def get_duration(notematrix: pd.DataFrame, timetype='beat') -> pd.Series:
  if timetype == 'beat':
    return notematrix['duration_beats']
  elif timetype == 'sec':
    return notematrix['duration_sec']
  else:
    ValueError(f"Invalid timetype: {timetype}. Choices are only 'beat' and 'sec'")

# %%
# clang boundary calculation funtion
def calculate_clang_boundaries(notematrix: pd.DataFrame):
  cl = 2*(get_onset(notematrix).diff() + get_duration(notematrix).shift(-1)) + abs(notematrix['midi_pitch'].diff())
  clb = (cl.shift(-1) > cl) & (cl.shift(1) > cl)
  clind = clb.index[clb].tolist()
  return clind

# %%
# segment boundary calculation function
def calculate_segment_boundaries(notematrix, clind):
    first = [0] + clind
    last = clind + [len(notematrix) - 1]
    mean_pitch = [notematrix.iloc[first[i]:last[i]+1]['midi_pitch'].mean() for i in range(len(first))]
    segdist = []
    for i in range(1, len(first)):
        segdist.append(abs(mean_pitch[i] - mean_pitch[i - 1]) +
                       notematrix.iloc[first[i]]['onset_beats'] - notematrix.iloc[last[i - 1]]['onset_beats'] +
                       notematrix.iloc[first[i]]['duration_beats'] + notematrix.iloc[first[i - 1]]['duration_beats'] +
                       2 * (notematrix.iloc[first[i]]['onset_beats'] - notematrix.iloc[last[i - 1]]['onset_beats']))

    segb = [(segdist[i] > segdist[i-1] and segdist[i] > segdist[i+1]) for i in range(1, len(segdist)-1)]
    segind = [clind[i] for i in range(1, len(segdist)-1) if segb[i-1]]
    return segind

# %%
# gestalt segmentation function
def segmentgestalt(notematrix):
    if notematrix.empty:
        return None

    # IR Assignment function here? <------------------------------------------------------ yayayaya look here
    clind = calculate_clang_boundaries(notematrix)
    segind = calculate_segment_boundaries(notematrix, clind)

    segments = []
    start_idx = 0
    for end_idx in segind:
        segments.append(notematrix.iloc[start_idx:end_idx+1])
        start_idx = end_idx + 1

    segments.append(notematrix.iloc[start_idx:])
    return segments

# %% [markdown]
# ## Get Clang Boundaries and Segments

# %%
# show clang boundaries
clang_boundaries = calculate_clang_boundaries(nmat)
print("Clang Boundaries:", clang_boundaries)
# Out:
# Clang Boundaries: [3, 6, 10, 13, 17, 20, 24, 27, 31, 34, 38, 41, 45, 48, 52, 55, 59, 62, 66, 69, 72, 75, 79, 82, 87, 90, 94, 97, 100, 103, 107, 110, 114, 117, 121, 124, 128, 131, 135, 138, 143, 146, 150, 153, 156, 159, 163, 166, 169, 172, 175, 179, 182, 185, 188, 192, 195, 200, 203, 207, 210, 213, 216, 220, 223, 227, 230, 234, 237, 241, 244, 248, 251, 256, 259, 263, 266, 269, 272, 276, 279, 283, 286, 290, 293, 300, 307, 311, 314, 318, 321, 326, 329, 333, 336, 340, 343, 347, 350, 359, 364, 368, 371, 375, 378, 382, 385, 389, 392, 396, 399, 403, 406, 413, 423, 425, 428, 431, 433, 436, 440, 443, 447, 450, 455, 480, 484, 487, 489, 491, 493, 495, 497, 499, 502, 504, 509, 511, 513, 515, 517, 519, 522, 525, 527, 529, 533, 538, 540, 542, 547, 549, 551, 554, 556, 558, 563, 565, 568, 570, 573, 579, 582, 584, 586, 591, 593, 595, 597, 599, 602, 605, 607, 610, 614, 616, 618, 622, 625, 627, 629, 631, 633, 635, 637, 639, 641, 643, 645, 647, 649, 651, 653, 655, 657, 659, 663, 665, 667, 669, 671, 673, 675, 677, 679, 681, 683, 685, 687, 689, 691, 695, 697, 701, 703, 705, 707, 709, 713, 715, 717, 719, 721, 723, 725, 727, 729, 731, 733, 735, 737, 739, 741, 743, 745, 747, 751, 754]

# %%
# show segments
segments = segmentgestalt(nmat)
for idx, segment in enumerate(segments):
    print(f"Segment {idx+1}:")
    print(segment)
    print("----------------------")


### Segments are calculated separate from clang boundaries
# Out:
# Segment 1:
#    onset_beats duration_beats  midi_pitch
# 0          0.0            0.5         0.0
# 1          0.5           0.25        67.0
# 2         0.75           0.25        72.0
# 3          1.0           0.25        76.0
# 4         1.25           0.25        67.0
# 5          1.5           0.25        72.0
# 6         1.75           0.25        76.0
# 7          2.0            0.5         0.0
# 8          2.5           0.25        67.0
# 9         2.75           0.25        72.0
# 10         3.0           0.25        76.0
# 11        3.25           0.25        67.0
# 12         3.5           0.25        72.0
# 13        3.75           0.25        76.0
# 14         4.0            0.5         0.0
# 15         4.5           0.25        69.0
# 16        4.75           0.25        74.0
# 17         5.0           0.25        77.0
# ----------------------
# Segment 2:
#    onset_beats duration_beats  midi_pitch
# 18        5.25           0.25        69.0
# 19         5.5           0.25        74.0
# 20        5.75           0.25        77.0
# 21         6.0            0.5         0.0
# 22         6.5           0.25        69.0
# 23        6.75           0.25        74.0
# 24         7.0           0.25        77.0
# 25        7.25           0.25        69.0
# 26         7.5           0.25        74.0
# 27        7.75           0.25        77.0
# ----------------------
# Segment 3:
#    onset_beats duration_beats  midi_pitch
# 28         8.0            0.5         0.0
# 29         8.5           0.25        67.0
# 30        8.75           0.25        74.0
# 31         9.0           0.25        77.0
# 32        9.25           0.25        67.0
# 33         9.5           0.25        74.0
# 34        9.75           0.25        77.0
# 35        10.0            0.5         0.0
# 36        10.5           0.25        67.0
# 37       10.75           0.25        74.0
# 38        11.0           0.25        77.0
# 39       11.25           0.25        67.0
# 40        11.5           0.25        74.0
# 41       11.75           0.25        77.0
# ----------------------
# Segment 4:
#    onset_beats duration_beats  midi_pitch
# 42        12.0            0.5         0.0
# 43        12.5           0.25        67.0
# 608      236.75           0.25         0.0
# 609       237.0           1.25         0.0
# 610      238.25           1.75         0.0
# 611       240.0            2/3         0.0
# 612       722/3            2/3         0.0
# 613       724/3            2/3         0.0
# 614       242.0           0.25         0.0
# 615      242.25           0.25         0.0
# 616       242.5           1.25         0.0
# 617      243.75           0.25         0.0
# 618       244.0            1.0         0.0
# 619       245.0           0.25         0.0
# 620      245.25            0.5         0.0
# 621      245.75           2.25         0.0
# 622         0.0            2.0        60.0
# ----------------------
# Segment 32:
#     onset_beats duration_beats  midi_pitch
# 623        0.25           1.75        64.0
# 624         2.0            2.0        60.0
# 625        2.25           1.75        64.0
# 626         4.0            2.0        60.0
# 627        4.25           1.75        62.0
# ----------------------
# Segment 33:
#     onset_beats duration_beats  midi_pitch
# 628         6.0            2.0        60.0
# 629        6.25           1.75        62.0
# 630         8.0            2.0        59.0
# 631        8.25           1.75        62.0
# 632        10.0            2.0        59.0
# 633       10.25           1.75        62.0
# ----------------------
# Segment 34:
#     onset_beats duration_beats  midi_pitch
# 634        12.0            2.0        60.0
# 635       12.25           1.75        64.0
# 636        14.0            2.0        60.0
# 637       14.25           1.75        64.0
# 638        16.0            2.0        60.0
# 639       16.25           1.75        64.0
# 640        18.0            2.0        60.0
# 641       18.25           1.75        64.0
# 642        20.0            2.0        60.0
# 643       20.25           1.75        62.0
# 644        22.0            2.0        60.0
# 645       22.25           1.75        62.0
# 646        24.0            2.0        59.0
# 647       24.25           1.75        62.0
# 648        26.0            2.0        59.0
# 649       26.25           1.75        62.0
# 650        28.0            2.0        59.0
# 651       28.25           1.75        60.0
# ----------------------
# Segment 35:
#     onset_beats duration_beats  midi_pitch
# 652        30.0            2.0        59.0
# 653       30.25           1.75        60.0
# 654        32.0            2.0        57.0
# 655       32.25           1.75        60.0
# 656        34.0            2.0        57.0
# 657       34.25           1.75        60.0
# ----------------------
# Segment 36:
#     onset_beats duration_beats  midi_pitch
# 658        36.0            2.0        50.0
# 659       36.25           1.75        57.0
# 660        38.0            2.0        50.0
# 661       38.25           1.75        57.0
# 662        40.0            2.0        55.0
# 663       40.25           1.75        59.0
# ----------------------
# Segment 37:
#     onset_beats duration_beats  midi_pitch
# 664        42.0            2.0        55.0
# 665       42.25           1.75        59.0
# 666        44.0            2.0        55.0
# 667       44.25           1.75        58.0
# 668        46.0            2.0        55.0
# 669       46.25           1.75        58.0
# ----------------------
# Segment 38:
#     onset_beats duration_beats  midi_pitch
# 670        48.0            2.0        53.0
# 671       48.25           1.75        57.0
# 672        50.0            2.0        53.0
# 673       50.25           1.75        57.0
# 674        52.0            2.0        53.0
# 675       52.25           1.75        56.0
# 676        54.0            2.0        53.0
# 677       54.25           1.75        56.0
# ----------------------
# Segment 39:
#     onset_beats duration_beats  midi_pitch
# 678        56.0            2.0        52.0
# 679       56.25           1.75        55.0
# 680        58.0            2.0        52.0
# 681       58.25           1.75        55.0
# 682        60.0            2.0        52.0
# 683       60.25           1.75        53.0
# ----------------------
# Segment 40:
#     onset_beats duration_beats  midi_pitch
# 684        62.0            2.0        52.0
# 685       62.25           1.75        53.0
# 686        64.0            2.0        50.0
# 687       64.25           1.75        53.0
# 688        66.0            2.0        50.0
# 689       66.25           1.75        53.0
# ----------------------
# Segment 41:
#     onset_beats duration_beats  midi_pitch
# 690        68.0            2.0        43.0
# 691       68.25           1.75        50.0
# 692        70.0            2.0        43.0
# 693       70.25           1.75        50.0
# 694        72.0            2.0        48.0
# 695       72.25           1.75        52.0
# ----------------------
# Segment 42:
#     onset_beats duration_beats  midi_pitch
# 696        74.0            2.0        48.0
# 697       74.25           1.75        52.0
# 698        76.0            2.0        48.0
# 699       76.25           1.75        55.0
# 700        78.0            2.0        48.0
# 701       78.25           1.75        55.0
# ----------------------
# Segment 43:
#     onset_beats duration_beats  midi_pitch
# 702        80.0            2.0        41.0
# 703       80.25           1.75        53.0
# 704        82.0            2.0        41.0
# 705       82.25           1.75        53.0
# 706        84.0            2.0        42.0
# 707       84.25           1.75        48.0
# 708        86.0            2.0        42.0
# 709       86.25           1.75        48.0
# ----------------------
# Segment 44:
#     onset_beats duration_beats  midi_pitch
# 710        88.0            2.0        44.0
# 711       88.25           1.75        53.0
# 712        90.0            2.0        44.0
# 713       90.25           1.75        53.0
# 714        92.0            2.0        43.0
# 715       92.25           1.75        53.0
# 716        94.0            2.0        43.0
# 717       94.25           1.75        53.0
# 718        96.0            2.0        43.0
# 719       96.25           1.75        52.0
# 720        98.0            2.0        43.0
# 721       98.25           1.75        52.0
# 722       100.0            2.0        43.0
# 723      100.25           1.75        50.0
# ----------------------
# Segment 45:
#     onset_beats duration_beats  midi_pitch
# 724       102.0            2.0        43.0
# 725      102.25           1.75        50.0
# 726       104.0            2.0        43.0
# 727      104.25           1.75        50.0
# 728       106.0            2.0        43.0
# 729      106.25           1.75        50.0
# 730       108.0            2.0        43.0
# 731      108.25           1.75        51.0
# 732       110.0            2.0        43.0
# 733      110.25           1.75        51.0
# 734       112.0            2.0        43.0
# 735      112.25           1.75        52.0
# 736       114.0            2.0        43.0
# 737      114.25           1.75        52.0
# 738       116.0            2.0        43.0
# 739      116.25           1.75        50.0
# ----------------------
# Segment 46:
#     onset_beats duration_beats  midi_pitch
# 740       118.0            2.0        43.0
# 741      118.25           1.75        50.0
# 742       120.0            2.0        43.0
# 743      120.25           1.75        50.0
# 744       122.0            2.0        43.0
# 745      122.25           1.75        50.0
# ----------------------
# Segment 47:
#     onset_beats duration_beats  midi_pitch
# 746       124.0            2.0        36.0
# 747      124.25           1.75        48.0
# 748       126.0            2.0        36.0
# 749      126.25           1.75        48.0
# 750       128.0           3.75        36.0
# 751      128.25            3.5        48.0
# 752      131.75           0.25         0.0
# 753       132.0           3.75        36.0
# 754      132.25            3.5        50.0
# 755      135.75           0.25         0.0
# 756       136.0           2.75        36.0
# 757      138.75           1.25         0.0
# ----------------------

# %% [markdown]
# ## DTW Distance Using TSLearn

# %%
def segments_to_distance_matrix(segments: list[pd.DataFrame], cores=None):
    if __name__ == '__main__':
        
        if cores is not None and cores > cpu_count():
            raise ValueError(f"You don't have enough cores! Please specify a value within your system's number of cores. \n Core Count: {cpu_count()}")
        
        seg_np = [segment.to_numpy() for segment in segments]
    
        num_segments = len(seg_np)
        distance_matrix = np.zeros((num_segments, num_segments))
    
        # Create argument list for multiprocessing
        args_list = []
        for i in range(num_segments):
            for j in range(i + 1, num_segments):
                args_list.append((i, j, segments[i], segments[j]))
    
        with Manager() as manager:
            message_list = manager.list()
    
            def log_message(message):
                message_list.append(message)
    
            # Use multiprocessing Pool to parallelize the calculations
            with Pool() as pool:
                results = pool.map(worker.calculate_distance, args_list)
    
            # Update distance matrix with the results
            for i, j, distance, message in results:
                distance_matrix[i, j] = distance
                distance_matrix[j, i] = distance  # Reflect along the diagonal
                log_message(message)
    
            # Print messages from the shared list
            for message in message_list:
                print(message)
    
        return distance_matrix

# %%
# segments to distance matrix
dist_mat = segments_to_distance_matrix(segments)
# Out:
# Calculated Edge Weight (0, 1)
# Calculated Edge Weight (0, 2)
# Calculated Edge Weight (0, 3)
# Calculated Edge Weight (0, 4)
# Calculated Edge Weight (0, 5)
# Calculated Edge Weight (0, 6)
# Calculated Edge Weight (0, 7)
# Calculated Edge Weight (0, 8)
# Calculated Edge Weight (0, 9)
# Calculated Edge Weight (0, 10)
# Calculated Edge Weight (0, 11)
# Calculated Edge Weight (0, 12)
# Calculated Edge Weight (0, 13)
# Calculated Edge Weight (0, 14)
# Calculated Edge Weight (0, 15)
# Calculated Edge Weight (0, 16)
# Calculated Edge Weight (0, 17)
# Calculated Edge Weight (0, 18)
# Calculated Edge Weight (0, 19)
# Calculated Edge Weight (0, 20)
# Calculated Edge Weight (0, 21)
# Calculated Edge Weight (0, 22)
# Calculated Edge Weight (0, 23)
# Calculated Edge Weight (0, 24)
# Calculated Edge Weight (0, 25)
# Calculated Edge Weight (0, 26)
# Calculated Edge Weight (0, 27)
# Calculated Edge Weight (0, 28)
# Calculated Edge Weight (0, 29)
# Calculated Edge Weight (0, 30)
# Calculated Edge Weight (0, 31)
# Calculated Edge Weight (0, 32)
# Calculated Edge Weight (0, 33)
# Calculated Edge Weight (0, 34)
# Calculated Edge Weight (0, 35)
# Calculated Edge Weight (0, 36)
# Calculated Edge Weight (0, 37)
# Calculated Edge Weight (0, 38)
# Calculated Edge Weight (0, 39)
# Calculated Edge Weight (0, 40)
# Calculated Edge Weight (0, 41)
# Calculated Edge Weight (0, 42)
# Calculated Edge Weight (0, 43)
# Calculated Edge Weight (0, 44)
# Calculated Edge Weight (0, 45)
# Calculated Edge Weight (0, 46)
# Calculated Edge Weight (1, 2)
# Calculated Edge Weight (1, 3)
# Calculated Edge Weight (1, 4)
# Calculated Edge Weight (1, 5)
# Calculated Edge Weight (1, 6)
# Calculated Edge Weight (1, 7)
# Calculated Edge Weight (1, 8)
# Calculated Edge Weight (1, 9)
# Calculated Edge Weight (1, 10)
# Calculated Edge Weight (1, 11)
# Calculated Edge Weight (1, 12)
# Calculated Edge Weight (1, 13)
# Calculated Edge Weight (1, 14)
# Calculated Edge Weight (1, 15)
# Calculated Edge Weight (1, 16)
# Calculated Edge Weight (1, 17)
# Calculated Edge Weight (1, 18)
# Calculated Edge Weight (1, 19)
# Calculated Edge Weight (1, 20)
# Calculated Edge Weight (1, 21)
# Calculated Edge Weight (1, 22)
# Calculated Edge Weight (1, 23)
# Calculated Edge Weight (1, 24)
# Calculated Edge Weight (1, 25)
# Calculated Edge Weight (1, 26)
# Calculated Edge Weight (1, 27)
# Calculated Edge Weight (1, 28)
# Calculated Edge Weight (1, 29)
# Calculated Edge Weight (1, 30)
# Calculated Edge Weight (1, 31)
# Calculated Edge Weight (1, 32)
# Calculated Edge Weight (1, 33)
# Calculated Edge Weight (1, 34)
# Calculated Edge Weight (1, 35)
# Calculated Edge Weight (1, 36)
# Calculated Edge Weight (1, 37)
# Calculated Edge Weight (1, 38)
# Calculated Edge Weight (1, 39)
# Calculated Edge Weight (1, 40)
# Calculated Edge Weight (1, 41)
# Calculated Edge Weight (1, 42)
# Calculated Edge Weight (1, 43)
# Calculated Edge Weight (1, 44)
# Calculated Edge Weight (1, 45)
# Calculated Edge Weight (1, 46)
# Calculated Edge Weight (2, 3)
# Calculated Edge Weight (2, 4)
# Calculated Edge Weight (2, 5)
# Calculated Edge Weight (2, 6)
# Calculated Edge Weight (2, 7)
# Calculated Edge Weight (2, 8)
# Calculated Edge Weight (2, 9)
# Calculated Edge Weight (2, 10)
# Calculated Edge Weight (2, 11)
# Calculated Edge Weight (2, 12)
# Calculated Edge Weight (2, 13)
# Calculated Edge Weight (2, 14)
# Calculated Edge Weight (2, 15)
# Calculated Edge Weight (2, 16)
# Calculated Edge Weight (2, 17)
# Calculated Edge Weight (2, 18)
# Calculated Edge Weight (2, 19)
# Calculated Edge Weight (2, 20)
# Calculated Edge Weight (2, 21)
# Calculated Edge Weight (2, 22)
# Calculated Edge Weight (2, 23)
# Calculated Edge Weight (2, 24)
# Calculated Edge Weight (2, 25)
# Calculated Edge Weight (2, 26)
# Calculated Edge Weight (2, 27)
# Calculated Edge Weight (2, 28)
# Calculated Edge Weight (2, 29)
# Calculated Edge Weight (2, 30)
# Calculated Edge Weight (2, 31)
# Calculated Edge Weight (2, 32)
# Calculated Edge Weight (2, 33)
# Calculated Edge Weight (2, 34)
# Calculated Edge Weight (2, 35)
# Calculated Edge Weight (2, 36)
# Calculated Edge Weight (2, 37)
# Calculated Edge Weight (2, 38)
# Calculated Edge Weight (2, 39)
# Calculated Edge Weight (2, 40)
# Calculated Edge Weight (2, 41)
# Calculated Edge Weight (2, 42)
# Calculated Edge Weight (2, 43)
# Calculated Edge Weight (2, 44)
# Calculated Edge Weight (2, 45)
# Calculated Edge Weight (2, 46)
# Calculated Edge Weight (3, 4)
# Calculated Edge Weight (3, 5)
# Calculated Edge Weight (3, 6)
# Calculated Edge Weight (3, 7)
# Calculated Edge Weight (3, 8)
# Calculated Edge Weight (3, 9)
# Calculated Edge Weight (3, 10)
# Calculated Edge Weight (3, 11)
# Calculated Edge Weight (3, 12)
# Calculated Edge Weight (3, 13)
# Calculated Edge Weight (3, 14)
# Calculated Edge Weight (3, 15)
# Calculated Edge Weight (3, 16)
# Calculated Edge Weight (3, 17)
# Calculated Edge Weight (3, 18)
# Calculated Edge Weight (3, 19)
# Calculated Edge Weight (3, 20)
# Calculated Edge Weight (3, 21)
# Calculated Edge Weight (3, 22)
# Calculated Edge Weight (3, 23)
# Calculated Edge Weight (3, 24)
# Calculated Edge Weight (3, 25)
# Calculated Edge Weight (3, 26)
# Calculated Edge Weight (3, 27)
# Calculated Edge Weight (3, 28)
# Calculated Edge Weight (3, 29)
# Calculated Edge Weight (3, 30)
# Calculated Edge Weight (3, 31)
# Calculated Edge Weight (3, 32)
# Calculated Edge Weight (3, 33)
# Calculated Edge Weight (3, 34)
# Calculated Edge Weight (3, 35)
# Calculated Edge Weight (3, 36)
# Calculated Edge Weight (3, 37)
# Calculated Edge Weight (3, 38)
# Calculated Edge Weight (3, 39)
# Calculated Edge Weight (3, 40)
# Calculated Edge Weight (3, 41)
# Calculated Edge Weight (3, 42)
# Calculated Edge Weight (3, 43)
# Calculated Edge Weight (3, 44)
# Calculated Edge Weight (3, 45)
# Calculated Edge Weight (3, 46)
# Calculated Edge Weight (4, 5)
# Calculated Edge Weight (4, 6)
# Calculated Edge Weight (4, 7)
# Calculated Edge Weight (4, 8)
# Calculated Edge Weight (4, 9)
# Calculated Edge Weight (4, 10)
# Calculated Edge Weight (4, 11)
# Calculated Edge Weight (4, 12)
# Calculated Edge Weight (4, 13)
# Calculated Edge Weight (4, 14)
# Calculated Edge Weight (4, 15)
# Calculated Edge Weight (4, 16)
# Calculated Edge Weight (4, 17)
# Calculated Edge Weight (4, 18)
# Calculated Edge Weight (4, 19)
# Calculated Edge Weight (4, 20)
# Calculated Edge Weight (4, 21)
# Calculated Edge Weight (4, 22)
# Calculated Edge Weight (4, 23)
# Calculated Edge Weight (4, 24)
# Calculated Edge Weight (4, 25)
# Calculated Edge Weight (4, 26)
# Calculated Edge Weight (4, 27)
# Calculated Edge Weight (4, 28)
# Calculated Edge Weight (4, 29)
# Calculated Edge Weight (4, 30)
# Calculated Edge Weight (4, 31)
# Calculated Edge Weight (4, 32)
# Calculated Edge Weight (4, 33)
# Calculated Edge Weight (4, 34)
# Calculated Edge Weight (4, 35)
# Calculated Edge Weight (4, 36)
# Calculated Edge Weight (4, 37)
# Calculated Edge Weight (4, 38)
# Calculated Edge Weight (4, 39)
# Calculated Edge Weight (4, 40)
# Calculated Edge Weight (4, 41)
# Calculated Edge Weight (4, 42)
# Calculated Edge Weight (4, 43)
# Calculated Edge Weight (4, 44)
# Calculated Edge Weight (4, 45)
# Calculated Edge Weight (4, 46)
# Calculated Edge Weight (5, 6)
# Calculated Edge Weight (5, 7)
# Calculated Edge Weight (5, 8)
# Calculated Edge Weight (5, 9)
# Calculated Edge Weight (5, 10)
# Calculated Edge Weight (5, 11)
# Calculated Edge Weight (5, 12)
# Calculated Edge Weight (5, 13)
# Calculated Edge Weight (5, 14)
# Calculated Edge Weight (5, 15)
# Calculated Edge Weight (5, 16)
# Calculated Edge Weight (5, 17)
# Calculated Edge Weight (5, 18)
# Calculated Edge Weight (5, 19)
# Calculated Edge Weight (5, 20)
# Calculated Edge Weight (5, 21)
# Calculated Edge Weight (5, 22)
# Calculated Edge Weight (5, 23)
# Calculated Edge Weight (5, 24)
# Calculated Edge Weight (5, 25)
# Calculated Edge Weight (5, 26)
# Calculated Edge Weight (5, 27)
# Calculated Edge Weight (5, 28)
# Calculated Edge Weight (5, 29)
# Calculated Edge Weight (5, 30)
# Calculated Edge Weight (5, 31)
# Calculated Edge Weight (5, 32)
# Calculated Edge Weight (5, 33)
# Calculated Edge Weight (5, 34)
# Calculated Edge Weight (5, 35)
# Calculated Edge Weight (5, 36)
# Calculated Edge Weight (5, 37)
# Calculated Edge Weight (5, 38)
# Calculated Edge Weight (5, 39)
# Calculated Edge Weight (5, 40)
# Calculated Edge Weight (5, 41)
# Calculated Edge Weight (5, 42)
# Calculated Edge Weight (5, 43)
# Calculated Edge Weight (5, 44)
# Calculated Edge Weight (5, 45)
# Calculated Edge Weight (5, 46)
# Calculated Edge Weight (6, 7)
# Calculated Edge Weight (6, 8)
# Calculated Edge Weight (6, 9)
# Calculated Edge Weight (6, 10)
# Calculated Edge Weight (6, 11)
# Calculated Edge Weight (6, 12)
# Calculated Edge Weight (6, 13)
# Calculated Edge Weight (6, 14)
# Calculated Edge Weight (6, 15)
# Calculated Edge Weight (6, 16)
# Calculated Edge Weight (6, 17)
# Calculated Edge Weight (6, 18)
# Calculated Edge Weight (6, 19)
# Calculated Edge Weight (6, 20)
# Calculated Edge Weight (6, 21)
# Calculated Edge Weight (6, 22)
# Calculated Edge Weight (6, 23)
# Calculated Edge Weight (6, 24)
# Calculated Edge Weight (6, 25)
# Calculated Edge Weight (6, 26)
# Calculated Edge Weight (6, 27)
# Calculated Edge Weight (6, 28)
# Calculated Edge Weight (6, 29)
# Calculated Edge Weight (6, 30)
# Calculated Edge Weight (6, 31)
# Calculated Edge Weight (6, 32)
# Calculated Edge Weight (6, 33)
# Calculated Edge Weight (6, 34)
# Calculated Edge Weight (6, 35)
# Calculated Edge Weight (6, 36)
# Calculated Edge Weight (6, 37)
# Calculated Edge Weight (6, 38)
# Calculated Edge Weight (6, 39)
# Calculated Edge Weight (6, 40)
# Calculated Edge Weight (6, 41)
# Calculated Edge Weight (6, 42)
# Calculated Edge Weight (6, 43)
# Calculated Edge Weight (6, 44)
# Calculated Edge Weight (6, 45)
# Calculated Edge Weight (6, 46)
# Calculated Edge Weight (7, 8)
# Calculated Edge Weight (7, 9)
# Calculated Edge Weight (7, 10)
# Calculated Edge Weight (7, 11)
# Calculated Edge Weight (7, 12)
# Calculated Edge Weight (7, 13)
# Calculated Edge Weight (7, 14)
# Calculated Edge Weight (7, 15)
# Calculated Edge Weight (7, 16)
# Calculated Edge Weight (7, 17)
# Calculated Edge Weight (7, 18)
# Calculated Edge Weight (7, 19)
# Calculated Edge Weight (7, 20)
# Calculated Edge Weight (7, 21)
# Calculated Edge Weight (7, 22)
# Calculated Edge Weight (7, 23)
# Calculated Edge Weight (7, 24)
# Calculated Edge Weight (7, 25)
# Calculated Edge Weight (7, 26)
# Calculated Edge Weight (7, 27)
# Calculated Edge Weight (7, 28)
# Calculated Edge Weight (7, 29)
# Calculated Edge Weight (7, 30)
# Calculated Edge Weight (7, 31)
# Calculated Edge Weight (7, 32)
# Calculated Edge Weight (7, 33)
# Calculated Edge Weight (7, 34)
# Calculated Edge Weight (7, 35)
# Calculated Edge Weight (7, 36)
# Calculated Edge Weight (7, 37)
# Calculated Edge Weight (7, 38)
# Calculated Edge Weight (7, 39)
# Calculated Edge Weight (7, 40)
# Calculated Edge Weight (7, 41)
# Calculated Edge Weight (7, 42)
# Calculated Edge Weight (7, 43)
# Calculated Edge Weight (7, 44)
# Calculated Edge Weight (7, 45)
# Calculated Edge Weight (7, 46)
# Calculated Edge Weight (8, 9)
# Calculated Edge Weight (8, 10)
# Calculated Edge Weight (8, 11)
# Calculated Edge Weight (8, 12)
# Calculated Edge Weight (8, 13)
# Calculated Edge Weight (8, 14)
# Calculated Edge Weight (8, 15)
# Calculated Edge Weight (8, 16)
# Calculated Edge Weight (8, 17)
# Calculated Edge Weight (8, 18)
# Calculated Edge Weight (8, 19)
# Calculated Edge Weight (8, 20)
# Calculated Edge Weight (8, 21)
# Calculated Edge Weight (8, 22)
# Calculated Edge Weight (8, 23)
# Calculated Edge Weight (8, 24)
# Calculated Edge Weight (8, 25)
# Calculated Edge Weight (8, 26)
# Calculated Edge Weight (8, 27)
# Calculated Edge Weight (8, 28)
# Calculated Edge Weight (8, 29)
# Calculated Edge Weight (8, 30)
# Calculated Edge Weight (8, 31)
# Calculated Edge Weight (8, 32)
# Calculated Edge Weight (8, 33)
# Calculated Edge Weight (8, 34)
# Calculated Edge Weight (8, 35)
# Calculated Edge Weight (8, 36)
# Calculated Edge Weight (8, 37)
# Calculated Edge Weight (8, 38)
# Calculated Edge Weight (8, 39)
# Calculated Edge Weight (8, 40)
# Calculated Edge Weight (8, 41)
# Calculated Edge Weight (8, 42)
# Calculated Edge Weight (8, 43)
# Calculated Edge Weight (8, 44)
# Calculated Edge Weight (8, 45)
# Calculated Edge Weight (8, 46)
# Calculated Edge Weight (9, 10)
# Calculated Edge Weight (9, 11)
# Calculated Edge Weight (9, 12)
# Calculated Edge Weight (9, 13)
# Calculated Edge Weight (9, 14)
# Calculated Edge Weight (9, 15)
# Calculated Edge Weight (9, 16)
# Calculated Edge Weight (9, 17)
# Calculated Edge Weight (9, 18)
# Calculated Edge Weight (9, 19)
# Calculated Edge Weight (9, 20)
# Calculated Edge Weight (9, 21)
# Calculated Edge Weight (9, 22)
# Calculated Edge Weight (9, 23)
# Calculated Edge Weight (9, 24)
# Calculated Edge Weight (9, 25)
# Calculated Edge Weight (9, 26)
# Calculated Edge Weight (9, 27)
# Calculated Edge Weight (9, 28)
# Calculated Edge Weight (9, 29)
# Calculated Edge Weight (9, 30)
# Calculated Edge Weight (9, 31)
# Calculated Edge Weight (9, 32)
# Calculated Edge Weight (9, 33)
# Calculated Edge Weight (9, 34)
# Calculated Edge Weight (9, 35)
# Calculated Edge Weight (9, 36)
# Calculated Edge Weight (9, 37)
# Calculated Edge Weight (9, 38)
# Calculated Edge Weight (9, 39)
# Calculated Edge Weight (9, 40)
# Calculated Edge Weight (9, 41)
# Calculated Edge Weight (9, 42)
# Calculated Edge Weight (9, 43)
# Calculated Edge Weight (9, 44)
# Calculated Edge Weight (9, 45)
# Calculated Edge Weight (9, 46)
# Calculated Edge Weight (10, 11)
# Calculated Edge Weight (10, 12)
# Calculated Edge Weight (10, 13)
# Calculated Edge Weight (10, 14)
# Calculated Edge Weight (10, 15)
# Calculated Edge Weight (10, 16)
# Calculated Edge Weight (10, 17)
# Calculated Edge Weight (10, 18)
# Calculated Edge Weight (10, 19)
# Calculated Edge Weight (10, 20)
# Calculated Edge Weight (10, 21)
# Calculated Edge Weight (10, 22)
# Calculated Edge Weight (10, 23)
# Calculated Edge Weight (10, 24)
# Calculated Edge Weight (10, 25)
# Calculated Edge Weight (10, 26)
# Calculated Edge Weight (10, 27)
# Calculated Edge Weight (10, 28)
# Calculated Edge Weight (10, 29)
# Calculated Edge Weight (10, 30)
# Calculated Edge Weight (10, 31)
# Calculated Edge Weight (10, 32)
# Calculated Edge Weight (10, 33)
# Calculated Edge Weight (10, 34)
# Calculated Edge Weight (10, 35)
# Calculated Edge Weight (10, 36)
# Calculated Edge Weight (10, 37)
# Calculated Edge Weight (10, 38)
# Calculated Edge Weight (10, 39)
# Calculated Edge Weight (10, 40)
# Calculated Edge Weight (10, 41)
# Calculated Edge Weight (10, 42)
# Calculated Edge Weight (10, 43)
# Calculated Edge Weight (10, 44)
# Calculated Edge Weight (10, 45)
# Calculated Edge Weight (10, 46)
# Calculated Edge Weight (11, 12)
# Calculated Edge Weight (11, 13)
# Calculated Edge Weight (11, 14)
# Calculated Edge Weight (11, 15)
# Calculated Edge Weight (11, 16)
# Calculated Edge Weight (11, 17)
# Calculated Edge Weight (11, 18)
# Calculated Edge Weight (11, 19)
# Calculated Edge Weight (11, 20)
# Calculated Edge Weight (11, 21)
# Calculated Edge Weight (11, 22)
# Calculated Edge Weight (11, 23)
# Calculated Edge Weight (11, 24)
# Calculated Edge Weight (11, 25)
# Calculated Edge Weight (11, 26)
# Calculated Edge Weight (11, 27)
# Calculated Edge Weight (11, 28)
# Calculated Edge Weight (11, 29)
# Calculated Edge Weight (11, 30)
# Calculated Edge Weight (11, 31)
# Calculated Edge Weight (11, 32)
# Calculated Edge Weight (11, 33)
# Calculated Edge Weight (11, 34)
# Calculated Edge Weight (11, 35)
# Calculated Edge Weight (11, 36)
# Calculated Edge Weight (11, 37)
# Calculated Edge Weight (11, 38)
# Calculated Edge Weight (11, 39)
# Calculated Edge Weight (11, 40)
# Calculated Edge Weight (11, 41)
# Calculated Edge Weight (11, 42)
# Calculated Edge Weight (11, 43)
# Calculated Edge Weight (11, 44)
# Calculated Edge Weight (11, 45)
# Calculated Edge Weight (11, 46)
# Calculated Edge Weight (12, 13)
# Calculated Edge Weight (12, 14)
# Calculated Edge Weight (12, 15)
# Calculated Edge Weight (12, 16)
# Calculated Edge Weight (12, 17)
# Calculated Edge Weight (12, 18)
# Calculated Edge Weight (12, 19)
# Calculated Edge Weight (12, 20)
# Calculated Edge Weight (12, 21)
# Calculated Edge Weight (12, 22)
# Calculated Edge Weight (12, 23)
# Calculated Edge Weight (12, 24)
# Calculated Edge Weight (12, 25)
# Calculated Edge Weight (12, 26)
# Calculated Edge Weight (12, 27)
# Calculated Edge Weight (12, 28)
# Calculated Edge Weight (12, 29)
# Calculated Edge Weight (12, 30)
# Calculated Edge Weight (12, 31)
# Calculated Edge Weight (12, 32)
# Calculated Edge Weight (12, 33)
# Calculated Edge Weight (12, 34)
# Calculated Edge Weight (12, 35)
# Calculated Edge Weight (12, 36)
# Calculated Edge Weight (12, 37)
# Calculated Edge Weight (12, 38)
# Calculated Edge Weight (12, 39)
# Calculated Edge Weight (12, 40)
# Calculated Edge Weight (12, 41)
# Calculated Edge Weight (12, 42)
# Calculated Edge Weight (12, 43)
# Calculated Edge Weight (12, 44)
# Calculated Edge Weight (12, 45)
# Calculated Edge Weight (12, 46)
# Calculated Edge Weight (13, 14)
# Calculated Edge Weight (13, 15)
# Calculated Edge Weight (13, 16)
# Calculated Edge Weight (13, 17)
# Calculated Edge Weight (13, 18)
# Calculated Edge Weight (13, 19)
# Calculated Edge Weight (13, 20)
# Calculated Edge Weight (13, 21)
# Calculated Edge Weight (13, 22)
# Calculated Edge Weight (13, 23)
# Calculated Edge Weight (13, 24)
# Calculated Edge Weight (13, 25)
# Calculated Edge Weight (13, 26)
# Calculated Edge Weight (13, 27)
# Calculated Edge Weight (13, 28)
# Calculated Edge Weight (13, 29)
# Calculated Edge Weight (13, 30)
# Calculated Edge Weight (13, 31)
# Calculated Edge Weight (13, 32)
# Calculated Edge Weight (13, 33)
# Calculated Edge Weight (13, 34)
# Calculated Edge Weight (13, 35)
# Calculated Edge Weight (13, 36)
# Calculated Edge Weight (13, 37)
# Calculated Edge Weight (13, 38)
# Calculated Edge Weight (13, 39)
# Calculated Edge Weight (13, 40)
# Calculated Edge Weight (13, 41)
# Calculated Edge Weight (13, 42)
# Calculated Edge Weight (13, 43)
# Calculated Edge Weight (13, 44)
# Calculated Edge Weight (13, 45)
# Calculated Edge Weight (13, 46)
# Calculated Edge Weight (14, 15)
# Calculated Edge Weight (14, 16)
# Calculated Edge Weight (14, 17)
# Calculated Edge Weight (14, 18)
# Calculated Edge Weight (14, 19)
# Calculated Edge Weight (14, 20)
# Calculated Edge Weight (14, 21)
# Calculated Edge Weight (14, 22)
# Calculated Edge Weight (14, 23)
# Calculated Edge Weight (14, 24)
# Calculated Edge Weight (14, 25)
# Calculated Edge Weight (14, 26)
# Calculated Edge Weight (14, 27)
# Calculated Edge Weight (14, 28)
# Calculated Edge Weight (14, 29)
# Calculated Edge Weight (14, 30)
# Calculated Edge Weight (14, 31)
# Calculated Edge Weight (14, 32)
# Calculated Edge Weight (14, 33)
# Calculated Edge Weight (14, 34)
# Calculated Edge Weight (14, 35)
# Calculated Edge Weight (14, 36)
# Calculated Edge Weight (14, 37)
# Calculated Edge Weight (14, 38)
# Calculated Edge Weight (14, 39)
# Calculated Edge Weight (14, 40)
# Calculated Edge Weight (14, 41)
# Calculated Edge Weight (14, 42)
# Calculated Edge Weight (14, 43)
# Calculated Edge Weight (14, 44)
# Calculated Edge Weight (14, 45)
# Calculated Edge Weight (14, 46)
# Calculated Edge Weight (15, 16)
# Calculated Edge Weight (15, 17)
# Calculated Edge Weight (15, 18)
# Calculated Edge Weight (15, 19)
# Calculated Edge Weight (15, 20)
# Calculated Edge Weight (15, 21)
# Calculated Edge Weight (15, 22)
# Calculated Edge Weight (15, 23)
# Calculated Edge Weight (15, 24)
# Calculated Edge Weight (15, 25)
# Calculated Edge Weight (15, 26)
# Calculated Edge Weight (15, 27)
# Calculated Edge Weight (15, 28)
# Calculated Edge Weight (15, 29)
# Calculated Edge Weight (15, 30)
# Calculated Edge Weight (15, 31)
# Calculated Edge Weight (15, 32)
# Calculated Edge Weight (15, 33)
# Calculated Edge Weight (15, 34)
# Calculated Edge Weight (15, 35)
# Calculated Edge Weight (15, 36)
# Calculated Edge Weight (15, 37)
# Calculated Edge Weight (15, 38)
# Calculated Edge Weight (15, 39)
# Calculated Edge Weight (15, 40)
# Calculated Edge Weight (15, 41)
# Calculated Edge Weight (15, 42)
# Calculated Edge Weight (15, 43)
# Calculated Edge Weight (15, 44)
# Calculated Edge Weight (15, 45)
# Calculated Edge Weight (15, 46)
# Calculated Edge Weight (16, 17)
# Calculated Edge Weight (16, 18)
# Calculated Edge Weight (16, 19)
# Calculated Edge Weight (16, 20)
# Calculated Edge Weight (16, 21)
# Calculated Edge Weight (16, 22)
# Calculated Edge Weight (16, 23)
# Calculated Edge Weight (16, 24)
# Calculated Edge Weight (16, 25)
# Calculated Edge Weight (16, 26)
# Calculated Edge Weight (16, 27)
# Calculated Edge Weight (16, 28)
# Calculated Edge Weight (16, 29)
# Calculated Edge Weight (16, 30)
# Calculated Edge Weight (16, 31)
# Calculated Edge Weight (16, 32)
# Calculated Edge Weight (16, 33)
# Calculated Edge Weight (16, 34)
# Calculated Edge Weight (16, 35)
# Calculated Edge Weight (16, 36)
# Calculated Edge Weight (16, 37)
# Calculated Edge Weight (16, 38)
# Calculated Edge Weight (16, 39)
# Calculated Edge Weight (16, 40)
# Calculated Edge Weight (16, 41)
# Calculated Edge Weight (16, 42)
# Calculated Edge Weight (16, 43)
# Calculated Edge Weight (16, 44)
# Calculated Edge Weight (16, 45)
# Calculated Edge Weight (16, 46)
# Calculated Edge Weight (17, 18)
# Calculated Edge Weight (17, 19)
# Calculated Edge Weight (17, 20)
# Calculated Edge Weight (17, 21)
# Calculated Edge Weight (17, 22)
# Calculated Edge Weight (17, 23)
# Calculated Edge Weight (17, 24)
# Calculated Edge Weight (17, 25)
# Calculated Edge Weight (17, 26)
# Calculated Edge Weight (17, 27)
# Calculated Edge Weight (17, 28)
# Calculated Edge Weight (17, 29)
# Calculated Edge Weight (17, 30)
# Calculated Edge Weight (17, 31)
# Calculated Edge Weight (17, 32)
# Calculated Edge Weight (17, 33)
# Calculated Edge Weight (17, 34)
# Calculated Edge Weight (17, 35)
# Calculated Edge Weight (17, 36)
# Calculated Edge Weight (17, 37)
# Calculated Edge Weight (17, 38)
# Calculated Edge Weight (17, 39)
# Calculated Edge Weight (17, 40)
# Calculated Edge Weight (17, 41)
# Calculated Edge Weight (17, 42)
# Calculated Edge Weight (17, 43)
# Calculated Edge Weight (17, 44)
# Calculated Edge Weight (17, 45)
# Calculated Edge Weight (17, 46)
# Calculated Edge Weight (18, 19)
# Calculated Edge Weight (18, 20)
# Calculated Edge Weight (18, 21)
# Calculated Edge Weight (18, 22)
# Calculated Edge Weight (18, 23)
# Calculated Edge Weight (18, 24)
# Calculated Edge Weight (18, 25)
# Calculated Edge Weight (18, 26)
# Calculated Edge Weight (18, 27)
# Calculated Edge Weight (18, 28)
# Calculated Edge Weight (18, 29)
# Calculated Edge Weight (18, 30)
# Calculated Edge Weight (18, 31)
# Calculated Edge Weight (18, 32)
# Calculated Edge Weight (18, 33)
# Calculated Edge Weight (18, 34)
# Calculated Edge Weight (18, 35)
# Calculated Edge Weight (18, 36)
# Calculated Edge Weight (18, 37)
# Calculated Edge Weight (18, 38)
# Calculated Edge Weight (18, 39)
# Calculated Edge Weight (18, 40)
# Calculated Edge Weight (18, 41)
# Calculated Edge Weight (18, 42)
# Calculated Edge Weight (18, 43)
# Calculated Edge Weight (18, 44)
# Calculated Edge Weight (18, 45)
# Calculated Edge Weight (18, 46)
# Calculated Edge Weight (19, 20)
# Calculated Edge Weight (19, 21)
# Calculated Edge Weight (19, 22)
# Calculated Edge Weight (19, 23)
# Calculated Edge Weight (19, 24)
# Calculated Edge Weight (19, 25)
# Calculated Edge Weight (19, 26)
# Calculated Edge Weight (19, 27)
# Calculated Edge Weight (19, 28)
# Calculated Edge Weight (19, 29)
# Calculated Edge Weight (19, 30)
# Calculated Edge Weight (19, 31)
# Calculated Edge Weight (19, 32)
# Calculated Edge Weight (19, 33)
# Calculated Edge Weight (19, 34)
# Calculated Edge Weight (19, 35)
# Calculated Edge Weight (19, 36)
# Calculated Edge Weight (19, 37)
# Calculated Edge Weight (19, 38)
# Calculated Edge Weight (19, 39)
# Calculated Edge Weight (19, 40)
# Calculated Edge Weight (19, 41)
# Calculated Edge Weight (19, 42)
# Calculated Edge Weight (19, 43)
# Calculated Edge Weight (19, 44)
# Calculated Edge Weight (19, 45)
# Calculated Edge Weight (19, 46)
# Calculated Edge Weight (20, 21)
# Calculated Edge Weight (20, 22)
# Calculated Edge Weight (20, 23)
# Calculated Edge Weight (20, 24)
# Calculated Edge Weight (20, 25)
# Calculated Edge Weight (20, 26)
# Calculated Edge Weight (20, 27)
# Calculated Edge Weight (20, 28)
# Calculated Edge Weight (20, 29)
# Calculated Edge Weight (20, 30)
# Calculated Edge Weight (20, 31)
# Calculated Edge Weight (20, 32)
# Calculated Edge Weight (20, 33)
# Calculated Edge Weight (20, 34)
# Calculated Edge Weight (20, 35)
# Calculated Edge Weight (20, 36)
# Calculated Edge Weight (20, 37)
# Calculated Edge Weight (20, 38)
# Calculated Edge Weight (20, 39)
# Calculated Edge Weight (20, 40)
# Calculated Edge Weight (20, 41)
# Calculated Edge Weight (20, 42)
# Calculated Edge Weight (20, 43)
# Calculated Edge Weight (20, 44)
# Calculated Edge Weight (20, 45)
# Calculated Edge Weight (20, 46)
# Calculated Edge Weight (21, 22)
# Calculated Edge Weight (21, 23)
# Calculated Edge Weight (21, 24)
# Calculated Edge Weight (21, 25)
# Calculated Edge Weight (21, 26)
# Calculated Edge Weight (21, 27)
# Calculated Edge Weight (21, 28)
# Calculated Edge Weight (21, 29)
# Calculated Edge Weight (21, 30)
# Calculated Edge Weight (21, 31)
# Calculated Edge Weight (21, 32)
# Calculated Edge Weight (21, 33)
# Calculated Edge Weight (21, 34)
# Calculated Edge Weight (21, 35)
# Calculated Edge Weight (21, 36)
# Calculated Edge Weight (21, 37)
# Calculated Edge Weight (21, 38)
# Calculated Edge Weight (21, 39)
# Calculated Edge Weight (21, 40)
# Calculated Edge Weight (21, 41)
# Calculated Edge Weight (21, 42)
# Calculated Edge Weight (21, 43)
# Calculated Edge Weight (21, 44)
# Calculated Edge Weight (21, 45)
# Calculated Edge Weight (21, 46)
# Calculated Edge Weight (22, 23)
# Calculated Edge Weight (22, 24)
# Calculated Edge Weight (22, 25)
# Calculated Edge Weight (22, 26)
# Calculated Edge Weight (22, 27)
# Calculated Edge Weight (22, 28)
# Calculated Edge Weight (22, 29)
# Calculated Edge Weight (22, 30)
# Calculated Edge Weight (22, 31)
# Calculated Edge Weight (22, 32)
# Calculated Edge Weight (22, 33)
# Calculated Edge Weight (22, 34)
# Calculated Edge Weight (22, 35)
# Calculated Edge Weight (22, 36)
# Calculated Edge Weight (22, 37)
# Calculated Edge Weight (22, 38)
# Calculated Edge Weight (22, 39)
# Calculated Edge Weight (22, 40)
# Calculated Edge Weight (22, 41)
# Calculated Edge Weight (22, 42)
# Calculated Edge Weight (22, 43)
# Calculated Edge Weight (22, 44)
# Calculated Edge Weight (22, 45)
# Calculated Edge Weight (22, 46)
# Calculated Edge Weight (23, 24)
# Calculated Edge Weight (23, 25)
# Calculated Edge Weight (23, 26)
# Calculated Edge Weight (23, 27)
# Calculated Edge Weight (23, 28)
# Calculated Edge Weight (23, 29)
# Calculated Edge Weight (23, 30)
# Calculated Edge Weight (23, 31)
# Calculated Edge Weight (23, 32)
# Calculated Edge Weight (23, 33)
# Calculated Edge Weight (23, 34)
# Calculated Edge Weight (23, 35)
# Calculated Edge Weight (23, 36)
# Calculated Edge Weight (23, 37)
# Calculated Edge Weight (23, 38)
# Calculated Edge Weight (23, 39)
# Calculated Edge Weight (23, 40)
# Calculated Edge Weight (23, 41)
# Calculated Edge Weight (23, 42)
# Calculated Edge Weight (23, 43)
# Calculated Edge Weight (23, 44)
# Calculated Edge Weight (23, 45)
# Calculated Edge Weight (23, 46)
# Calculated Edge Weight (24, 25)
# Calculated Edge Weight (24, 26)
# Calculated Edge Weight (24, 27)
# Calculated Edge Weight (24, 28)
# Calculated Edge Weight (24, 29)
# Calculated Edge Weight (24, 30)
# Calculated Edge Weight (24, 31)
# Calculated Edge Weight (24, 32)
# Calculated Edge Weight (24, 33)
# Calculated Edge Weight (24, 34)
# Calculated Edge Weight (24, 35)
# Calculated Edge Weight (24, 36)
# Calculated Edge Weight (24, 37)
# Calculated Edge Weight (24, 38)
# Calculated Edge Weight (24, 39)
# Calculated Edge Weight (24, 40)
# Calculated Edge Weight (24, 41)
# Calculated Edge Weight (24, 42)
# Calculated Edge Weight (24, 43)
# Calculated Edge Weight (24, 44)
# Calculated Edge Weight (24, 45)
# Calculated Edge Weight (24, 46)
# Calculated Edge Weight (25, 26)
# Calculated Edge Weight (25, 27)
# Calculated Edge Weight (25, 28)
# Calculated Edge Weight (25, 29)
# Calculated Edge Weight (25, 30)
# Calculated Edge Weight (25, 31)
# Calculated Edge Weight (25, 32)
# Calculated Edge Weight (25, 33)
# Calculated Edge Weight (25, 34)
# Calculated Edge Weight (25, 35)
# Calculated Edge Weight (25, 36)
# Calculated Edge Weight (25, 37)
# Calculated Edge Weight (25, 38)
# Calculated Edge Weight (25, 39)
# Calculated Edge Weight (25, 40)
# Calculated Edge Weight (25, 41)
# Calculated Edge Weight (25, 42)
# Calculated Edge Weight (25, 43)
# Calculated Edge Weight (25, 44)
# Calculated Edge Weight (25, 45)
# Calculated Edge Weight (25, 46)
# Calculated Edge Weight (26, 27)
# Calculated Edge Weight (26, 28)
# Calculated Edge Weight (26, 29)
# Calculated Edge Weight (26, 30)
# Calculated Edge Weight (26, 31)
# Calculated Edge Weight (26, 32)
# Calculated Edge Weight (26, 33)
# Calculated Edge Weight (26, 34)
# Calculated Edge Weight (26, 35)
# Calculated Edge Weight (26, 36)
# Calculated Edge Weight (26, 37)
# Calculated Edge Weight (26, 38)
# Calculated Edge Weight (26, 39)
# Calculated Edge Weight (26, 40)
# Calculated Edge Weight (26, 41)
# Calculated Edge Weight (26, 42)
# Calculated Edge Weight (26, 43)
# Calculated Edge Weight (26, 44)
# Calculated Edge Weight (26, 45)
# Calculated Edge Weight (26, 46)
# Calculated Edge Weight (27, 28)
# Calculated Edge Weight (27, 29)
# Calculated Edge Weight (27, 30)
# Calculated Edge Weight (27, 31)
# Calculated Edge Weight (27, 32)
# Calculated Edge Weight (27, 33)
# Calculated Edge Weight (27, 34)
# Calculated Edge Weight (27, 35)
# Calculated Edge Weight (27, 36)
# Calculated Edge Weight (27, 37)
# Calculated Edge Weight (27, 38)
# Calculated Edge Weight (27, 39)
# Calculated Edge Weight (27, 40)
# Calculated Edge Weight (27, 41)
# Calculated Edge Weight (27, 42)
# Calculated Edge Weight (27, 43)
# Calculated Edge Weight (27, 44)
# Calculated Edge Weight (27, 45)
# Calculated Edge Weight (27, 46)
# Calculated Edge Weight (28, 29)
# Calculated Edge Weight (28, 30)
# Calculated Edge Weight (28, 31)
# Calculated Edge Weight (28, 32)
# Calculated Edge Weight (28, 33)
# Calculated Edge Weight (28, 34)
# Calculated Edge Weight (28, 35)
# Calculated Edge Weight (28, 36)
# Calculated Edge Weight (28, 37)
# Calculated Edge Weight (28, 38)
# Calculated Edge Weight (28, 39)
# Calculated Edge Weight (28, 40)
# Calculated Edge Weight (28, 41)
# Calculated Edge Weight (28, 42)
# Calculated Edge Weight (28, 43)
# Calculated Edge Weight (28, 44)
# Calculated Edge Weight (28, 45)
# Calculated Edge Weight (28, 46)
# Calculated Edge Weight (29, 30)
# Calculated Edge Weight (29, 31)
# Calculated Edge Weight (29, 32)
# Calculated Edge Weight (29, 33)
# Calculated Edge Weight (29, 34)
# Calculated Edge Weight (29, 35)
# Calculated Edge Weight (29, 36)
# Calculated Edge Weight (29, 37)
# Calculated Edge Weight (29, 38)
# Calculated Edge Weight (29, 39)
# Calculated Edge Weight (29, 40)
# Calculated Edge Weight (29, 41)
# Calculated Edge Weight (29, 42)
# Calculated Edge Weight (29, 43)
# Calculated Edge Weight (29, 44)
# Calculated Edge Weight (29, 45)
# Calculated Edge Weight (29, 46)
# Calculated Edge Weight (30, 31)
# Calculated Edge Weight (30, 32)
# Calculated Edge Weight (30, 33)
# Calculated Edge Weight (30, 34)
# Calculated Edge Weight (30, 35)
# Calculated Edge Weight (30, 36)
# Calculated Edge Weight (30, 37)
# Calculated Edge Weight (30, 38)
# Calculated Edge Weight (30, 39)
# Calculated Edge Weight (30, 40)
# Calculated Edge Weight (30, 41)
# Calculated Edge Weight (30, 42)
# Calculated Edge Weight (30, 43)
# Calculated Edge Weight (30, 44)
# Calculated Edge Weight (30, 45)
# Calculated Edge Weight (30, 46)
# Calculated Edge Weight (31, 32)
# Calculated Edge Weight (31, 33)
# Calculated Edge Weight (31, 34)
# Calculated Edge Weight (31, 35)
# Calculated Edge Weight (31, 36)
# Calculated Edge Weight (31, 37)
# Calculated Edge Weight (31, 38)
# Calculated Edge Weight (31, 39)
# Calculated Edge Weight (31, 40)
# Calculated Edge Weight (31, 41)
# Calculated Edge Weight (31, 42)
# Calculated Edge Weight (31, 43)
# Calculated Edge Weight (31, 44)
# Calculated Edge Weight (31, 45)
# Calculated Edge Weight (31, 46)
# Calculated Edge Weight (32, 33)
# Calculated Edge Weight (32, 34)
# Calculated Edge Weight (32, 35)
# Calculated Edge Weight (32, 36)
# Calculated Edge Weight (32, 37)
# Calculated Edge Weight (32, 38)
# Calculated Edge Weight (32, 39)
# Calculated Edge Weight (32, 40)
# Calculated Edge Weight (32, 41)
# Calculated Edge Weight (32, 42)
# Calculated Edge Weight (32, 43)
# Calculated Edge Weight (32, 44)
# Calculated Edge Weight (32, 45)
# Calculated Edge Weight (32, 46)
# Calculated Edge Weight (33, 34)
# Calculated Edge Weight (33, 35)
# Calculated Edge Weight (33, 36)
# Calculated Edge Weight (33, 37)
# Calculated Edge Weight (33, 38)
# Calculated Edge Weight (33, 39)
# Calculated Edge Weight (33, 40)
# Calculated Edge Weight (33, 41)
# Calculated Edge Weight (33, 42)
# Calculated Edge Weight (33, 43)
# Calculated Edge Weight (33, 44)
# Calculated Edge Weight (33, 45)
# Calculated Edge Weight (33, 46)
# Calculated Edge Weight (34, 35)
# Calculated Edge Weight (34, 36)
# Calculated Edge Weight (34, 37)
# Calculated Edge Weight (34, 38)
# Calculated Edge Weight (34, 39)
# Calculated Edge Weight (34, 40)
# Calculated Edge Weight (34, 41)
# Calculated Edge Weight (34, 42)
# Calculated Edge Weight (34, 43)
# Calculated Edge Weight (34, 44)
# Calculated Edge Weight (34, 45)
# Calculated Edge Weight (34, 46)
# Calculated Edge Weight (35, 36)
# Calculated Edge Weight (35, 37)
# Calculated Edge Weight (35, 38)
# Calculated Edge Weight (35, 39)
# Calculated Edge Weight (35, 40)
# Calculated Edge Weight (35, 41)
# Calculated Edge Weight (35, 42)
# Calculated Edge Weight (35, 43)
# Calculated Edge Weight (35, 44)
# Calculated Edge Weight (35, 45)
# Calculated Edge Weight (35, 46)
# Calculated Edge Weight (36, 37)
# Calculated Edge Weight (36, 38)
# Calculated Edge Weight (36, 39)
# Calculated Edge Weight (36, 40)
# Calculated Edge Weight (36, 41)
# Calculated Edge Weight (36, 42)
# Calculated Edge Weight (36, 43)
# Calculated Edge Weight (36, 44)
# Calculated Edge Weight (36, 45)
# Calculated Edge Weight (36, 46)
# Calculated Edge Weight (37, 38)
# Calculated Edge Weight (37, 39)
# Calculated Edge Weight (37, 40)
# Calculated Edge Weight (37, 41)
# Calculated Edge Weight (37, 42)
# Calculated Edge Weight (37, 43)
# Calculated Edge Weight (37, 44)
# Calculated Edge Weight (37, 45)
# Calculated Edge Weight (37, 46)
# Calculated Edge Weight (38, 39)
# Calculated Edge Weight (38, 40)
# Calculated Edge Weight (38, 41)
# Calculated Edge Weight (38, 42)
# Calculated Edge Weight (38, 43)
# Calculated Edge Weight (38, 44)
# Calculated Edge Weight (38, 45)
# Calculated Edge Weight (38, 46)
# Calculated Edge Weight (39, 40)
# Calculated Edge Weight (39, 41)
# Calculated Edge Weight (39, 42)
# Calculated Edge Weight (39, 43)
# Calculated Edge Weight (39, 44)
# Calculated Edge Weight (39, 45)
# Calculated Edge Weight (39, 46)
# Calculated Edge Weight (40, 41)
# Calculated Edge Weight (40, 42)
# Calculated Edge Weight (40, 43)
# Calculated Edge Weight (40, 44)
# Calculated Edge Weight (40, 45)
# Calculated Edge Weight (40, 46)
# Calculated Edge Weight (41, 42)
# Calculated Edge Weight (41, 43)
# Calculated Edge Weight (41, 44)
# Calculated Edge Weight (41, 45)
# Calculated Edge Weight (41, 46)
# Calculated Edge Weight (42, 43)
# Calculated Edge Weight (42, 44)
# Calculated Edge Weight (42, 45)
# Calculated Edge Weight (42, 46)
# Calculated Edge Weight (43, 44)
# Calculated Edge Weight (43, 45)
# Calculated Edge Weight (43, 46)
# Calculated Edge Weight (44, 45)
# Calculated Edge Weight (44, 46)
# Calculated Edge Weight (45, 46)

# %% [markdown]
# ## Building the KNN Graph

# %%
# building KNN Graph
k = 3
distance_matrix = dist_mat
knn_graph = kneighbors_graph(distance_matrix, n_neighbors=k, mode='connectivity')

G = nx.from_scipy_sparse_array(knn_graph)

# Detect if the graph is disjoint
if not nx.is_connected(G):
    print("The KNN graph is disjoint. Ensuring connectivity...")

    # Calculate the connected components
    components = list(nx.connected_components(G))

    # Connect the components
    for i in range(len(components) - 1):
        min_dist = np.inf
        closest_pair = None
        for node1 in components[i]:
            for node2 in components[i + 1]:
                dist = distance_matrix[node1, node2]
                if dist < min_dist:
                    min_dist = dist
                    closest_pair = (node1, node2)

        # Add an edge between the closest pair of nodes from different components
        G.add_edge(closest_pair[0], closest_pair[1])

# Plot the final connected graph
pos = nx.spring_layout(G, seed=42, iterations=50)
pos_dict = {i: pos[i] for i in range(len(pos))}
nx.draw(G, node_size=50, pos=pos_dict)
plt.title('Bach Prelude in C')
plt.show()

# %%
# distance matrix to knn graph function
def distance_matrix_to_knn_graph(k: int, distance_matrix: np.array, graph_title: str,
                                 seed: int, iterations: int):
  knn_graph = kneighbors_graph(distance_matrix, n_neighbors=k, mode='connectivity')

  G = nx.from_scipy_sparse_array(knn_graph)

  # Detect if the graph is disjoint
  if not nx.is_connected(G):
      print("The KNN graph is disjoint. Ensuring connectivity...")

      # Calculate the connected components
      components = list(nx.connected_components(G))

      # Connect the components
      for i in range(len(components) - 1):
          min_dist = np.inf
          closest_pair = None
          for node1 in components[i]:
              for node2 in components[i + 1]:
                  dist = distance_matrix[node1, node2]
                  if dist < min_dist:
                      min_dist = dist
                      closest_pair = (node1, node2)

          # Add an edge between the closest pair of nodes from different components
          G.add_edge(closest_pair[0], closest_pair[1])

  # Plot the final connected graph
  pos = nx.spring_layout(G, seed=seed, iterations=iterations)
  nx.draw(G, node_size=50, pos=pos)
  plt.title(graph_title + f" (K={k})")
  plt.show()

# %%
# show graph
distance_matrix_to_knn_graph(3, dist_mat, "Bach Prelude in C", 42, 50)

# %% [markdown]
# ### Currently Trying to Put The Segment Data Into The Node so we can analyze grouped segments

# %%
# segments to graph function
def segments_to_graph(k: int, segments: list[pd.DataFrame], cores=None):
  # Convert segments to a distance matrix
  distance_matrix = segments_to_distance_matrix(segments, cores=cores)

  # Compute the k-NN graph
  knn_graph = kneighbors_graph(distance_matrix, n_neighbors=k, mode='connectivity')

  # Convert the k-NN graph to a NetworkX graph
  G = nx.from_scipy_sparse_array(knn_graph)

  # Add segment data as attributes to each node
  for i in range(len(segments)):
    G.nodes[i]['segment'] = segments[i]

  # Detect if the graph is disjoint
  if not nx.is_connected(G):
      print("The KNN graph is disjoint. Ensuring connectivity...")

      # Calculate the connected components
      components = list(nx.connected_components(G))

      # Connect the components
      for i in range(len(components) - 1):
          min_dist = np.inf
          closest_pair = None
          for node1 in components[i]:
              for node2 in components[i + 1]:
                  dist = distance_matrix[node1, node2]
                  if dist < min_dist:
                      min_dist = dist
                      closest_pair = (node1, node2)

          # Add an edge between the closest pair of nodes from different components
          G.add_edge(closest_pair[0], closest_pair[1])

  return G, distance_matrix

# %%
# segments to graph
graph, distance_matrix = segments_to_graph(5, segments)
# Out:
# Calculated Edge Weight (0, 1)
# Calculated Edge Weight (0, 2)
# Calculated Edge Weight (0, 3)
# Calculated Edge Weight (0, 4)
# Calculated Edge Weight (0, 5)
# Calculated Edge Weight (0, 6)
# Calculated Edge Weight (0, 7)
# Calculated Edge Weight (0, 8)
# Calculated Edge Weight (0, 9)
# Calculated Edge Weight (0, 10)
# Calculated Edge Weight (0, 11)
# Calculated Edge Weight (0, 12)
# Calculated Edge Weight (0, 13)
# Calculated Edge Weight (0, 14)
# Calculated Edge Weight (0, 15)
# Calculated Edge Weight (0, 16)
# Calculated Edge Weight (0, 17)
# Calculated Edge Weight (0, 18)
# Calculated Edge Weight (0, 19)
# Calculated Edge Weight (0, 20)
# Calculated Edge Weight (0, 21)
# Calculated Edge Weight (0, 22)
# Calculated Edge Weight (0, 23)
# Calculated Edge Weight (0, 24)
# Calculated Edge Weight (0, 25)
# Calculated Edge Weight (0, 26)
# Calculated Edge Weight (0, 27)
# Calculated Edge Weight (0, 28)
# Calculated Edge Weight (0, 29)
# Calculated Edge Weight (0, 30)
# Calculated Edge Weight (0, 31)
# Calculated Edge Weight (0, 32)
# Calculated Edge Weight (0, 33)
# Calculated Edge Weight (0, 34)
# Calculated Edge Weight (0, 35)
# Calculated Edge Weight (0, 36)
# Calculated Edge Weight (0, 37)
# Calculated Edge Weight (0, 38)
# Calculated Edge Weight (0, 39)
# Calculated Edge Weight (0, 40)
# Calculated Edge Weight (0, 41)
# Calculated Edge Weight (0, 42)
# Calculated Edge Weight (0, 43)
# Calculated Edge Weight (0, 44)
# Calculated Edge Weight (0, 45)
# Calculated Edge Weight (0, 46)
# Calculated Edge Weight (1, 2)
# Calculated Edge Weight (1, 3)
# Calculated Edge Weight (1, 4)
# Calculated Edge Weight (1, 5)
# Calculated Edge Weight (1, 6)
# Calculated Edge Weight (1, 7)
# Calculated Edge Weight (1, 8)
# Calculated Edge Weight (1, 9)
# Calculated Edge Weight (1, 10)
# Calculated Edge Weight (1, 11)
# Calculated Edge Weight (1, 12)
# Calculated Edge Weight (1, 13)
# Calculated Edge Weight (1, 14)
# Calculated Edge Weight (1, 15)
# Calculated Edge Weight (1, 16)
# Calculated Edge Weight (1, 17)
# Calculated Edge Weight (1, 18)
# Calculated Edge Weight (1, 19)
# Calculated Edge Weight (1, 20)
# Calculated Edge Weight (1, 21)
# Calculated Edge Weight (1, 22)
# Calculated Edge Weight (1, 23)
# Calculated Edge Weight (1, 24)
# Calculated Edge Weight (1, 25)
# Calculated Edge Weight (1, 26)
# Calculated Edge Weight (1, 27)
# Calculated Edge Weight (1, 28)
# Calculated Edge Weight (1, 29)
# Calculated Edge Weight (1, 30)
# Calculated Edge Weight (1, 31)
# Calculated Edge Weight (1, 32)
# Calculated Edge Weight (1, 33)
# Calculated Edge Weight (1, 34)
# Calculated Edge Weight (1, 35)
# Calculated Edge Weight (1, 36)
# Calculated Edge Weight (1, 37)
# Calculated Edge Weight (1, 38)
# Calculated Edge Weight (1, 39)
# Calculated Edge Weight (1, 40)
# Calculated Edge Weight (1, 41)
# Calculated Edge Weight (1, 42)
# Calculated Edge Weight (1, 43)
# Calculated Edge Weight (1, 44)
# Calculated Edge Weight (1, 45)
# Calculated Edge Weight (1, 46)
# Calculated Edge Weight (2, 3)
# Calculated Edge Weight (2, 4)
# Calculated Edge Weight (2, 5)
# Calculated Edge Weight (2, 6)
# Calculated Edge Weight (2, 7)
# Calculated Edge Weight (2, 8)
# Calculated Edge Weight (2, 9)
# Calculated Edge Weight (2, 10)
# Calculated Edge Weight (2, 11)
# Calculated Edge Weight (2, 12)
# Calculated Edge Weight (2, 13)
# Calculated Edge Weight (2, 14)
# Calculated Edge Weight (2, 15)
# Calculated Edge Weight (2, 16)
# Calculated Edge Weight (2, 17)
# Calculated Edge Weight (2, 18)
# Calculated Edge Weight (2, 19)
# Calculated Edge Weight (2, 20)
# Calculated Edge Weight (2, 21)
# Calculated Edge Weight (2, 22)
# Calculated Edge Weight (2, 23)
# Calculated Edge Weight (2, 24)
# Calculated Edge Weight (2, 25)
# Calculated Edge Weight (2, 26)
# Calculated Edge Weight (2, 27)
# Calculated Edge Weight (2, 28)
# Calculated Edge Weight (2, 29)
# Calculated Edge Weight (2, 30)
# Calculated Edge Weight (2, 31)
# Calculated Edge Weight (2, 32)
# Calculated Edge Weight (2, 33)
# Calculated Edge Weight (2, 34)
# Calculated Edge Weight (2, 35)
# Calculated Edge Weight (2, 36)
# Calculated Edge Weight (2, 37)
# Calculated Edge Weight (2, 38)
# Calculated Edge Weight (2, 39)
# Calculated Edge Weight (2, 40)
# Calculated Edge Weight (2, 41)
# Calculated Edge Weight (2, 42)
# Calculated Edge Weight (2, 43)
# Calculated Edge Weight (2, 44)
# Calculated Edge Weight (2, 45)
# Calculated Edge Weight (2, 46)
# Calculated Edge Weight (3, 4)
# Calculated Edge Weight (3, 5)
# Calculated Edge Weight (3, 6)
# Calculated Edge Weight (3, 7)
# Calculated Edge Weight (3, 8)
# Calculated Edge Weight (3, 9)
# Calculated Edge Weight (3, 10)
# Calculated Edge Weight (3, 11)
# Calculated Edge Weight (3, 12)
# Calculated Edge Weight (3, 13)
# Calculated Edge Weight (3, 14)
# Calculated Edge Weight (3, 15)
# Calculated Edge Weight (3, 16)
# Calculated Edge Weight (3, 17)
# Calculated Edge Weight (3, 18)
# Calculated Edge Weight (3, 19)
# Calculated Edge Weight (3, 20)
# Calculated Edge Weight (3, 21)
# Calculated Edge Weight (3, 22)
# Calculated Edge Weight (3, 23)
# Calculated Edge Weight (3, 24)
# Calculated Edge Weight (3, 25)
# Calculated Edge Weight (3, 26)
# Calculated Edge Weight (3, 27)
# Calculated Edge Weight (3, 28)
# Calculated Edge Weight (3, 29)
# Calculated Edge Weight (3, 30)
# Calculated Edge Weight (3, 31)
# Calculated Edge Weight (3, 32)
# Calculated Edge Weight (3, 33)
# Calculated Edge Weight (3, 34)
# Calculated Edge Weight (3, 35)
# Calculated Edge Weight (3, 36)
# Calculated Edge Weight (3, 37)
# Calculated Edge Weight (3, 38)
# Calculated Edge Weight (3, 39)
# Calculated Edge Weight (3, 40)
# Calculated Edge Weight (3, 41)
# Calculated Edge Weight (3, 42)
# Calculated Edge Weight (3, 43)
# Calculated Edge Weight (3, 44)
# Calculated Edge Weight (3, 45)
# Calculated Edge Weight (3, 46)
# Calculated Edge Weight (4, 5)
# Calculated Edge Weight (4, 6)
# Calculated Edge Weight (4, 7)
# Calculated Edge Weight (4, 8)
# Calculated Edge Weight (4, 9)
# Calculated Edge Weight (4, 10)
# Calculated Edge Weight (4, 11)
# Calculated Edge Weight (4, 12)
# Calculated Edge Weight (4, 13)
# Calculated Edge Weight (4, 14)
# Calculated Edge Weight (4, 15)
# Calculated Edge Weight (4, 16)
# Calculated Edge Weight (4, 17)
# Calculated Edge Weight (4, 18)
# Calculated Edge Weight (4, 19)
# Calculated Edge Weight (4, 20)
# Calculated Edge Weight (4, 21)
# Calculated Edge Weight (4, 22)
# Calculated Edge Weight (4, 23)
# Calculated Edge Weight (4, 24)
# Calculated Edge Weight (4, 25)
# Calculated Edge Weight (4, 26)
# Calculated Edge Weight (4, 27)
# Calculated Edge Weight (4, 28)
# Calculated Edge Weight (4, 29)
# Calculated Edge Weight (4, 30)
# Calculated Edge Weight (4, 31)
# Calculated Edge Weight (4, 32)
# Calculated Edge Weight (4, 33)
# Calculated Edge Weight (4, 34)
# Calculated Edge Weight (4, 35)
# Calculated Edge Weight (4, 36)
# Calculated Edge Weight (4, 37)
# Calculated Edge Weight (4, 38)
# Calculated Edge Weight (4, 39)
# Calculated Edge Weight (4, 40)
# Calculated Edge Weight (4, 41)
# Calculated Edge Weight (4, 42)
# Calculated Edge Weight (4, 43)
# Calculated Edge Weight (4, 44)
# Calculated Edge Weight (4, 45)
# Calculated Edge Weight (4, 46)
# Calculated Edge Weight (5, 6)
# Calculated Edge Weight (5, 7)
# Calculated Edge Weight (5, 8)
# Calculated Edge Weight (5, 9)
# Calculated Edge Weight (5, 10)
# Calculated Edge Weight (5, 11)
# Calculated Edge Weight (5, 12)
# Calculated Edge Weight (5, 13)
# Calculated Edge Weight (5, 14)
# Calculated Edge Weight (5, 15)
# Calculated Edge Weight (5, 16)
# Calculated Edge Weight (5, 17)
# Calculated Edge Weight (5, 18)
# Calculated Edge Weight (5, 19)
# Calculated Edge Weight (5, 20)
# Calculated Edge Weight (5, 21)
# Calculated Edge Weight (5, 22)
# Calculated Edge Weight (5, 23)
# Calculated Edge Weight (5, 24)
# Calculated Edge Weight (5, 25)
# Calculated Edge Weight (5, 26)
# Calculated Edge Weight (5, 27)
# Calculated Edge Weight (5, 28)
# Calculated Edge Weight (5, 29)
# Calculated Edge Weight (5, 30)
# Calculated Edge Weight (5, 31)
# Calculated Edge Weight (5, 32)
# Calculated Edge Weight (5, 33)
# Calculated Edge Weight (5, 34)
# Calculated Edge Weight (5, 35)
# Calculated Edge Weight (5, 36)
# Calculated Edge Weight (5, 37)
# Calculated Edge Weight (5, 38)
# Calculated Edge Weight (5, 39)
# Calculated Edge Weight (5, 40)
# Calculated Edge Weight (5, 41)
# Calculated Edge Weight (5, 42)
# Calculated Edge Weight (5, 43)
# Calculated Edge Weight (5, 44)
# Calculated Edge Weight (5, 45)
# Calculated Edge Weight (5, 46)
# Calculated Edge Weight (6, 7)
# Calculated Edge Weight (6, 8)
# Calculated Edge Weight (6, 9)
# Calculated Edge Weight (6, 10)
# Calculated Edge Weight (6, 11)
# Calculated Edge Weight (6, 12)
# Calculated Edge Weight (6, 13)
# Calculated Edge Weight (6, 14)
# Calculated Edge Weight (6, 15)
# Calculated Edge Weight (6, 16)
# Calculated Edge Weight (6, 17)
# Calculated Edge Weight (6, 18)
# Calculated Edge Weight (6, 19)
# Calculated Edge Weight (6, 20)
# Calculated Edge Weight (6, 21)
# Calculated Edge Weight (6, 22)
# Calculated Edge Weight (6, 23)
# Calculated Edge Weight (6, 24)
# Calculated Edge Weight (6, 25)
# Calculated Edge Weight (6, 26)
# Calculated Edge Weight (6, 27)
# Calculated Edge Weight (6, 28)
# Calculated Edge Weight (6, 29)
# Calculated Edge Weight (6, 30)
# Calculated Edge Weight (6, 31)
# Calculated Edge Weight (6, 32)
# Calculated Edge Weight (6, 33)
# Calculated Edge Weight (6, 34)
# Calculated Edge Weight (6, 35)
# Calculated Edge Weight (6, 36)
# Calculated Edge Weight (6, 37)
# Calculated Edge Weight (6, 38)
# Calculated Edge Weight (6, 39)
# Calculated Edge Weight (6, 40)
# Calculated Edge Weight (6, 41)
# Calculated Edge Weight (6, 42)
# Calculated Edge Weight (6, 43)
# Calculated Edge Weight (6, 44)
# Calculated Edge Weight (6, 45)
# Calculated Edge Weight (6, 46)
# Calculated Edge Weight (7, 8)
# Calculated Edge Weight (7, 9)
# Calculated Edge Weight (7, 10)
# Calculated Edge Weight (7, 11)
# Calculated Edge Weight (7, 12)
# Calculated Edge Weight (7, 13)
# Calculated Edge Weight (7, 14)
# Calculated Edge Weight (7, 15)
# Calculated Edge Weight (7, 16)
# Calculated Edge Weight (7, 17)
# Calculated Edge Weight (7, 18)
# Calculated Edge Weight (7, 19)
# Calculated Edge Weight (7, 20)
# Calculated Edge Weight (7, 21)
# Calculated Edge Weight (7, 22)
# Calculated Edge Weight (7, 23)
# Calculated Edge Weight (7, 24)
# Calculated Edge Weight (7, 25)
# Calculated Edge Weight (7, 26)
# Calculated Edge Weight (7, 27)
# Calculated Edge Weight (7, 28)
# Calculated Edge Weight (7, 29)
# Calculated Edge Weight (7, 30)
# Calculated Edge Weight (7, 31)
# Calculated Edge Weight (7, 32)
# Calculated Edge Weight (7, 33)
# Calculated Edge Weight (7, 34)
# Calculated Edge Weight (7, 35)
# Calculated Edge Weight (7, 36)
# Calculated Edge Weight (7, 37)
# Calculated Edge Weight (7, 38)
# Calculated Edge Weight (7, 39)
# Calculated Edge Weight (7, 40)
# Calculated Edge Weight (7, 41)
# Calculated Edge Weight (7, 42)
# Calculated Edge Weight (7, 43)
# Calculated Edge Weight (7, 44)
# Calculated Edge Weight (7, 45)
# Calculated Edge Weight (7, 46)
# Calculated Edge Weight (8, 9)
# Calculated Edge Weight (8, 10)
# Calculated Edge Weight (8, 11)
# Calculated Edge Weight (8, 12)
# Calculated Edge Weight (8, 13)
# Calculated Edge Weight (8, 14)
# Calculated Edge Weight (8, 15)
# Calculated Edge Weight (8, 16)
# Calculated Edge Weight (8, 17)
# Calculated Edge Weight (8, 18)
# Calculated Edge Weight (8, 19)
# Calculated Edge Weight (8, 20)
# Calculated Edge Weight (8, 21)
# Calculated Edge Weight (8, 22)
# Calculated Edge Weight (8, 23)
# Calculated Edge Weight (8, 24)
# Calculated Edge Weight (8, 25)
# Calculated Edge Weight (8, 26)
# Calculated Edge Weight (8, 27)
# Calculated Edge Weight (8, 28)
# Calculated Edge Weight (8, 29)
# Calculated Edge Weight (8, 30)
# Calculated Edge Weight (8, 31)
# Calculated Edge Weight (8, 32)
# Calculated Edge Weight (8, 33)
# Calculated Edge Weight (8, 34)
# Calculated Edge Weight (8, 35)
# Calculated Edge Weight (8, 36)
# Calculated Edge Weight (8, 37)
# Calculated Edge Weight (8, 38)
# Calculated Edge Weight (8, 39)
# Calculated Edge Weight (8, 40)
# Calculated Edge Weight (8, 41)
# Calculated Edge Weight (8, 42)
# Calculated Edge Weight (8, 43)
# Calculated Edge Weight (8, 44)
# Calculated Edge Weight (8, 45)
# Calculated Edge Weight (8, 46)
# Calculated Edge Weight (9, 10)
# Calculated Edge Weight (9, 11)
# Calculated Edge Weight (9, 12)
# Calculated Edge Weight (9, 13)
# Calculated Edge Weight (9, 14)
# Calculated Edge Weight (9, 15)
# Calculated Edge Weight (9, 16)
# Calculated Edge Weight (9, 17)
# Calculated Edge Weight (9, 18)
# Calculated Edge Weight (9, 19)
# Calculated Edge Weight (9, 20)
# Calculated Edge Weight (9, 21)
# Calculated Edge Weight (9, 22)
# Calculated Edge Weight (9, 23)
# Calculated Edge Weight (9, 24)
# Calculated Edge Weight (9, 25)
# Calculated Edge Weight (9, 26)
# Calculated Edge Weight (9, 27)
# Calculated Edge Weight (9, 28)
# Calculated Edge Weight (9, 29)
# Calculated Edge Weight (9, 30)
# Calculated Edge Weight (9, 31)
# Calculated Edge Weight (9, 32)
# Calculated Edge Weight (9, 33)
# Calculated Edge Weight (9, 34)
# Calculated Edge Weight (9, 35)
# Calculated Edge Weight (9, 36)
# Calculated Edge Weight (9, 37)
# Calculated Edge Weight (9, 38)
# Calculated Edge Weight (9, 39)
# Calculated Edge Weight (9, 40)
# Calculated Edge Weight (9, 41)
# Calculated Edge Weight (9, 42)
# Calculated Edge Weight (9, 43)
# Calculated Edge Weight (9, 44)
# Calculated Edge Weight (9, 45)
# Calculated Edge Weight (9, 46)
# Calculated Edge Weight (10, 11)
# Calculated Edge Weight (10, 12)
# Calculated Edge Weight (10, 13)
# Calculated Edge Weight (10, 14)
# Calculated Edge Weight (10, 15)
# Calculated Edge Weight (10, 16)
# Calculated Edge Weight (10, 17)
# Calculated Edge Weight (10, 18)
# Calculated Edge Weight (10, 19)
# Calculated Edge Weight (10, 20)
# Calculated Edge Weight (10, 21)
# Calculated Edge Weight (10, 22)
# Calculated Edge Weight (10, 23)
# Calculated Edge Weight (10, 24)
# Calculated Edge Weight (10, 25)
# Calculated Edge Weight (10, 26)
# Calculated Edge Weight (10, 27)
# Calculated Edge Weight (10, 28)
# Calculated Edge Weight (10, 29)
# Calculated Edge Weight (10, 30)
# Calculated Edge Weight (10, 31)
# Calculated Edge Weight (10, 32)
# Calculated Edge Weight (10, 33)
# Calculated Edge Weight (10, 34)
# Calculated Edge Weight (10, 35)
# Calculated Edge Weight (10, 36)
# Calculated Edge Weight (10, 37)
# Calculated Edge Weight (10, 38)
# Calculated Edge Weight (10, 39)
# Calculated Edge Weight (10, 40)
# Calculated Edge Weight (10, 41)
# Calculated Edge Weight (10, 42)
# Calculated Edge Weight (10, 43)
# Calculated Edge Weight (10, 44)
# Calculated Edge Weight (10, 45)
# Calculated Edge Weight (10, 46)
# Calculated Edge Weight (11, 12)
# Calculated Edge Weight (11, 13)
# Calculated Edge Weight (11, 14)
# Calculated Edge Weight (11, 15)
# Calculated Edge Weight (11, 16)
# Calculated Edge Weight (11, 17)
# Calculated Edge Weight (11, 18)
# Calculated Edge Weight (11, 19)
# Calculated Edge Weight (11, 20)
# Calculated Edge Weight (11, 21)
# Calculated Edge Weight (11, 22)
# Calculated Edge Weight (11, 23)
# Calculated Edge Weight (11, 24)
# Calculated Edge Weight (11, 25)
# Calculated Edge Weight (11, 26)
# Calculated Edge Weight (11, 27)
# Calculated Edge Weight (11, 28)
# Calculated Edge Weight (11, 29)
# Calculated Edge Weight (11, 30)
# Calculated Edge Weight (11, 31)
# Calculated Edge Weight (11, 32)
# Calculated Edge Weight (11, 33)
# Calculated Edge Weight (11, 34)
# Calculated Edge Weight (11, 35)
# Calculated Edge Weight (11, 36)
# Calculated Edge Weight (11, 37)
# Calculated Edge Weight (11, 38)
# Calculated Edge Weight (11, 39)
# Calculated Edge Weight (11, 40)
# Calculated Edge Weight (11, 41)
# Calculated Edge Weight (11, 42)
# Calculated Edge Weight (11, 43)
# Calculated Edge Weight (11, 44)
# Calculated Edge Weight (11, 45)
# Calculated Edge Weight (11, 46)
# Calculated Edge Weight (12, 13)
# Calculated Edge Weight (12, 14)
# Calculated Edge Weight (12, 15)
# Calculated Edge Weight (12, 16)
# Calculated Edge Weight (12, 17)
# Calculated Edge Weight (12, 18)
# Calculated Edge Weight (12, 19)
# Calculated Edge Weight (12, 20)
# Calculated Edge Weight (12, 21)
# Calculated Edge Weight (12, 22)
# Calculated Edge Weight (12, 23)
# Calculated Edge Weight (12, 24)
# Calculated Edge Weight (12, 25)
# Calculated Edge Weight (12, 26)
# Calculated Edge Weight (12, 27)
# Calculated Edge Weight (12, 28)
# Calculated Edge Weight (12, 29)
# Calculated Edge Weight (12, 30)
# Calculated Edge Weight (12, 31)
# Calculated Edge Weight (12, 32)
# Calculated Edge Weight (12, 33)
# Calculated Edge Weight (12, 34)
# Calculated Edge Weight (12, 35)
# Calculated Edge Weight (12, 36)
# Calculated Edge Weight (12, 37)
# Calculated Edge Weight (12, 38)
# Calculated Edge Weight (12, 39)
# Calculated Edge Weight (12, 40)
# Calculated Edge Weight (12, 41)
# Calculated Edge Weight (12, 42)
# Calculated Edge Weight (12, 43)
# Calculated Edge Weight (12, 44)
# Calculated Edge Weight (12, 45)
# Calculated Edge Weight (12, 46)
# Calculated Edge Weight (13, 14)
# Calculated Edge Weight (13, 15)
# Calculated Edge Weight (13, 16)
# Calculated Edge Weight (13, 17)
# Calculated Edge Weight (13, 18)
# Calculated Edge Weight (13, 19)
# Calculated Edge Weight (13, 20)
# Calculated Edge Weight (13, 21)
# Calculated Edge Weight (13, 22)
# Calculated Edge Weight (13, 23)
# Calculated Edge Weight (13, 24)
# Calculated Edge Weight (13, 25)
# Calculated Edge Weight (13, 26)
# Calculated Edge Weight (13, 27)
# Calculated Edge Weight (13, 28)
# Calculated Edge Weight (13, 29)
# Calculated Edge Weight (13, 30)
# Calculated Edge Weight (13, 31)
# Calculated Edge Weight (13, 32)
# Calculated Edge Weight (13, 33)
# Calculated Edge Weight (13, 34)
# Calculated Edge Weight (13, 35)
# Calculated Edge Weight (13, 36)
# Calculated Edge Weight (13, 37)
# Calculated Edge Weight (13, 38)
# Calculated Edge Weight (13, 39)
# Calculated Edge Weight (13, 40)
# Calculated Edge Weight (13, 41)
# Calculated Edge Weight (13, 42)
# Calculated Edge Weight (13, 43)
# Calculated Edge Weight (13, 44)
# Calculated Edge Weight (13, 45)
# Calculated Edge Weight (13, 46)
# Calculated Edge Weight (14, 15)
# Calculated Edge Weight (14, 16)
# Calculated Edge Weight (14, 17)
# Calculated Edge Weight (14, 18)
# Calculated Edge Weight (14, 19)
# Calculated Edge Weight (14, 20)
# Calculated Edge Weight (14, 21)
# Calculated Edge Weight (14, 22)
# Calculated Edge Weight (14, 23)
# Calculated Edge Weight (14, 24)
# Calculated Edge Weight (14, 25)
# Calculated Edge Weight (14, 26)
# Calculated Edge Weight (14, 27)
# Calculated Edge Weight (14, 28)
# Calculated Edge Weight (14, 29)
# Calculated Edge Weight (14, 30)
# Calculated Edge Weight (14, 31)
# Calculated Edge Weight (14, 32)
# Calculated Edge Weight (14, 33)
# Calculated Edge Weight (14, 34)
# Calculated Edge Weight (14, 35)
# Calculated Edge Weight (14, 36)
# Calculated Edge Weight (14, 37)
# Calculated Edge Weight (14, 38)
# Calculated Edge Weight (14, 39)
# Calculated Edge Weight (14, 40)
# Calculated Edge Weight (14, 41)
# Calculated Edge Weight (14, 42)
# Calculated Edge Weight (14, 43)
# Calculated Edge Weight (14, 44)
# Calculated Edge Weight (14, 45)
# Calculated Edge Weight (14, 46)
# Calculated Edge Weight (15, 16)
# Calculated Edge Weight (15, 17)
# Calculated Edge Weight (15, 18)
# Calculated Edge Weight (15, 19)
# Calculated Edge Weight (15, 20)
# Calculated Edge Weight (15, 21)
# Calculated Edge Weight (15, 22)
# Calculated Edge Weight (15, 23)
# Calculated Edge Weight (15, 24)
# Calculated Edge Weight (15, 25)
# Calculated Edge Weight (15, 26)
# Calculated Edge Weight (15, 27)
# Calculated Edge Weight (15, 28)
# Calculated Edge Weight (15, 29)
# Calculated Edge Weight (15, 30)
# Calculated Edge Weight (15, 31)
# Calculated Edge Weight (15, 32)
# Calculated Edge Weight (15, 33)
# Calculated Edge Weight (15, 34)
# Calculated Edge Weight (15, 35)
# Calculated Edge Weight (15, 36)
# Calculated Edge Weight (15, 37)
# Calculated Edge Weight (15, 38)
# Calculated Edge Weight (15, 39)
# Calculated Edge Weight (15, 40)
# Calculated Edge Weight (15, 41)
# Calculated Edge Weight (15, 42)
# Calculated Edge Weight (15, 43)
# Calculated Edge Weight (15, 44)
# Calculated Edge Weight (15, 45)
# Calculated Edge Weight (15, 46)
# Calculated Edge Weight (16, 17)
# Calculated Edge Weight (16, 18)
# Calculated Edge Weight (16, 19)
# Calculated Edge Weight (16, 20)
# Calculated Edge Weight (16, 21)
# Calculated Edge Weight (16, 22)
# Calculated Edge Weight (16, 23)
# Calculated Edge Weight (16, 24)
# Calculated Edge Weight (16, 25)
# Calculated Edge Weight (16, 26)
# Calculated Edge Weight (16, 27)
# Calculated Edge Weight (16, 28)
# Calculated Edge Weight (16, 29)
# Calculated Edge Weight (16, 30)
# Calculated Edge Weight (16, 31)
# Calculated Edge Weight (16, 32)
# Calculated Edge Weight (16, 33)
# Calculated Edge Weight (16, 34)
# Calculated Edge Weight (16, 35)
# Calculated Edge Weight (16, 36)
# Calculated Edge Weight (16, 37)
# Calculated Edge Weight (16, 38)
# Calculated Edge Weight (16, 39)
# Calculated Edge Weight (16, 40)
# Calculated Edge Weight (16, 41)
# Calculated Edge Weight (16, 42)
# Calculated Edge Weight (16, 43)
# Calculated Edge Weight (16, 44)
# Calculated Edge Weight (16, 45)
# Calculated Edge Weight (16, 46)
# Calculated Edge Weight (17, 18)
# Calculated Edge Weight (17, 19)
# Calculated Edge Weight (17, 20)
# Calculated Edge Weight (17, 21)
# Calculated Edge Weight (17, 22)
# Calculated Edge Weight (17, 23)
# Calculated Edge Weight (17, 24)
# Calculated Edge Weight (17, 25)
# Calculated Edge Weight (17, 26)
# Calculated Edge Weight (17, 27)
# Calculated Edge Weight (17, 28)
# Calculated Edge Weight (17, 29)
# Calculated Edge Weight (17, 30)
# Calculated Edge Weight (17, 31)
# Calculated Edge Weight (17, 32)
# Calculated Edge Weight (17, 33)
# Calculated Edge Weight (17, 34)
# Calculated Edge Weight (17, 35)
# Calculated Edge Weight (17, 36)
# Calculated Edge Weight (17, 37)
# Calculated Edge Weight (17, 38)
# Calculated Edge Weight (17, 39)
# Calculated Edge Weight (17, 40)
# Calculated Edge Weight (17, 41)
# Calculated Edge Weight (17, 42)
# Calculated Edge Weight (17, 43)
# Calculated Edge Weight (17, 44)
# Calculated Edge Weight (17, 45)
# Calculated Edge Weight (17, 46)
# Calculated Edge Weight (18, 19)
# Calculated Edge Weight (18, 20)
# Calculated Edge Weight (18, 21)
# Calculated Edge Weight (18, 22)
# Calculated Edge Weight (18, 23)
# Calculated Edge Weight (18, 24)
# Calculated Edge Weight (18, 25)
# Calculated Edge Weight (18, 26)
# Calculated Edge Weight (18, 27)
# Calculated Edge Weight (18, 28)
# Calculated Edge Weight (18, 29)
# Calculated Edge Weight (18, 30)
# Calculated Edge Weight (18, 31)
# Calculated Edge Weight (18, 32)
# Calculated Edge Weight (18, 33)
# Calculated Edge Weight (18, 34)
# Calculated Edge Weight (18, 35)
# Calculated Edge Weight (18, 36)
# Calculated Edge Weight (18, 37)
# Calculated Edge Weight (18, 38)
# Calculated Edge Weight (18, 39)
# Calculated Edge Weight (18, 40)
# Calculated Edge Weight (18, 41)
# Calculated Edge Weight (18, 42)
# Calculated Edge Weight (18, 43)
# Calculated Edge Weight (18, 44)
# Calculated Edge Weight (18, 45)
# Calculated Edge Weight (18, 46)
# Calculated Edge Weight (19, 20)
# Calculated Edge Weight (19, 21)
# Calculated Edge Weight (19, 22)
# Calculated Edge Weight (19, 23)
# Calculated Edge Weight (19, 24)
# Calculated Edge Weight (19, 25)
# Calculated Edge Weight (19, 26)
# Calculated Edge Weight (19, 27)
# Calculated Edge Weight (19, 28)
# Calculated Edge Weight (19, 29)
# Calculated Edge Weight (19, 30)
# Calculated Edge Weight (19, 31)
# Calculated Edge Weight (19, 32)
# Calculated Edge Weight (19, 33)
# Calculated Edge Weight (19, 34)
# Calculated Edge Weight (19, 35)
# Calculated Edge Weight (19, 36)
# Calculated Edge Weight (19, 37)
# Calculated Edge Weight (19, 38)
# Calculated Edge Weight (19, 39)
# Calculated Edge Weight (19, 40)
# Calculated Edge Weight (19, 41)
# Calculated Edge Weight (19, 42)
# Calculated Edge Weight (19, 43)
# Calculated Edge Weight (19, 44)
# Calculated Edge Weight (19, 45)
# Calculated Edge Weight (19, 46)
# Calculated Edge Weight (20, 21)
# Calculated Edge Weight (20, 22)
# Calculated Edge Weight (20, 23)
# Calculated Edge Weight (20, 24)
# Calculated Edge Weight (20, 25)
# Calculated Edge Weight (20, 26)
# Calculated Edge Weight (20, 27)
# Calculated Edge Weight (20, 28)
# Calculated Edge Weight (20, 29)
# Calculated Edge Weight (20, 30)
# Calculated Edge Weight (20, 31)
# Calculated Edge Weight (20, 32)
# Calculated Edge Weight (20, 33)
# Calculated Edge Weight (20, 34)
# Calculated Edge Weight (20, 35)
# Calculated Edge Weight (20, 36)
# Calculated Edge Weight (20, 37)
# Calculated Edge Weight (20, 38)
# Calculated Edge Weight (20, 39)
# Calculated Edge Weight (20, 40)
# Calculated Edge Weight (20, 41)
# Calculated Edge Weight (20, 42)
# Calculated Edge Weight (20, 43)
# Calculated Edge Weight (20, 44)
# Calculated Edge Weight (20, 45)
# Calculated Edge Weight (20, 46)
# Calculated Edge Weight (21, 22)
# Calculated Edge Weight (21, 23)
# Calculated Edge Weight (21, 24)
# Calculated Edge Weight (21, 25)
# Calculated Edge Weight (21, 26)
# Calculated Edge Weight (21, 27)
# Calculated Edge Weight (21, 28)
# Calculated Edge Weight (21, 29)
# Calculated Edge Weight (21, 30)
# Calculated Edge Weight (21, 31)
# Calculated Edge Weight (21, 32)
# Calculated Edge Weight (21, 33)
# Calculated Edge Weight (21, 34)
# Calculated Edge Weight (21, 35)
# Calculated Edge Weight (21, 36)
# Calculated Edge Weight (21, 37)
# Calculated Edge Weight (21, 38)
# Calculated Edge Weight (21, 39)
# Calculated Edge Weight (21, 40)
# Calculated Edge Weight (21, 41)
# Calculated Edge Weight (21, 42)
# Calculated Edge Weight (21, 43)
# Calculated Edge Weight (21, 44)
# Calculated Edge Weight (21, 45)
# Calculated Edge Weight (21, 46)
# Calculated Edge Weight (22, 23)
# Calculated Edge Weight (22, 24)
# Calculated Edge Weight (22, 25)
# Calculated Edge Weight (22, 26)
# Calculated Edge Weight (22, 27)
# Calculated Edge Weight (22, 28)
# Calculated Edge Weight (22, 29)
# Calculated Edge Weight (22, 30)
# Calculated Edge Weight (22, 31)
# Calculated Edge Weight (22, 32)
# Calculated Edge Weight (22, 33)
# Calculated Edge Weight (22, 34)
# Calculated Edge Weight (22, 35)
# Calculated Edge Weight (22, 36)
# Calculated Edge Weight (22, 37)
# Calculated Edge Weight (22, 38)
# Calculated Edge Weight (22, 39)
# Calculated Edge Weight (22, 40)
# Calculated Edge Weight (22, 41)
# Calculated Edge Weight (22, 42)
# Calculated Edge Weight (22, 43)
# Calculated Edge Weight (22, 44)
# Calculated Edge Weight (22, 45)
# Calculated Edge Weight (22, 46)
# Calculated Edge Weight (23, 24)
# Calculated Edge Weight (23, 25)
# Calculated Edge Weight (23, 26)
# Calculated Edge Weight (23, 27)
# Calculated Edge Weight (23, 28)
# Calculated Edge Weight (23, 29)
# Calculated Edge Weight (23, 30)
# Calculated Edge Weight (23, 31)
# Calculated Edge Weight (23, 32)
# Calculated Edge Weight (23, 33)
# Calculated Edge Weight (23, 34)
# Calculated Edge Weight (23, 35)
# Calculated Edge Weight (23, 36)
# Calculated Edge Weight (23, 37)
# Calculated Edge Weight (23, 38)
# Calculated Edge Weight (23, 39)
# Calculated Edge Weight (23, 40)
# Calculated Edge Weight (23, 41)
# Calculated Edge Weight (23, 42)
# Calculated Edge Weight (23, 43)
# Calculated Edge Weight (23, 44)
# Calculated Edge Weight (23, 45)
# Calculated Edge Weight (23, 46)
# Calculated Edge Weight (24, 25)
# Calculated Edge Weight (24, 26)
# Calculated Edge Weight (24, 27)
# Calculated Edge Weight (24, 28)
# Calculated Edge Weight (24, 29)
# Calculated Edge Weight (24, 30)
# Calculated Edge Weight (24, 31)
# Calculated Edge Weight (24, 32)
# Calculated Edge Weight (24, 33)
# Calculated Edge Weight (24, 34)
# Calculated Edge Weight (24, 35)
# Calculated Edge Weight (24, 36)
# Calculated Edge Weight (24, 37)
# Calculated Edge Weight (24, 38)
# Calculated Edge Weight (24, 39)
# Calculated Edge Weight (24, 40)
# Calculated Edge Weight (24, 41)
# Calculated Edge Weight (24, 42)
# Calculated Edge Weight (24, 43)
# Calculated Edge Weight (24, 44)
# Calculated Edge Weight (24, 45)
# Calculated Edge Weight (24, 46)
# Calculated Edge Weight (25, 26)
# Calculated Edge Weight (25, 27)
# Calculated Edge Weight (25, 28)
# Calculated Edge Weight (25, 29)
# Calculated Edge Weight (25, 30)
# Calculated Edge Weight (25, 31)
# Calculated Edge Weight (25, 32)
# Calculated Edge Weight (25, 33)
# Calculated Edge Weight (25, 34)
# Calculated Edge Weight (25, 35)
# Calculated Edge Weight (25, 36)
# Calculated Edge Weight (25, 37)
# Calculated Edge Weight (25, 38)
# Calculated Edge Weight (25, 39)
# Calculated Edge Weight (25, 40)
# Calculated Edge Weight (25, 41)
# Calculated Edge Weight (25, 42)
# Calculated Edge Weight (25, 43)
# Calculated Edge Weight (25, 44)
# Calculated Edge Weight (25, 45)
# Calculated Edge Weight (25, 46)
# Calculated Edge Weight (26, 27)
# Calculated Edge Weight (26, 28)
# Calculated Edge Weight (26, 29)
# Calculated Edge Weight (26, 30)
# Calculated Edge Weight (26, 31)
# Calculated Edge Weight (26, 32)
# Calculated Edge Weight (26, 33)
# Calculated Edge Weight (26, 34)
# Calculated Edge Weight (26, 35)
# Calculated Edge Weight (26, 36)
# Calculated Edge Weight (26, 37)
# Calculated Edge Weight (26, 38)
# Calculated Edge Weight (26, 39)
# Calculated Edge Weight (26, 40)
# Calculated Edge Weight (26, 41)
# Calculated Edge Weight (26, 42)
# Calculated Edge Weight (26, 43)
# Calculated Edge Weight (26, 44)
# Calculated Edge Weight (26, 45)
# Calculated Edge Weight (26, 46)
# Calculated Edge Weight (27, 28)
# Calculated Edge Weight (27, 29)
# Calculated Edge Weight (27, 30)
# Calculated Edge Weight (27, 31)
# Calculated Edge Weight (27, 32)
# Calculated Edge Weight (27, 33)
# Calculated Edge Weight (27, 34)
# Calculated Edge Weight (27, 35)
# Calculated Edge Weight (27, 36)
# Calculated Edge Weight (27, 37)
# Calculated Edge Weight (27, 38)
# Calculated Edge Weight (27, 39)
# Calculated Edge Weight (27, 40)
# Calculated Edge Weight (27, 41)
# Calculated Edge Weight (27, 42)
# Calculated Edge Weight (27, 43)
# Calculated Edge Weight (27, 44)
# Calculated Edge Weight (27, 45)
# Calculated Edge Weight (27, 46)
# Calculated Edge Weight (28, 29)
# Calculated Edge Weight (28, 30)
# Calculated Edge Weight (28, 31)
# Calculated Edge Weight (28, 32)
# Calculated Edge Weight (28, 33)
# Calculated Edge Weight (28, 34)
# Calculated Edge Weight (28, 35)
# Calculated Edge Weight (28, 36)
# Calculated Edge Weight (28, 37)
# Calculated Edge Weight (28, 38)
# Calculated Edge Weight (28, 39)
# Calculated Edge Weight (28, 40)
# Calculated Edge Weight (28, 41)
# Calculated Edge Weight (28, 42)
# Calculated Edge Weight (28, 43)
# Calculated Edge Weight (28, 44)
# Calculated Edge Weight (28, 45)
# Calculated Edge Weight (28, 46)
# Calculated Edge Weight (29, 30)
# Calculated Edge Weight (29, 31)
# Calculated Edge Weight (29, 32)
# Calculated Edge Weight (29, 33)
# Calculated Edge Weight (29, 34)
# Calculated Edge Weight (29, 35)
# Calculated Edge Weight (29, 36)
# Calculated Edge Weight (29, 37)
# Calculated Edge Weight (29, 38)
# Calculated Edge Weight (29, 39)
# Calculated Edge Weight (29, 40)
# Calculated Edge Weight (29, 41)
# Calculated Edge Weight (29, 42)
# Calculated Edge Weight (29, 43)
# Calculated Edge Weight (29, 44)
# Calculated Edge Weight (29, 45)
# Calculated Edge Weight (29, 46)
# Calculated Edge Weight (30, 31)
# Calculated Edge Weight (30, 32)
# Calculated Edge Weight (30, 33)
# Calculated Edge Weight (30, 34)
# Calculated Edge Weight (30, 35)
# Calculated Edge Weight (30, 36)
# Calculated Edge Weight (30, 37)
# Calculated Edge Weight (30, 38)
# Calculated Edge Weight (30, 39)
# Calculated Edge Weight (30, 40)
# Calculated Edge Weight (30, 41)
# Calculated Edge Weight (30, 42)
# Calculated Edge Weight (30, 43)
# Calculated Edge Weight (30, 44)
# Calculated Edge Weight (30, 45)
# Calculated Edge Weight (30, 46)
# Calculated Edge Weight (31, 32)
# Calculated Edge Weight (31, 33)
# Calculated Edge Weight (31, 34)
# Calculated Edge Weight (31, 35)
# Calculated Edge Weight (31, 36)
# Calculated Edge Weight (31, 37)
# Calculated Edge Weight (31, 38)
# Calculated Edge Weight (31, 39)
# Calculated Edge Weight (31, 40)
# Calculated Edge Weight (31, 41)
# Calculated Edge Weight (31, 42)
# Calculated Edge Weight (31, 43)
# Calculated Edge Weight (31, 44)
# Calculated Edge Weight (31, 45)
# Calculated Edge Weight (31, 46)
# Calculated Edge Weight (32, 33)
# Calculated Edge Weight (32, 34)
# Calculated Edge Weight (32, 35)
# Calculated Edge Weight (32, 36)
# Calculated Edge Weight (32, 37)
# Calculated Edge Weight (32, 38)
# Calculated Edge Weight (32, 39)
# Calculated Edge Weight (32, 40)
# Calculated Edge Weight (32, 41)
# Calculated Edge Weight (32, 42)
# Calculated Edge Weight (32, 43)
# Calculated Edge Weight (32, 44)
# Calculated Edge Weight (32, 45)
# Calculated Edge Weight (32, 46)
# Calculated Edge Weight (33, 34)
# Calculated Edge Weight (33, 35)
# Calculated Edge Weight (33, 36)
# Calculated Edge Weight (33, 37)
# Calculated Edge Weight (33, 38)
# Calculated Edge Weight (33, 39)
# Calculated Edge Weight (33, 40)
# Calculated Edge Weight (33, 41)
# Calculated Edge Weight (33, 42)
# Calculated Edge Weight (33, 43)
# Calculated Edge Weight (33, 44)
# Calculated Edge Weight (33, 45)
# Calculated Edge Weight (33, 46)
# Calculated Edge Weight (34, 35)
# Calculated Edge Weight (34, 36)
# Calculated Edge Weight (34, 37)
# Calculated Edge Weight (34, 38)
# Calculated Edge Weight (34, 39)
# Calculated Edge Weight (34, 40)
# Calculated Edge Weight (34, 41)
# Calculated Edge Weight (34, 42)
# Calculated Edge Weight (34, 43)
# Calculated Edge Weight (34, 44)
# Calculated Edge Weight (34, 45)
# Calculated Edge Weight (34, 46)
# Calculated Edge Weight (35, 36)
# Calculated Edge Weight (35, 37)
# Calculated Edge Weight (35, 38)
# Calculated Edge Weight (35, 39)
# Calculated Edge Weight (35, 40)
# Calculated Edge Weight (35, 41)
# Calculated Edge Weight (35, 42)
# Calculated Edge Weight (35, 43)
# Calculated Edge Weight (35, 44)
# Calculated Edge Weight (35, 45)
# Calculated Edge Weight (35, 46)
# Calculated Edge Weight (36, 37)
# Calculated Edge Weight (36, 38)
# Calculated Edge Weight (36, 39)
# Calculated Edge Weight (36, 40)
# Calculated Edge Weight (36, 41)
# Calculated Edge Weight (36, 42)
# Calculated Edge Weight (36, 43)
# Calculated Edge Weight (36, 44)
# Calculated Edge Weight (36, 45)
# Calculated Edge Weight (36, 46)
# Calculated Edge Weight (37, 38)
# Calculated Edge Weight (37, 39)
# Calculated Edge Weight (37, 40)
# Calculated Edge Weight (37, 41)
# Calculated Edge Weight (37, 42)
# Calculated Edge Weight (37, 43)
# Calculated Edge Weight (37, 44)
# Calculated Edge Weight (37, 45)
# Calculated Edge Weight (37, 46)
# Calculated Edge Weight (38, 39)
# Calculated Edge Weight (38, 40)
# Calculated Edge Weight (38, 41)
# Calculated Edge Weight (38, 42)
# Calculated Edge Weight (38, 43)
# Calculated Edge Weight (38, 44)
# Calculated Edge Weight (38, 45)
# Calculated Edge Weight (38, 46)
# Calculated Edge Weight (39, 40)
# Calculated Edge Weight (39, 41)
# Calculated Edge Weight (39, 42)
# Calculated Edge Weight (39, 43)
# Calculated Edge Weight (39, 44)
# Calculated Edge Weight (39, 45)
# Calculated Edge Weight (39, 46)
# Calculated Edge Weight (40, 41)
# Calculated Edge Weight (40, 42)
# Calculated Edge Weight (40, 43)
# Calculated Edge Weight (40, 44)
# Calculated Edge Weight (40, 45)
# Calculated Edge Weight (40, 46)
# Calculated Edge Weight (41, 42)
# Calculated Edge Weight (41, 43)
# Calculated Edge Weight (41, 44)
# Calculated Edge Weight (41, 45)
# Calculated Edge Weight (41, 46)
# Calculated Edge Weight (42, 43)
# Calculated Edge Weight (42, 44)
# Calculated Edge Weight (42, 45)
# Calculated Edge Weight (42, 46)
# Calculated Edge Weight (43, 44)
# Calculated Edge Weight (43, 45)
# Calculated Edge Weight (43, 46)
# Calculated Edge Weight (44, 45)
# Calculated Edge Weight (44, 46)
# Calculated Edge Weight (45, 46)

# %% [markdown]
# ## Trying to find ways to validate "Graph Identity"
#
# besides average dtw distance Im trying to see if I can make something of a graph "silhouette score".
#
# Basically get the communities in the graph then calculate the following:
#
# * homogeneity: intra-cluster distance
#
# * heterogeneity: inter-cluster distance
#
# * "Graph Silhoette Score:" $\frac{Heterogeneity - Homogeneity} {max(Hetero, Homo)}$
#
# Also might take a look at clustering coefficients

# %%
# graph metrics function
def graph_metrics(graph: nx.classes.graph.Graph, distance_matrix: np.array,
                  seed: int):
  avg_dtw_distance = distance_matrix.mean()
  avg_clustering_coef = nx.average_clustering(graph)

  communities = nx.community.louvain_communities(graph, seed)

  silhouette_scores = []
  for cluster in communities:
    for i in cluster:
      cluster_distances = distance_matrix[i, list(cluster - {i})]
      homogeneity = np.mean(cluster_distances)
      other_cluster_distances = [np.mean(distance_matrix[i, list(other_cluster)]) for other_cluster in communities if other_cluster != cluster]
      heterogeneity = min(other_cluster_distances) if other_cluster_distances else homogeneity
      silhouette_score = (heterogeneity - homogeneity) / max(heterogeneity, homogeneity)
      silhouette_scores.append(silhouette_score)

  # Average silhouette score for all nodes
  average_silhouette_score = np.mean(silhouette_scores)

  conductance_scores = []
  for cluster in communities:
    cluster_conductance = conductance(graph, cluster)
    conductance_scores.append(cluster_conductance)

  average_conductance = np.mean(conductance_scores)

  print("Average DTW Distance:", avg_dtw_distance)
  print("Average Clustering Coefficient:", avg_clustering_coef)
  print("Average Silhouette Score", average_silhouette_score)
  print("Average Conductance:", average_conductance)

# %%
# show graph metrics and segment data
graph_metrics(graph, distance_matrix, 42)
print(f"Graph Length: {len(graph)}")

for node in graph.nodes(data=True):
  node_id = node[0]
  segment_data = node[1]['segment']
  print(f"Node {node_id} segment data:")
  print(segment_data)
# Out:
# Average DTW Distance: 349.9931871998737
# Average Clustering Coefficient: 0.6603988210371189
# Average Silhouette Score 0.37030400367086674
# Average Conductance: 0.09654807742588918
# Graph Length: 47
# Node 0 segment data:
#    onset_beats duration_beats  midi_pitch
# 0          0.0            0.5         0.0
# 1          0.5           0.25        67.0
# 2         0.75           0.25        72.0
# 3          1.0           0.25        76.0
# 4         1.25           0.25        67.0
# 5          1.5           0.25        72.0
# 6         1.75           0.25        76.0
# 7          2.0            0.5         0.0
# 8          2.5           0.25        67.0
# 9         2.75           0.25        72.0
# 10         3.0           0.25        76.0
# 11        3.25           0.25        67.0
# 12         3.5           0.25        72.0
# 13        3.75           0.25        76.0
# 14         4.0            0.5         0.0
# 15         4.5           0.25        69.0
# 16        4.75           0.25        74.0
# 17         5.0           0.25        77.0
# Node 1 segment data:
#    onset_beats duration_beats  midi_pitch
# 18        5.25           0.25        69.0
# 19         5.5           0.25        74.0
# 20        5.75           0.25        77.0
# 21         6.0            0.5         0.0
# 22         6.5           0.25        69.0
# 23        6.75           0.25        74.0
# 24         7.0           0.25        77.0
# 25        7.25           0.25        69.0
# 26         7.5           0.25        74.0
# 27        7.75           0.25        77.0
# Node 2 segment data:
#    onset_beats duration_beats  midi_pitch
# 28         8.0            0.5         0.0
# 29         8.5           0.25        67.0
# 30        8.75           0.25        74.0
# 31         9.0           0.25        77.0
# 32        9.25           0.25        67.0
# 33         9.5           0.25        74.0
# 34        9.75           0.25        77.0
# 35        10.0            0.5         0.0
# 36        10.5           0.25        67.0
# 37       10.75           0.25        74.0
# 38        11.0           0.25        77.0
# 39       11.25           0.25        67.0
# 40        11.5           0.25        74.0
# 41       11.75           0.25        77.0
# Node 3 segment data:
#    onset_beats duration_beats  midi_pitch
# 42        12.0            0.5         0.0
# 43        12.5           0.25        67.0
# 44       12.75           0.25        72.0
# 45        13.0           0.25        76.0
# 46       13.25           0.25        67.0
# 47        13.5           0.25        72.0
# 532       177.5           0.25         0.0
# 533      177.75           0.25         0.0
# 534       178.0           0.25         0.0
# 535      178.25            0.5         0.0
# 536      178.75           0.75         0.0
# 537       179.5            0.5         0.0
# 538       180.0           0.75         0.0
# 539      180.75           0.25         0.0
# 540       181.0           0.75         0.0
# 541      181.75           0.25         0.0
# 542       182.0            1.0         0.0
# 543       183.0            0.5         0.0
# 544       183.5            0.5         0.0
# 545       184.0            0.5         0.0
# 546       184.5            0.5         0.0
# 547       185.0           1.75         0.0
# 548      186.75           0.25         0.0
# 549       187.0            1.0         0.0
# 550       188.0            0.5         0.0
# 551       188.5            2.0         0.0
# 552       190.5            0.5         0.0
# 553       191.0            1.0         0.0
# 554       192.0            1.5         0.0
# Node 26 segment data:
#     onset_beats duration_beats  midi_pitch
# 555       193.5            0.5         0.0
# 556       194.0           0.75         0.0
# 557      194.75           0.25         0.0
# 558       195.0            1.0         0.0
# 559       196.0            0.5         0.0
# 560       196.5           0.75         0.0
# 561      197.25            0.5         0.0
# 562      197.75           0.25         0.0
# 563       198.0            1.5         0.0
# Node 27 segment data:
#     onset_beats duration_beats  midi_pitch
# 564       199.5            0.5         0.0
# 565       200.0           0.75         0.0
# 566      200.75           0.25         0.0
# 567       201.0            0.5         0.0
# 568       201.5           1.25         0.0
# 569      202.75           0.25         0.0
# 570       203.0           0.75         0.0
# 571      203.75           0.25         0.0
# 572       204.0            0.5         0.0
# 573       204.5            2.0         0.0
# 574       206.5            0.5         0.0
# 575       207.0            1.0         0.0
# 576       208.0            1.0         0.0
# 577       209.0            0.5         0.0
# 578       209.5            0.5         0.0
# 579       210.0            1.5         0.0
# 580       211.5            0.5         0.0
# 581       212.0           0.75         0.0
# 582      212.75           2.25         0.0
# Node 28 segment data:
#     onset_beats duration_beats  midi_pitch
# 583       215.0            1.0         0.0
# 584       216.0           1.25         0.0
# 585      217.25           0.25         0.0
# 586       217.5            1.0         0.0
# 587       218.5            0.5         0.0
# 588       219.0            1.0         0.0
# 589       220.0           0.75         0.0
# 590      220.75           0.25         0.0
# 591       221.0            1.0         0.0
# 592       222.0            0.5         0.0
# 593       222.5            1.5         0.0
# Node 29 segment data:
#     onset_beats duration_beats  midi_pitch
# 594       224.0            0.5         0.0
# 595       224.5            0.5         0.0
# 596       225.0            0.5         0.0
# 597       225.5            2.0         0.0
# 598       227.5            0.5         0.0
# 599       228.0            2.0         0.0
# 600       230.0            0.5         0.0
# 601       230.5            1.5         0.0
# 602       232.0            2.5         0.0
# Node 30 segment data:
#     onset_beats duration_beats  midi_pitch
# 603       234.5           0.25         0.0
# 604      234.75           0.25         0.0
# 605       235.0            1.0         0.0
# 606       236.0            0.5         0.0
# 607       236.5           0.25         0.0
# 608      236.75           0.25         0.0
# 609       237.0           1.25         0.0
# 610      238.25           1.75         0.0
# 611       240.0            2/3         0.0
# 612       722/3            2/3         0.0
# 613       724/3            2/3         0.0
# 614       242.0           0.25         0.0
# 615      242.25           0.25         0.0
# 616       242.5           1.25         0.0
# 617      243.75           0.25         0.0
# 618       244.0            1.0         0.0
# 619       245.0           0.25         0.0
# 620      245.25            0.5         0.0
# 621      245.75           2.25         0.0
# 622         0.0            2.0        60.0
# Node 31 segment data:
#     onset_beats duration_beats  midi_pitch
# 623        0.25           1.75        64.0
# 624         2.0            2.0        60.0
# 625        2.25           1.75        64.0
# 626         4.0            2.0        60.0
# 627        4.25           1.75        62.0
# Node 32 segment data:
#     onset_beats duration_beats  midi_pitch
# 628         6.0            2.0        60.0
# 629        6.25           1.75        62.0
# 630         8.0            2.0        59.0
# 631        8.25           1.75        62.0
# 632        10.0            2.0        59.0
# 633       10.25           1.75        62.0
# Node 33 segment data:
#     onset_beats duration_beats  midi_pitch
# 634        12.0            2.0        60.0
# 635       12.25           1.75        64.0
# 636        14.0            2.0        60.0
# 637       14.25           1.75        64.0
# 638        16.0            2.0        60.0
# 639       16.25           1.75        64.0
# 640        18.0            2.0        60.0
# 641       18.25           1.75        64.0
# 642        20.0            2.0        60.0
# 643       20.25           1.75        62.0
# 644        22.0            2.0        60.0
# 645       22.25           1.75        62.0
# 646        24.0            2.0        59.0
# 647       24.25           1.75        62.0
# 648        26.0            2.0        59.0
# 649       26.25           1.75        62.0
# 650        28.0            2.0        59.0
# 651       28.25           1.75        60.0
# Node 34 segment data:
#     onset_beats duration_beats  midi_pitch
# 652        30.0            2.0        59.0
# 653       30.25           1.75        60.0
# 654        32.0            2.0        57.0
# 655       32.25           1.75        60.0
# 656        34.0            2.0        57.0
# 657       34.25           1.75        60.0
# Node 35 segment data:
#     onset_beats duration_beats  midi_pitch
# 658        36.0            2.0        50.0
# 659       36.25           1.75        57.0
# 660        38.0            2.0        50.0
# 661       38.25           1.75        57.0
# 662        40.0            2.0        55.0
# 663       40.25           1.75        59.0
# Node 36 segment data:
#     onset_beats duration_beats  midi_pitch
# 664        42.0            2.0        55.0
# 665       42.25           1.75        59.0
# 666        44.0            2.0        55.0
# 667       44.25           1.75        58.0
# 668        46.0            2.0        55.0
# 669       46.25           1.75        58.0
# Node 37 segment data:
#     onset_beats duration_beats  midi_pitch
# 670        48.0            2.0        53.0
# 671       48.25           1.75        57.0
# 672        50.0            2.0        53.0
# 673       50.25           1.75        57.0
# 674        52.0            2.0        53.0
# 675       52.25           1.75        56.0
# 676        54.0            2.0        53.0
# 677       54.25           1.75        56.0
# Node 38 segment data:
#     onset_beats duration_beats  midi_pitch
# 678        56.0            2.0        52.0
# 679       56.25           1.75        55.0
# 680        58.0            2.0        52.0
# 681       58.25           1.75        55.0
# 682        60.0            2.0        52.0
# 683       60.25           1.75        53.0
# Node 39 segment data:
#     onset_beats duration_beats  midi_pitch
# 684        62.0            2.0        52.0
# 685       62.25           1.75        53.0
# 686        64.0            2.0        50.0
# 687       64.25           1.75        53.0
# 688        66.0            2.0        50.0
# 689       66.25           1.75        53.0
# Node 40 segment data:
#     onset_beats duration_beats  midi_pitch
# 690        68.0            2.0        43.0
# 691       68.25           1.75        50.0
# 692        70.0            2.0        43.0
# 693       70.25           1.75        50.0
# 694        72.0            2.0        48.0
# 695       72.25           1.75        52.0
# Node 41 segment data:
#     onset_beats duration_beats  midi_pitch
# 696        74.0            2.0        48.0
# 697       74.25           1.75        52.0
# 698        76.0            2.0        48.0
# 699       76.25           1.75        55.0
# 700        78.0            2.0        48.0
# 701       78.25           1.75        55.0
# Node 42 segment data:
#     onset_beats duration_beats  midi_pitch
# 702        80.0            2.0        41.0
# 703       80.25           1.75        53.0
# 704        82.0            2.0        41.0
# 705       82.25           1.75        53.0
# 706        84.0            2.0        42.0
# 707       84.25           1.75        48.0
# 708        86.0            2.0        42.0
# 709       86.25           1.75        48.0
# Node 43 segment data:
#     onset_beats duration_beats  midi_pitch
# 710        88.0            2.0        44.0
# 711       88.25           1.75        53.0
# 712        90.0            2.0        44.0
# 713       90.25           1.75        53.0
# 714        92.0            2.0        43.0
# 715       92.25           1.75        53.0
# 716        94.0            2.0        43.0
# 717       94.25           1.75        53.0
# 718        96.0            2.0        43.0
# 719       96.25           1.75        52.0
# 720        98.0            2.0        43.0
# 721       98.25           1.75        52.0
# 722       100.0            2.0        43.0
# 723      100.25           1.75        50.0
# Node 44 segment data:
#     onset_beats duration_beats  midi_pitch
# 724       102.0            2.0        43.0
# 725      102.25           1.75        50.0
# 726       104.0            2.0        43.0
# 727      104.25           1.75        50.0
# 728       106.0            2.0        43.0
# 729      106.25           1.75        50.0
# 730       108.0            2.0        43.0
# 731      108.25           1.75        51.0
# 732       110.0            2.0        43.0
# 733      110.25           1.75        51.0
# 734       112.0            2.0        43.0
# 735      112.25           1.75        52.0
# 736       114.0            2.0        43.0
# 737      114.25           1.75        52.0
# 738       116.0            2.0        43.0
# 739      116.25           1.75        50.0
# Node 45 segment data:
#     onset_beats duration_beats  midi_pitch
# 740       118.0            2.0        43.0
# 741      118.25           1.75        50.0
# 742       120.0            2.0        43.0
# 743      120.25           1.75        50.0
# 744       122.0            2.0        43.0
# 745      122.25           1.75        50.0
# Node 46 segment data:
#     onset_beats duration_beats  midi_pitch
# 746       124.0            2.0        36.0
# 747      124.25           1.75        48.0
# 748       126.0            2.0        36.0
# 749      126.25           1.75        48.0
# 750       128.0           3.75        36.0
# 751      128.25            3.5        48.0
# 752      131.75           0.25         0.0
# 753       132.0           3.75        36.0
# 754      132.25            3.5        50.0
# 755      135.75           0.25         0.0
# 756       136.0           2.75        36.0
# 757      138.75           1.25         0.0

# %%
# plot graph function
def plot_graph(graph: nx.classes.graph.Graph,
               seed: int,
               iterations: int,
               title: str,
               node_size: int):
  pos = nx.spring_layout(graph, seed=seed, iterations=iterations)
  nx.draw(G, node_size=node_size, pos=pos)
  plt.title(title)
  plt.show()

# %%
# show graph
plot_graph(graph, 3, 50, "Bach Prelud in C (K=5)", 50)

# %%
for i in range(len(graph.nodes())):
  graph.nodes[i]['segment'] = graph.nodes[i]['segment'].to_json(default_handler=str)

nt = Network('1000px', '1000px', notebook=True, cdn_resources = 'remote')
nt.from_nx(graph)
nt.show('sample_graph.html')   ### Still need to figure out the labels
display(HTML('sample_graph.html'))
