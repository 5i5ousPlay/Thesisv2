# %% [markdown]
# ## Setup in Local Machine

# %%
#Install
# %pip install worker
# %pip install pandas
# %pip install numpy
# %pip install networkx
# %pip install matplotlib
# %pip install music21
# %pip install musescore
# %pip install tslearn
# %pip install sklearn
# %pip install multiprocessing
# %pip install pyvis
# Out:
# Requirement already satisfied: worker in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (2018.4.1)
# Requirement already satisfied: termcc in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from worker) (2019.8.2)
# Requirement already satisfied: loader in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from worker) (2017.9.11)
# Requirement already satisfied: async-timeout in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from worker) (4.0.3)
# Requirement already satisfied: aiohttp in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from worker) (3.9.5)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from aiohttp->worker) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from aiohttp->worker) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from aiohttp->worker) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from aiohttp->worker) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from aiohttp->worker) (1.9.4)
# Requirement already satisfied: bs4 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from loader->worker) (0.0.2)
# Requirement already satisfied: logbook in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from termcc->worker) (1.7.0.post0)
# Requirement already satisfied: pendulum in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from termcc->worker) (3.0.0)
# Requirement already satisfied: terminaltables in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from termcc->worker) (3.1.10)
# Requirement already satisfied: idna>=2.0 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from yarl<2.0,>=1.0->aiohttp->worker) (3.7)
# Requirement already satisfied: beautifulsoup4 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from bs4->loader->worker) (4.12.3)
# Requirement already satisfied: python-dateutil>=2.6 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from pendulum->termcc->worker) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2020.1 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from pendulum->termcc->worker) (2024.1)
# Requirement already satisfied: time-machine>=2.6.0 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from pendulum->termcc->worker) (2.14.1)
# Requirement already satisfied: six>=1.5 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from python-dateutil>=2.6->pendulum->termcc->worker) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from beautifulsoup4->bs4->loader->worker) (2.5)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (1.26.4)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: networkx in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (3.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (3.8.4)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: contourpy>=1.0.1 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.21 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: music21 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (9.1.0)
# Requirement already satisfied: chardet in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from music21) (5.2.0)
# Requirement already satisfied: joblib in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from music21) (1.4.2)
# Requirement already satisfied: jsonpickle in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from music21) (3.0.4)
# Requirement already satisfied: matplotlib in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from music21) (3.8.4)
# Requirement already satisfied: more-itertools in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from music21) (10.2.0)
# Requirement already satisfied: numpy in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from music21) (1.26.4)
# Requirement already satisfied: requests in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from music21) (2.31.0)
# Requirement already satisfied: webcolors>=1.5 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from music21) (1.13)
# Requirement already satisfied: contourpy>=1.0.1 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from matplotlib->music21) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from matplotlib->music21) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from matplotlib->music21) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from matplotlib->music21) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from matplotlib->music21) (24.0)
# Requirement already satisfied: pillow>=8 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from matplotlib->music21) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from matplotlib->music21) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from matplotlib->music21) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from requests->music21) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from requests->music21) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from requests->music21) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from requests->music21) (2024.2.2)
# Requirement already satisfied: six>=1.5 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib->music21) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: musescore in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (0.0.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tslearn in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (0.6.3)
# Requirement already satisfied: numpy in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from tslearn) (1.26.4)
# Requirement already satisfied: scipy in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from tslearn) (1.13.0)
# Requirement already satisfied: scikit-learn in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from tslearn) (1.4.2)
# Requirement already satisfied: numba in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from tslearn) (0.59.1)
# Requirement already satisfied: joblib in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from tslearn) (1.4.2)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from numba->tslearn) (0.42.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from scikit-learn->tslearn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.Collecting sklearn
#   Using cached sklearn-0.0.post12.tar.gz (2.6 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   Getting requirements to build wheel did not run successfully.
#   exit code: 1
#
#   [15 lines of output]
#   The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#   rather than 'sklearn' for pip commands.
#
#   Here is how to fix this error in the main use cases:
#   - use 'pip install scikit-learn' rather than 'pip install sklearn'
#   - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#     (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#   - if the 'sklearn' package is used by one of your dependencies,
#     it would be great if you take some time to track which package uses
#     'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#   - as a last resort, set the environment variable
#     SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#   More information is available at
#   https://github.com/scikit-learn/sklearn-pypi-package
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# Getting requirements to build wheel did not run successfully.
# exit code: 1
#
# See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# Collecting multiprocessing
#   Using cached multiprocessing-2.6.2.1.tar.gz (108 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   Getting requirements to build wheel did not run successfully.
#   exit code: 1
#
#   [22 lines of output]
#   Traceback (most recent call last):
#     File "C:\.School\CSC142\csci42_group4\.venv\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 353, in <module>
#       main()
#     File "C:\.School\CSC142\csci42_group4\.venv\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 335, in main
#       json_out['return_val'] = hook(**hook_input['kwargs'])
#                                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\.School\CSC142\csci42_group4\.venv\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 118, in get_requires_for_build_wheel
#       return hook(config_settings)
#              ^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\oyutn\AppData\Local\Temp\pip-build-env-nccv96in\overlay\Lib\site-packages\setuptools\build_meta.py", line 325, in get_requires_for_build_wheel
#       return self._get_build_requires(config_settings, requirements=['wheel'])
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\oyutn\AppData\Local\Temp\pip-build-env-nccv96in\overlay\Lib\site-packages\setuptools\build_meta.py", line 295, in _get_build_requires
#       self.run_setup()
#     File "C:\Users\oyutn\AppData\Local\Temp\pip-build-env-nccv96in\overlay\Lib\site-packages\setuptools\build_meta.py", line 487, in run_setup
#       super().run_setup(setup_script=setup_script)
#     File "C:\Users\oyutn\AppData\Local\Temp\pip-build-env-nccv96in\overlay\Lib\site-packages\setuptools\build_meta.py", line 311, in run_setup
#       exec(code, locals())
#     File "<string>", line 94
#       print 'Macros:'
#       ^^^^^^^^^^^^^^^
#   SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# Getting requirements to build wheel did not run successfully.
# exit code: 1
#
# See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# Requirement already satisfied: pyvis in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (0.3.2)
# Requirement already satisfied: ipython>=5.3.0 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from pyvis) (8.24.0)
# Requirement already satisfied: jinja2>=2.9.6 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from pyvis) (3.1.4)
# Requirement already satisfied: jsonpickle>=1.4.1 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from pyvis) (3.0.4)
# Requirement already satisfied: networkx>=1.11 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from pyvis) (3.3)
# Requirement already satisfied: decorator in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from ipython>=5.3.0->pyvis) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from ipython>=5.3.0->pyvis) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from ipython>=5.3.0->pyvis) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from ipython>=5.3.0->pyvis) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from ipython>=5.3.0->pyvis) (2.18.0)
# Requirement already satisfied: stack-data in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from ipython>=5.3.0->pyvis) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from ipython>=5.3.0->pyvis) (5.14.3)
# Requirement already satisfied: colorama in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from ipython>=5.3.0->pyvis) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from jinja2>=2.9.6->pyvis) (2.1.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis) (0.8.4)
# Requirement already satisfied: wcwidth in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->pyvis) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from stack-data->ipython>=5.3.0->pyvis) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from stack-data->ipython>=5.3.0->pyvis) (2.4.1)
# Requirement already satisfied: pure-eval in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from stack-data->ipython>=5.3.0->pyvis) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in c:\.school\csc142\csci42_group4\.venv\lib\site-packages (from asttokens>=2.1.0->stack-data->ipython>=5.3.0->pyvis) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import
import worker
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

from music21 import *
from music21 import converter, corpus, environment, note, chord
from tslearn.metrics import dtw
from multiprocessing import Pool, Manager, cpu_count
from sklearn.neighbors import kneighbors_graph
from sklearn.metrics import pairwise_distances
from networkx.algorithms.cuts import conductance
from pyvis.network import Network
from IPython.display import display, HTML

# %%
# Path
env = environment.Environment()
env['musicxmlPath'] = 'C:\\Program Files\\MuseScore 4\\bin\\MuseScore4.exe' # Change if needed
env['musescoreDirectPNGPath'] = 'C:\\Program Files\\MuseScore 4\\bin\\MuseScore4.exe' # Change if needed

# %% [markdown]
# ## Process Sample Music

# %% [markdown]
# #### Functions

# %%
# midi to score array function (contains all data needed for score visualization)
def midi_to_sarr(midi_parsed):
    sarr = []
    for part in midi_parsed.parts:
        for element in part.flatten():
            sarr.append(element)
    return sarr

# %%
# sarr to narr and nmat function (removes all elements except notes, rests and chords then turn it into a matrix )
def sarr_to_nmat_and_narr(score_array):
  trashed_elements = 0
  narr = []
  nmat = pd.DataFrame(columns=['onset_beats', 'duration_beats', 'midi_pitch', 'ir_symbol'])

  for element in score_array:
    if isinstance(element, chord.Chord):
      row = [element.offset, element.duration.quarterLength, element.root().midi, 'unassigned']
      nmat.loc[len(nmat)] = row
      narr.append(element)
    elif isinstance(element, note.Rest):
      row = [element.offset, element.duration.quarterLength, 0, 'rest']
      nmat.loc[len(nmat)] = row
      narr.append(element)    
    else:
      try:
        row = [element.offset, element.duration.quarterLength, element.pitch.midi, 'unassigned']
        nmat.loc[len(nmat)] = row
        narr.append(element)
      except:
        trashed_elements += 1
        # print(f"Trashed element #{trashed_elements}:\n{note}") # for debugging
  return nmat, narr

# %% [markdown]
# #### Usage

# %%
# parse the midi and keep score title
midi_file = 'bach_846.mid' # Hardcoded, for multiple songs, make a function to iterate thru folder
midi_parsed = converter.parse(midi_file)
score_title = midi_file[:-4] # Temporary, apparently the title is not a score element that you can extract so im using the filename
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 # parse the midi and keep score title
#       2 midi_file = 'bach_846.mid' # Hardcoded, for multiple songs, make a function to iterate thru folder
# ----> 3 midi_parsed = converter.parse(midi_file)
#       4 score_title = midi_file[:-4] # Temporary, apparently the title is not a score element that you can extract so im using the filename
#
# File c:\Users\AL\AppData\Local\Programs\Python\Python312\Lib\site-packages\music21\converter\__init__.py:1424, in parse(value, forceSource, number, format, **keywords)
#    1421     raise FileNotFoundError(f'Cannot find file in {str(value)}')
#    1422 elif isinstance(value, str) and common.findFormatFile(value) is not None:
#    1423     # assume mistyped file path
# -> 1424     raise FileNotFoundError(f'Cannot find file in {str(value)}')
#    1425 else:
#    1426     # all else, including MidiBytes
#    1427     return parseData(value, number=number, format=format, **keywords)
#
# FileNotFoundError: Cannot find file in bach_846.mid

# %%
# convert parsed midi into a readable array of elements that forms the score
sarr = midi_to_sarr(midi_parsed) # this midi was cleaned

# output sarr to a readable .txt file
with open("sarr.txt", "w") as f:
    f.write(f"Number of elements: {len(sarr)}\n\n")
    for element in sarr:
        f.write(f"{element}\n")

# %%
# convert score array into a note array and note matrix
nmat, narr = sarr_to_nmat_and_narr(sarr)

# output nmat to a readable .txt file
with open("nmat.txt", "w") as f:
    f.write(f"Number of notes: {len(nmat)}\n\n")
    for note in nmat:
        f.write(f"{note}\n")
    f.write("\n")
    np.savetxt('nmat.txt', nmat, delimiter=',', fmt='%s')

# output narr to a readable .txt file
with open("narr.txt", "w") as f:
    f.write(f"Number of notes: {len(narr)}\n\n")
    for note in narr:
        f.write(f"{note}\n")

# %%
sarr
# Out:
# [<music21.instrument.Piano 'Piano, Piano right: Piano, Piano right'>,
#  <music21.instrument.Piano 'Piano'>,
#  <music21.clef.TrebleClef>,
#  <music21.tempo.MetronomeMark andante Quarter=74>,
#  <music21.key.Key of C major>,
#  <music21.meter.TimeSignature 4/4>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Note E>,
#  <music21.tempo.MetronomeMark andante Quarter=74>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.tempo.MetronomeMark andante Quarter=74>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note A>,
#  <music21.tempo.MetronomeMark Quarter=76>,
#  <music21.note.Note D>,
#  <music21.tempo.MetronomeMark andantino Quarter=78>,
#  <music21.note.Note F>,
#  <music21.tempo.MetronomeMark Quarter=76>,
#  <music21.note.Note A>,
#  <music21.note.Note D>,
#  <music21.note.Note F>,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note A>,
#  <music21.tempo.MetronomeMark Quarter=77>,
#  <music21.note.Note D>,
#  <music21.tempo.MetronomeMark andantino Quarter=79>,
#  <music21.note.Note F>,
#  <music21.tempo.MetronomeMark Quarter=77>,
#  <music21.note.Note A>,
#  <music21.note.Note D>,
#  <music21.tempo.MetronomeMark andante Quarter=74>,
#  <music21.note.Note F>,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.tempo.MetronomeMark Quarter=77>,
#  <music21.note.Note D>,
#  <music21.tempo.MetronomeMark andantino Quarter=80>,
#  <music21.note.Note F>,
#  <music21.tempo.MetronomeMark Quarter=77>,
#  <music21.note.Note G>,
#  <music21.note.Note D>,
#  <music21.note.Note F>,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.tempo.MetronomeMark Quarter=76>,
#  <music21.note.Note D>,
#  <music21.tempo.MetronomeMark andantino Quarter=78>,
#  <music21.note.Note F>,
#  <music21.tempo.MetronomeMark Quarter=76>,
#  <music21.note.Note G>,
#  <music21.note.Note D>,
#  <music21.tempo.MetronomeMark andante Quarter=73>,
#  <music21.note.Note F>,
#  <music21.tempo.MetronomeMark Quarter=76>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.tempo.MetronomeMark andantino Quarter=79>,
#  <music21.note.Note E>,
#  <music21.tempo.MetronomeMark Quarter=76>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.tempo.MetronomeMark andante Quarter=73>,
#  <music21.note.Note E>,
#  <music21.tempo.MetronomeMark Quarter=76>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.tempo.MetronomeMark andantino Quarter=78>,
#  <music21.note.Note E>,
#  <music21.tempo.MetronomeMark Quarter=76>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.tempo.MetronomeMark andante Quarter=74>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note A>,
#  <music21.tempo.MetronomeMark Quarter=76>,
#  <music21.note.Note E>,
#  <music21.tempo.MetronomeMark andantino Quarter=78>,
#  <music21.note.Note A>,
#  <music21.tempo.MetronomeMark Quarter=76>,
#  <music21.note.Note A>,
#  <music21.note.Note E>,
#  <music21.note.Note A>,
#  <music21.tempo.MetronomeMark andante Quarter=74>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note A>,
#  <music21.tempo.MetronomeMark Quarter=76>,
#  <music21.note.Note E>,
#  <music21.tempo.MetronomeMark andantino Quarter=78>,
#  <music21.note.Note A>,
#  <music21.tempo.MetronomeMark Quarter=76>,
#  <music21.note.Note A>,
#  <music21.note.Note E>,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Note A>,
#  <music21.tempo.MetronomeMark Quarter=76>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note F#>,
#  <music21.note.Note A>,
#  <music21.tempo.MetronomeMark andantino Quarter=79>,
#  <music21.note.Note D>,
#  <music21.tempo.MetronomeMark Quarter=77>,
#  <music21.note.Note F#>,
#  <music21.note.Note A>,
#  <music21.note.Note D>,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note F#>,
#  <music21.note.Note A>,
#  <music21.tempo.MetronomeMark Quarter=77>,
#  <music21.note.Note D>,
#  <music21.note.Note F#>,
#  <music21.note.Note A>,
#  <music21.tempo.MetronomeMark andante Quarter=73>,
#  <music21.note.Note D>,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.tempo.MetronomeMark Quarter=77>,
#  <music21.note.Note D>,
#  <music21.tempo.MetronomeMark andantino Quarter=78>,
#  <music21.note.Note G>,
#  <music21.tempo.MetronomeMark Quarter=77>,
#  <music21.note.Note G>,
#  <music21.note.Note D>,
#  <music21.tempo.MetronomeMark andante Quarter=74>,
#  <music21.note.Note G>,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.tempo.MetronomeMark Quarter=77>,
#  <music21.note.Note D>,
#  <music21.note.Note G>,
#  <music21.note.Note G>,
#  <music21.note.Note D>,
#  <music21.tempo.MetronomeMark andante Quarter=73>,
#  <music21.note.Note G>,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.tempo.MetronomeMark Quarter=77>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.tempo.MetronomeMark andante Quarter=74>,
#  <music21.note.Note C>,
#  <music21.tempo.MetronomeMark Quarter=76>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.tempo.MetronomeMark Quarter=77>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.tempo.MetronomeMark andante Quarter=73>,
#  <music21.note.Note C>,
#  <music21.tempo.MetronomeMark Quarter=76>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.tempo.MetronomeMark andante Quarter=74>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.tempo.MetronomeMark andante Quarter=73>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.tempo.MetronomeMark Quarter=69>,
#  <music21.note.Note C>,
#  <music21.tempo.MetronomeMark andante Quarter=73>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note D>,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Note F#>,
#  <music21.note.Note C>,
#  <music21.note.Note D>,
#  <music21.note.Note F#>,
#  <music21.note.Note C>,
#  <music21.tempo.MetronomeMark andante Quarter=73>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note D>,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Note F#>,
#  <music21.note.Note C>,
#  <music21.note.Note D>,
#  <music21.note.Note F#>,
#  <music21.tempo.MetronomeMark andante Quarter=73>,
#  <music21.note.Note C>,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note D>,
#  <music21.note.Note G>,
#  <music21.tempo.MetronomeMark Quarter=76>,
#  <music21.note.Note B>,
#  <music21.note.Note D>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note D>,
#  <music21.note.Note G>,
#  <music21.tempo.MetronomeMark Quarter=77>,
#  <music21.note.Note B>,
#  <music21.note.Note D>,
#  <music21.note.Note G>,
#  <music21.tempo.MetronomeMark andante Quarter=74>,
#  <music21.note.Note B>,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.tempo.MetronomeMark Quarter=77>,
#  <music21.note.Note C#>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.tempo.MetronomeMark andante Quarter=73>,
#  <music21.note.Note C#>,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.tempo.MetronomeMark Quarter=76>,
#  <music21.note.Note C#>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.tempo.MetronomeMark andante Quarter=73>,
#  <music21.note.Note C#>,
#  <music21.tempo.MetronomeMark andante Quarter=72>,
#  <music21.note.Rest 16th>,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Rest 16th>,
#  <music21.note.Note D>,
#  <music21.note.Note A>,
#  <music21.tempo.MetronomeMark Quarter=76>,
#  <music21.note.Note D>,
#  <music21.note.Note D>,
#  <music21.note.Note A>,
#  <music21.note.Note D>,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note D>,
#  <music21.note.Note A>,
#  <music21.tempo.MetronomeMark Quarter=76>,
#  <music21.note.Note D>,
#  <music21.note.Note D>,
#  <music21.note.Note A>,
#  <music21.tempo.MetronomeMark andante Quarter=72>,
#  <music21.note.Note D>,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note D>,
#  <music21.note.Note F>,
#  <music21.tempo.MetronomeMark Quarter=76>,
#  <music21.note.Note B>,
#  <music21.note.Note D>,
#  <music21.note.Note F>,
#  <music21.note.Note B>,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note D>,
#  <music21.note.Note F>,
#  <music21.tempo.MetronomeMark Quarter=76>,
#  <music21.note.Note B>,
#  <music21.note.Note D>,
#  <music21.note.Note F>,
#  <music21.tempo.MetronomeMark andante Quarter=73>,
#  <music21.note.Note B>,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note C>,
#  <music21.note.Note G>,
#  <music21.tempo.MetronomeMark Quarter=77>,
#  <music21.note.Note C>,
#  <music21.note.Note C>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note C>,
#  <music21.note.Note G>,
#  <music21.tempo.MetronomeMark Quarter=77>,
#  <music21.note.Note C>,
#  <music21.note.Note C>,
#  <music21.note.Note G>,
#  <music21.tempo.MetronomeMark andante Quarter=71>,
#  <music21.note.Note C>,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.tempo.MetronomeMark Quarter=76>,
#  <music21.note.Note F>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.note.Note F>,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.tempo.MetronomeMark Quarter=76>,
#  <music21.note.Note F>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.tempo.MetronomeMark andante Quarter=70>,
#  <music21.note.Note F>,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.tempo.MetronomeMark Quarter=76>,
#  <music21.note.Note F>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.tempo.MetronomeMark andante Quarter=71>,
#  <music21.note.Note F>,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.note.Note F>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.tempo.MetronomeMark andante Quarter=70>,
#  <music21.note.Note F>,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.note.Note F>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.note.Note F>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.note.Note F>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.note.Note F>,
#  <music21.tempo.MetronomeMark andante Quarter=73>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.tempo.MetronomeMark andante Quarter=73>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note B->,
#  <music21.note.Note C>,
#  <music21.tempo.MetronomeMark Quarter=77>,
#  <music21.note.Note E>,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Note B->,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note B->,
#  <music21.note.Note C>,
#  <music21.tempo.MetronomeMark Quarter=77>,
#  <music21.note.Note E>,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Note B->,
#  <music21.note.Note C>,
#  <music21.tempo.MetronomeMark Quarter=69>,
#  <music21.note.Note E>,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.tempo.MetronomeMark Quarter=76>,
#  <music21.note.Note E>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.tempo.MetronomeMark Quarter=76>,
#  <music21.note.Note E>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.tempo.MetronomeMark andante Quarter=70>,
#  <music21.note.Note E>,
#  <music21.tempo.MetronomeMark andante Quarter=73>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Note E->,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.note.Note E->,
#  <music21.tempo.MetronomeMark andante Quarter=73>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Note E->,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.tempo.MetronomeMark adagietto Quarter=64>,
#  <music21.note.Note E->,
#  <music21.tempo.MetronomeMark Quarter=76>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note B>,
#  <music21.note.Note C>,
#  <music21.note.Note D>,
#  <music21.tempo.MetronomeMark andantino Quarter=78>,
#  <music21.note.Note B>,
#  <music21.note.Note C>,
#  <music21.tempo.MetronomeMark andante Quarter=73>,
#  <music21.note.Note D>,
#  <music21.tempo.MetronomeMark Quarter=76>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note B>,
#  <music21.note.Note C>,
#  <music21.note.Note D>,
#  <music21.tempo.MetronomeMark Quarter=77>,
#  <music21.note.Note B>,
#  <music21.note.Note C>,
#  <music21.tempo.MetronomeMark andante Quarter=73>,
#  <music21.note.Note D>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.tempo.MetronomeMark Quarter=76>,
#  <music21.note.Note B>,
#  <music21.note.Note D>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.note.Note D>,
#  <music21.tempo.MetronomeMark andante Quarter=74>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.tempo.MetronomeMark Quarter=76>,
#  <music21.note.Note B>,
#  <music21.note.Note D>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.tempo.MetronomeMark andante Quarter=72>,
#  <music21.note.Note D>,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.tempo.MetronomeMark Quarter=76>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.tempo.MetronomeMark Quarter=76>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.tempo.MetronomeMark andantino Quarter=78>,
#  <music21.note.Note F>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.tempo.MetronomeMark andante Quarter=73>,
#  <music21.note.Note F>,
#  <music21.tempo.MetronomeMark andante Quarter=74>,
#  <music21.note.Rest 16th>,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Rest 16th>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.tempo.MetronomeMark andantino Quarter=78>,
#  <music21.note.Note F>,
#  <music21.note.Note G>,
#  <music21.tempo.MetronomeMark Quarter=77>,
#  <music21.note.Note C>,
#  <music21.tempo.MetronomeMark andante Quarter=73>,
#  <music21.note.Note F>,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.tempo.MetronomeMark Quarter=77>,
#  <music21.note.Note F>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.note.Note F>,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.tempo.MetronomeMark Quarter=77>,
#  <music21.note.Note F>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.tempo.MetronomeMark andante Quarter=73>,
#  <music21.note.Note F>,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.note.Note F#>,
#  <music21.tempo.MetronomeMark andante Quarter=73>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.note.Note F#>,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.note.Note F#>,
#  <music21.tempo.MetronomeMark andante Quarter=73>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.tempo.MetronomeMark Quarter=69>,
#  <music21.note.Note F#>,
#  <music21.tempo.MetronomeMark andante Quarter=70>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Note C>,
#  <music21.note.Note G>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note G>,
#  <music21.tempo.MetronomeMark andante Quarter=71>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Note C>,
#  <music21.note.Note G>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.tempo.MetronomeMark andante Quarter=70>,
#  <music21.note.Note G>,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note F>,
#  <music21.tempo.MetronomeMark Quarter=76>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note F>,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note F>,
#  <music21.tempo.MetronomeMark Quarter=76>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note F>,
#  <music21.tempo.MetronomeMark andante Quarter=70>,
#  <music21.note.Rest 16th>,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Rest 16th>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.note.Note F>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.note.Note F>,
#  <music21.tempo.MetronomeMark andante Quarter=71>,
#  <music21.note.Rest 16th>,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Rest 16th>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.note.Note F>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.note.Note F>,
#  <music21.tempo.MetronomeMark andante Quarter=73>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.note.Note B->,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note B->,
#  <music21.tempo.MetronomeMark andante Quarter=70>,
#  <music21.note.Note E>,
#  <music21.tempo.MetronomeMark andante Quarter=73>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.note.Note B->,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note B->,
#  <music21.tempo.MetronomeMark andante Quarter=71>,
#  <music21.note.Note E>,
#  <music21.tempo.MetronomeMark andante Quarter=73>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note F>,
#  <music21.tempo.MetronomeMark Quarter=75>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.tempo.MetronomeMark andante Quarter=73>,
#  <music21.note.Note F>,
#  <music21.note.Note C>,
#  <music21.note.Note A>,
#  <music21.tempo.MetronomeMark Quarter=76>,
#  <music21.note.Note C>,
#  <music21.tempo.MetronomeMark andante Quarter=73>,
#  <music21.note.Note A>,
#  <music21.note.Note F>,
#  <music21.note.Note A>,
#  <music21.tempo.MetronomeMark andante Quarter=71>,
#  <music21.note.Note F>,
#  <music21.note.Note D>,
#  <music21.tempo.MetronomeMark adagietto Quarter=66>,
#  <music21.note.Note F>,
#  <music21.tempo.MetronomeMark larghetto Quarter=60>,
#  <music21.note.Note D>,
#  <music21.tempo.MetronomeMark andante Quarter=71>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.note.Note D>,
#  <music21.note.Note F>,
#  <music21.note.Note D>,
#  <music21.note.Note B>,
#  <music21.tempo.MetronomeMark Quarter=63>,
#  <music21.note.Note D>,
#  <music21.note.Note B>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.tempo.MetronomeMark adagio Quarter=55>,
#  <music21.tempo.MetronomeMark lento Quarter=54>,
#  <music21.tempo.MetronomeMark lento Quarter=53>,
#  <music21.note.Note D>,
#  <music21.tempo.MetronomeMark lento Quarter=52>,
#  <music21.tempo.MetronomeMark lento Quarter=51>,
#  <music21.tempo.MetronomeMark lento Quarter=50>,
#  <music21.note.Note F>,
#  <music21.tempo.MetronomeMark Quarter=49>,
#  <music21.tempo.MetronomeMark largo Quarter=47>,
#  <music21.tempo.MetronomeMark largo Quarter=46>,
#  <music21.tempo.MetronomeMark largo Quarter=45>,
#  <music21.note.Note E>,
#  <music21.tempo.MetronomeMark largo Quarter=44>,
#  <music21.tempo.MetronomeMark grave Quarter=42>,
#  <music21.tempo.MetronomeMark largamente Quarter=31>,
#  <music21.note.Note D>,
#  <music21.chord.Chord E4 G4 C5>,
#  <music21.note.Rest 1.25ql>,
#  <music21.tempo.MetronomeMark larghetto Quarter=62>,
#  <music21.note.Rest half>,
#  <music21.tempo.MetronomeMark Quarter=63>,
#  <music21.note.Rest dotted-eighth>,
#  <music21.tempo.MetronomeMark adagietto Quarter=67>,
#  <music21.note.Rest 16th>,
#  <music21.tempo.MetronomeMark Quarter=63>,
#  <music21.note.Rest quarter>,
#  <music21.tempo.MetronomeMark larghetto Quarter=61>,
#  <music21.note.Rest eighth>,
#  <music21.tempo.MetronomeMark Quarter=63>,
#  <music21.note.Rest 1.75ql>,
#  <music21.tempo.MetronomeMark larghetto Quarter=61>,
#  <music21.note.Rest 16th>,
#  <music21.tempo.MetronomeMark Quarter=63>,
#  <music21.note.Rest quarter>,
#  <music21.tempo.MetronomeMark larghetto Quarter=61>,
#  <music21.note.Rest eighth>,
#  <music21.tempo.MetronomeMark Quarter=63>,
#  <music21.note.Rest dotted-eighth>,
#  <music21.tempo.MetronomeMark adagietto Quarter=67>,
#  <music21.note.Rest 16th>,
#  <music21.tempo.MetronomeMark Quarter=63>,
#  <music21.note.Rest quarter>,
#  <music21.tempo.MetronomeMark larghetto Quarter=62>,
#  <music21.note.Rest eighth>,
#  <music21.tempo.MetronomeMark adagietto Quarter=64>,
#  <music21.note.Rest dotted-quarter>,
#  <music21.tempo.MetronomeMark Quarter=63>,
#  <music21.note.Rest quarter>,
#  <music21.tempo.MetronomeMark adagietto Quarter=64>,
#  <music21.note.Rest dotted-quarter>,
#  <music21.tempo.MetronomeMark larghetto Quarter=61>,
#  <music21.note.Rest 16th>,
#  <music21.tempo.MetronomeMark adagietto Quarter=67>,
#  <music21.note.Rest 16th>,
#  <music21.tempo.MetronomeMark adagietto Quarter=64>,
#  <music21.note.Rest quarter>,
#  <music21.tempo.MetronomeMark larghetto Quarter=61>,
#  <music21.note.Rest eighth>,
#  <music21.tempo.MetronomeMark adagietto Quarter=64>,
#  <music21.note.Rest half>,
#  <music21.tempo.MetronomeMark larghetto Quarter=62>,
#  <music21.note.Rest eighth>,
#  <music21.tempo.MetronomeMark adagietto Quarter=64>,
#  <music21.note.Rest quarter>,
#  <music21.note.Rest dotted-eighth>,
#  <music21.tempo.MetronomeMark Quarter=69>,
#  <music21.note.Rest 16th>,
#  <music21.tempo.MetronomeMark Quarter=63>,
#  <music21.note.Rest quarter>,
#  <music21.tempo.MetronomeMark larghetto Quarter=62>,
#  <music21.note.Rest eighth>,
#  <music21.tempo.MetronomeMark Quarter=63>,
#  <music21.note.Rest quarter>,
#  <music21.tempo.MetronomeMark adagietto Quarter=66>,
#  <music21.note.Rest eighth>,
#  <music21.tempo.MetronomeMark Quarter=63>,
#  <music21.note.Rest dotted-quarter>,
#  <music21.tempo.MetronomeMark larghetto Quarter=62>,
#  <music21.note.Rest eighth>,
#  <music21.tempo.MetronomeMark Quarter=63>,
#  <music21.note.Rest dotted-eighth>,
#  <music21.tempo.MetronomeMark adagietto Quarter=67>,
#  <music21.note.Rest 16th>,
#  <music21.tempo.MetronomeMark adagietto Quarter=64>,
#  <music21.note.Rest quarter>,
#  <music21.tempo.MetronomeMark larghetto Quarter=62>,
#  <music21.note.Rest eighth>,
#  <music21.tempo.MetronomeMark Quarter=63>,
#  <music21.note.Rest quarter>,
#  <music21.tempo.MetronomeMark adagietto Quarter=66>,
#  <music21.note.Rest eighth>,
#  <music21.tempo.MetronomeMark larghetto Quarter=61>,
#  <music21.note.Rest eighth>,
#  <music21.tempo.MetronomeMark Quarter=63>,
#  <music21.note.Rest quarter>,
#  <music21.tempo.MetronomeMark adagietto Quarter=66>,
#  <music21.note.Rest 16th>,
#  <music21.tempo.MetronomeMark larghetto Quarter=62>,
#  <music21.note.Rest 16th>,
#  <music21.tempo.MetronomeMark Quarter=63>,
#  <music21.note.Rest 2.75ql>,
#  <music21.tempo.MetronomeMark adagietto Quarter=67>,
#  <music21.note.Rest 16th>,
#  <music21.tempo.MetronomeMark Quarter=63>,
#  <music21.note.Rest dotted-eighth>,
#  <music21.tempo.MetronomeMark adagietto Quarter=64>,
#  <music21.note.Rest 16th>,
#  <music21.tempo.MetronomeMark larghetto Quarter=61>,
#  <music21.note.Rest eighth>,
#  <music21.tempo.MetronomeMark adagietto Quarter=64>,
#  <music21.note.Rest eighth>,
#  <music21.tempo.MetronomeMark adagietto Quarter=66>,
#  <music21.note.Rest eighth>,
#  <music21.tempo.MetronomeMark adagietto Quarter=65>,
#  <music21.note.Rest 16th>,
#  <music21.tempo.MetronomeMark adagietto Quarter=64>,
#  <music21.note.Rest 16th>,
#  <music21.tempo.MetronomeMark adagietto Quarter=66>,
#  <music21.note.Rest 16th>,
#  <music21.tempo.MetronomeMark adagietto Quarter=65>,
#  <music21.note.Rest eighth>,
#  <music21.tempo.MetronomeMark adagietto Quarter=64>,
#  <music21.note.Rest dotted-eighth>,
#  <music21.tempo.MetronomeMark Quarter=63>,
#  <music21.note.Rest eighth>,
#  <music21.tempo.MetronomeMark adagietto Quarter=64>,
#  <music21.note.Rest dotted-eighth>,
#  <music21.tempo.MetronomeMark adagietto Quarter=67>,
#  <music21.note.Rest 16th>,
#  <music21.tempo.MetronomeMark adagietto Quarter=64>,
#  <music21.note.Rest dotted-eighth>,
#  <music21.tempo.MetronomeMark adagietto Quarter=67>,
#  <music21.note.Rest 16th>,
#  <music21.tempo.MetronomeMark adagietto Quarter=64>,
#  <music21.note.Rest quarter>,
#  <music21.tempo.MetronomeMark larghetto Quarter=61>,
#  <music21.note.Rest eighth>,
#  <music21.tempo.MetronomeMark adagietto Quarter=64>,
#  <music21.note.Rest eighth>,
#  <music21.note.Rest eighth>,
#  <music21.tempo.MetronomeMark larghetto Quarter=62>,
#  <music21.note.Rest eighth>,
#  <music21.tempo.MetronomeMark Quarter=63>,
#  <music21.note.Rest 1.75ql>,
#  <music21.tempo.MetronomeMark adagietto Quarter=67>,
#  <music21.note.Rest 16th>,
#  <music21.tempo.MetronomeMark adagietto Quarter=64>,
#  <music21.note.Rest quarter>,
#  <music21.tempo.MetronomeMark larghetto Quarter=61>,
#  <music21.note.Rest eighth>,
#  <music21.tempo.MetronomeMark adagietto Quarter=64>,
#  <music21.note.Rest half>,
#  <music21.tempo.MetronomeMark larghetto Quarter=60>,
#  <music21.note.Rest eighth>,
#  <music21.tempo.MetronomeMark adagio Quarter=57>,
#  <music21.note.Rest quarter>,
#  <music21.tempo.MetronomeMark larghetto Quarter=62>,
#  <music21.note.Rest dotted-quarter>,
#  <music21.tempo.MetronomeMark larghetto Quarter=60>,
#  <music21.note.Rest eighth>,
#  <music21.tempo.MetronomeMark Quarter=63>,
#  <music21.note.Rest dotted-eighth>,
#  <music21.tempo.MetronomeMark adagietto Quarter=66>,
#  <music21.note.Rest 16th>,
#  <music21.tempo.MetronomeMark Quarter=63>,
#  <music21.note.Rest quarter>,
#  <music21.tempo.MetronomeMark larghetto Quarter=61>,
#  <music21.note.Rest eighth>,
#  <music21.tempo.MetronomeMark Quarter=63>,
#  <music21.note.Rest dotted-eighth>,
#  <music21.tempo.MetronomeMark adagietto Quarter=65>,
#  <music21.note.Rest eighth>,
#  <music21.tempo.MetronomeMark larghetto Quarter=61>,
#  <music21.note.Rest 16th>,
#  <music21.tempo.MetronomeMark Quarter=63>,
#  <music21.note.Rest dotted-quarter>,
#  <music21.tempo.MetronomeMark larghetto Quarter=61>,
#  <music21.note.Rest eighth>,
#  <music21.tempo.MetronomeMark Quarter=63>,
#  <music21.note.Rest dotted-eighth>,
#  <music21.tempo.MetronomeMark adagietto Quarter=66>,
#  <music21.note.Rest 16th>,
#  <music21.tempo.MetronomeMark larghetto Quarter=61>,
#  <music21.note.Rest eighth>,
#  <music21.tempo.MetronomeMark Quarter=63>,
#  <music21.note.Rest 1.25ql>,
#  <music21.tempo.MetronomeMark larghetto Quarter=60>,
#  <music21.note.Rest 16th>,
#  <music21.tempo.MetronomeMark Quarter=63>,
#  <music21.note.Rest dotted-eighth>,
#  <music21.tempo.MetronomeMark adagietto Quarter=65>,
#  <music21.note.Rest 16th>,
#  <music21.tempo.MetronomeMark larghetto Quarter=61>,
#  <music21.note.Rest eighth>,
#  <music21.tempo.MetronomeMark Quarter=63>,
#  <music21.note.Rest half>,
#  <music21.tempo.MetronomeMark adagietto Quarter=66>,
#  <music21.note.Rest eighth>,
#  <music21.tempo.MetronomeMark Quarter=63>,
#  <music21.note.Rest quarter>,
#  <music21.tempo.MetronomeMark larghetto Quarter=61>,
#  <music21.note.Rest quarter>,
#  <music21.tempo.MetronomeMark Quarter=63>,
#  <music21.note.Rest eighth>,
#  <music21.tempo.MetronomeMark adagietto Quarter=65>,
#  <music21.note.Rest eighth>,
#  <music21.tempo.MetronomeMark Quarter=63>,
#  <music21.note.Rest dotted-quarter>,
#  <music21.tempo.MetronomeMark larghetto Quarter=60>,
#  <music21.note.Rest eighth>,
#  <music21.tempo.MetronomeMark Quarter=63>,
#  <music21.note.Rest dotted-eighth>,
#  <music21.tempo.MetronomeMark larghetto Quarter=60>,
#  <music21.note.Rest 2.25ql>,
#  <music21.tempo.MetronomeMark Quarter=63>,
#  <music21.note.Rest quarter>,
#  <music21.note.Rest 1.25ql>,
#  <music21.tempo.MetronomeMark adagio Quarter=58>,
#  <music21.note.Rest 16th>,
#  <music21.tempo.MetronomeMark larghetto Quarter=62>,
#  <music21.note.Rest quarter>,
#  <music21.tempo.MetronomeMark adagietto Quarter=64>,
#  <music21.note.Rest eighth>,
#  <music21.tempo.MetronomeMark Quarter=63>,
#  <music21.note.Rest quarter>,
#  <music21.note.Rest dotted-eighth>,
#  <music21.tempo.MetronomeMark larghetto Quarter=60>,
#  <music21.note.Rest 16th>,
#  <music21.tempo.MetronomeMark Quarter=63>,
#  <music21.note.Rest quarter>,
#  <music21.tempo.MetronomeMark larghetto Quarter=60>,
#  <music21.note.Rest eighth>,
#  <music21.tempo.MetronomeMark Quarter=63>,
#  <music21.note.Rest dotted-quarter>,
#  <music21.note.Rest eighth>,
#  <music21.tempo.MetronomeMark adagietto Quarter=65>,
#  <music21.note.Rest eighth>,
#  <music21.tempo.MetronomeMark Quarter=63>,
#  <music21.note.Rest eighth>,
#  <music21.tempo.MetronomeMark larghetto Quarter=61>,
#  <music21.note.Rest half>,
#  <music21.tempo.MetronomeMark Quarter=63>,
#  <music21.note.Rest eighth>,
#  <music21.tempo.MetronomeMark larghetto Quarter=61>,
#  <music21.note.Rest half>,
#  <music21.tempo.MetronomeMark larghetto Quarter=59>,
#  <music21.note.Rest eighth>,
#  <music21.tempo.MetronomeMark lento Quarter=54>,
#  <music21.note.Rest dotted-quarter>,
#  <music21.tempo.MetronomeMark adagio Quarter=57>,
#  <music21.note.Rest 2.5ql>,
#  <music21.tempo.MetronomeMark larghetto Quarter=60>,
#  <music21.note.Rest 16th>,
#  <music21.tempo.MetronomeMark lento Quarter=54>,
#  <music21.note.Rest 16th>,
#  <music21.tempo.MetronomeMark adagio Quarter=57>,
#  <music21.note.Rest quarter>,
#  <music21.note.Rest eighth>,
#  <music21.tempo.MetronomeMark larghetto Quarter=60>,
#  <music21.note.Rest 16th>,
#  <music21.tempo.MetronomeMark lento Quarter=54>,
#  <music21.note.Rest 16th>,
#  <music21.tempo.MetronomeMark adagio Quarter=57>,
#  <music21.note.Rest 1.25ql>,
#  <music21.tempo.MetronomeMark adagio Quarter=55>,
#  <music21.note.Rest 1.75ql>,
#  <music21.note.Rest 2/3ql>,
#  <music21.tempo.MetronomeMark lento Quarter=54>,
#  <music21.note.Rest 2/3ql>,
#  <music21.tempo.MetronomeMark lento Quarter=53>,
#  <music21.note.Rest 2/3ql>,
#  <music21.tempo.MetronomeMark lento Quarter=52>,
#  <music21.note.Rest 16th>,
#  <music21.tempo.MetronomeMark adagio Quarter=56>,
#  <music21.note.Rest 16th>,
#  <music21.tempo.MetronomeMark lento Quarter=52>,
#  <music21.note.Rest 1.25ql>,
#  <music21.tempo.MetronomeMark adagio Quarter=55>,
#  <music21.note.Rest 16th>,
#  <music21.tempo.MetronomeMark lento Quarter=52>,
#  <music21.note.Rest quarter>,
#  <music21.tempo.MetronomeMark largo Quarter=45>,
#  <music21.note.Rest 16th>,
#  <music21.tempo.MetronomeMark grave Quarter=38>,
#  <music21.note.Rest eighth>,
#  <music21.tempo.MetronomeMark Quarter=27>,
#  <music21.note.Rest 2.25ql>,
#  <music21.bar.Barline type=final>,
#  <music21.instrument.Piano 'Piano, Piano right: Piano, Piano right'>,
#  <music21.clef.BassClef>,
#  <music21.key.Key of C major>,
#  <music21.meter.TimeSignature 4/4>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Note C>,
#  <music21.note.Note D>,
#  <music21.note.Note C>,
#  <music21.note.Note D>,
#  <music21.note.Note B>,
#  <music21.note.Note D>,
#  <music21.note.Note B>,
#  <music21.note.Note D>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Note C>,
#  <music21.note.Note D>,
#  <music21.note.Note C>,
#  <music21.note.Note D>,
#  <music21.note.Note B>,
#  <music21.note.Note D>,
#  <music21.note.Note B>,
#  <music21.note.Note D>,
#  <music21.note.Note B>,
#  <music21.note.Note C>,
#  <music21.note.Note B>,
#  <music21.note.Note C>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.note.Note D>,
#  <music21.note.Note A>,
#  <music21.note.Note D>,
#  ...]

# %%
narr
# Out:
# [<music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note A>,
#  <music21.note.Note D>,
#  <music21.note.Note F>,
#  <music21.note.Note A>,
#  <music21.note.Note D>,
#  <music21.note.Note F>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note A>,
#  <music21.note.Note D>,
#  <music21.note.Note F>,
#  <music21.note.Note A>,
#  <music21.note.Note D>,
#  <music21.note.Note F>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.note.Note D>,
#  <music21.note.Note F>,
#  <music21.note.Note G>,
#  <music21.note.Note D>,
#  <music21.note.Note F>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.note.Note D>,
#  <music21.note.Note F>,
#  <music21.note.Note G>,
#  <music21.note.Note D>,
#  <music21.note.Note F>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note A>,
#  <music21.note.Note E>,
#  <music21.note.Note A>,
#  <music21.note.Note A>,
#  <music21.note.Note E>,
#  <music21.note.Note A>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note A>,
#  <music21.note.Note E>,
#  <music21.note.Note A>,
#  <music21.note.Note A>,
#  <music21.note.Note E>,
#  <music21.note.Note A>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note F#>,
#  <music21.note.Note A>,
#  <music21.note.Note D>,
#  <music21.note.Note F#>,
#  <music21.note.Note A>,
#  <music21.note.Note D>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note F#>,
#  <music21.note.Note A>,
#  <music21.note.Note D>,
#  <music21.note.Note F#>,
#  <music21.note.Note A>,
#  <music21.note.Note D>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.note.Note D>,
#  <music21.note.Note G>,
#  <music21.note.Note G>,
#  <music21.note.Note D>,
#  <music21.note.Note G>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.note.Note D>,
#  <music21.note.Note G>,
#  <music21.note.Note G>,
#  <music21.note.Note D>,
#  <music21.note.Note G>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note D>,
#  <music21.note.Note F#>,
#  <music21.note.Note C>,
#  <music21.note.Note D>,
#  <music21.note.Note F#>,
#  <music21.note.Note C>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note D>,
#  <music21.note.Note F#>,
#  <music21.note.Note C>,
#  <music21.note.Note D>,
#  <music21.note.Note F#>,
#  <music21.note.Note C>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note D>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.note.Note D>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note D>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.note.Note D>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note C#>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note C#>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note C#>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note C#>,
#  <music21.note.Rest 16th>,
#  <music21.note.Rest 16th>,
#  <music21.note.Note D>,
#  <music21.note.Note A>,
#  <music21.note.Note D>,
#  <music21.note.Note D>,
#  <music21.note.Note A>,
#  <music21.note.Note D>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note D>,
#  <music21.note.Note A>,
#  <music21.note.Note D>,
#  <music21.note.Note D>,
#  <music21.note.Note A>,
#  <music21.note.Note D>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note D>,
#  <music21.note.Note F>,
#  <music21.note.Note B>,
#  <music21.note.Note D>,
#  <music21.note.Note F>,
#  <music21.note.Note B>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note D>,
#  <music21.note.Note F>,
#  <music21.note.Note B>,
#  <music21.note.Note D>,
#  <music21.note.Note F>,
#  <music21.note.Note B>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note C>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note C>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note C>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note C>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.note.Note F>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.note.Note F>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.note.Note F>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.note.Note F>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.note.Note F>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.note.Note F>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.note.Note F>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.note.Note F>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.note.Note F>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.note.Note F>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.note.Note F>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.note.Note F>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note B->,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Note B->,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note B->,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Note B->,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.note.Note E->,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.note.Note E->,
#  <music21.note.Rest eighth>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.note.Note E->,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.note.Note E->,
#  <music21.note.Rest eighth>,
#  <music21.note.Note B>,
#  <music21.note.Note C>,
#  <music21.note.Note D>,
#  <music21.note.Note B>,
#  <music21.note.Note C>,
#  <music21.note.Note D>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note B>,
#  <music21.note.Note C>,
#  <music21.note.Note D>,
#  <music21.note.Note B>,
#  <music21.note.Note C>,
#  <music21.note.Note D>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.note.Note D>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.note.Note D>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.note.Note D>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.note.Note D>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note F>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note F>,
#  <music21.note.Rest 16th>,
#  <music21.note.Rest 16th>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note F>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note F>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.note.Note F>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.note.Note F>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.note.Note F>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.note.Note F>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.note.Note F#>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.note.Note F#>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.note.Note F#>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.note.Note F#>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note G>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note G>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note G>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note G>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note F>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note F>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note F>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note F>,
#  <music21.note.Rest 16th>,
#  <music21.note.Rest 16th>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.note.Note F>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.note.Note F>,
#  <music21.note.Rest 16th>,
#  <music21.note.Rest 16th>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.note.Note F>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.note.Note F>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.note.Note B->,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note B->,
#  <music21.note.Note E>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.note.Note B->,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note B->,
#  <music21.note.Note E>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note F>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.note.Note F>,
#  <music21.note.Note C>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.note.Note A>,
#  <music21.note.Note F>,
#  <music21.note.Note A>,
#  <music21.note.Note F>,
#  <music21.note.Note D>,
#  <music21.note.Note F>,
#  <music21.note.Note D>,
#  <music21.note.Rest eighth>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.note.Note D>,
#  <music21.note.Note F>,
#  <music21.note.Note D>,
#  <music21.note.Note B>,
#  <music21.note.Note D>,
#  <music21.note.Note B>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.note.Note D>,
#  <music21.note.Note F>,
#  <music21.note.Note E>,
#  <music21.note.Note D>,
#  <music21.chord.Chord E4 G4 C5>,
#  <music21.note.Rest 1.25ql>,
#  <music21.note.Rest half>,
#  <music21.note.Rest dotted-eighth>,
#  <music21.note.Rest 16th>,
#  <music21.note.Rest quarter>,
#  <music21.note.Rest eighth>,
#  <music21.note.Rest 1.75ql>,
#  <music21.note.Rest 16th>,
#  <music21.note.Rest quarter>,
#  <music21.note.Rest eighth>,
#  <music21.note.Rest dotted-eighth>,
#  <music21.note.Rest 16th>,
#  <music21.note.Rest quarter>,
#  <music21.note.Rest eighth>,
#  <music21.note.Rest dotted-quarter>,
#  <music21.note.Rest quarter>,
#  <music21.note.Rest dotted-quarter>,
#  <music21.note.Rest 16th>,
#  <music21.note.Rest 16th>,
#  <music21.note.Rest quarter>,
#  <music21.note.Rest eighth>,
#  <music21.note.Rest half>,
#  <music21.note.Rest eighth>,
#  <music21.note.Rest quarter>,
#  <music21.note.Rest dotted-eighth>,
#  <music21.note.Rest 16th>,
#  <music21.note.Rest quarter>,
#  <music21.note.Rest eighth>,
#  <music21.note.Rest quarter>,
#  <music21.note.Rest eighth>,
#  <music21.note.Rest dotted-quarter>,
#  <music21.note.Rest eighth>,
#  <music21.note.Rest dotted-eighth>,
#  <music21.note.Rest 16th>,
#  <music21.note.Rest quarter>,
#  <music21.note.Rest eighth>,
#  <music21.note.Rest quarter>,
#  <music21.note.Rest eighth>,
#  <music21.note.Rest eighth>,
#  <music21.note.Rest quarter>,
#  <music21.note.Rest 16th>,
#  <music21.note.Rest 16th>,
#  <music21.note.Rest 2.75ql>,
#  <music21.note.Rest 16th>,
#  <music21.note.Rest dotted-eighth>,
#  <music21.note.Rest 16th>,
#  <music21.note.Rest eighth>,
#  <music21.note.Rest eighth>,
#  <music21.note.Rest eighth>,
#  <music21.note.Rest 16th>,
#  <music21.note.Rest 16th>,
#  <music21.note.Rest 16th>,
#  <music21.note.Rest eighth>,
#  <music21.note.Rest dotted-eighth>,
#  <music21.note.Rest eighth>,
#  <music21.note.Rest dotted-eighth>,
#  <music21.note.Rest 16th>,
#  <music21.note.Rest dotted-eighth>,
#  <music21.note.Rest 16th>,
#  <music21.note.Rest quarter>,
#  <music21.note.Rest eighth>,
#  <music21.note.Rest eighth>,
#  <music21.note.Rest eighth>,
#  <music21.note.Rest eighth>,
#  <music21.note.Rest 1.75ql>,
#  <music21.note.Rest 16th>,
#  <music21.note.Rest quarter>,
#  <music21.note.Rest eighth>,
#  <music21.note.Rest half>,
#  <music21.note.Rest eighth>,
#  <music21.note.Rest quarter>,
#  <music21.note.Rest dotted-quarter>,
#  <music21.note.Rest eighth>,
#  <music21.note.Rest dotted-eighth>,
#  <music21.note.Rest 16th>,
#  <music21.note.Rest quarter>,
#  <music21.note.Rest eighth>,
#  <music21.note.Rest dotted-eighth>,
#  <music21.note.Rest eighth>,
#  <music21.note.Rest 16th>,
#  <music21.note.Rest dotted-quarter>,
#  <music21.note.Rest eighth>,
#  <music21.note.Rest dotted-eighth>,
#  <music21.note.Rest 16th>,
#  <music21.note.Rest eighth>,
#  <music21.note.Rest 1.25ql>,
#  <music21.note.Rest 16th>,
#  <music21.note.Rest dotted-eighth>,
#  <music21.note.Rest 16th>,
#  <music21.note.Rest eighth>,
#  <music21.note.Rest half>,
#  <music21.note.Rest eighth>,
#  <music21.note.Rest quarter>,
#  <music21.note.Rest quarter>,
#  <music21.note.Rest eighth>,
#  <music21.note.Rest eighth>,
#  <music21.note.Rest dotted-quarter>,
#  <music21.note.Rest eighth>,
#  <music21.note.Rest dotted-eighth>,
#  <music21.note.Rest 2.25ql>,
#  <music21.note.Rest quarter>,
#  <music21.note.Rest 1.25ql>,
#  <music21.note.Rest 16th>,
#  <music21.note.Rest quarter>,
#  <music21.note.Rest eighth>,
#  <music21.note.Rest quarter>,
#  <music21.note.Rest dotted-eighth>,
#  <music21.note.Rest 16th>,
#  <music21.note.Rest quarter>,
#  <music21.note.Rest eighth>,
#  <music21.note.Rest dotted-quarter>,
#  <music21.note.Rest eighth>,
#  <music21.note.Rest eighth>,
#  <music21.note.Rest eighth>,
#  <music21.note.Rest half>,
#  <music21.note.Rest eighth>,
#  <music21.note.Rest half>,
#  <music21.note.Rest eighth>,
#  <music21.note.Rest dotted-quarter>,
#  <music21.note.Rest 2.5ql>,
#  <music21.note.Rest 16th>,
#  <music21.note.Rest 16th>,
#  <music21.note.Rest quarter>,
#  <music21.note.Rest eighth>,
#  <music21.note.Rest 16th>,
#  <music21.note.Rest 16th>,
#  <music21.note.Rest 1.25ql>,
#  <music21.note.Rest 1.75ql>,
#  <music21.note.Rest 2/3ql>,
#  <music21.note.Rest 2/3ql>,
#  <music21.note.Rest 2/3ql>,
#  <music21.note.Rest 16th>,
#  <music21.note.Rest 16th>,
#  <music21.note.Rest 1.25ql>,
#  <music21.note.Rest 16th>,
#  <music21.note.Rest quarter>,
#  <music21.note.Rest 16th>,
#  <music21.note.Rest eighth>,
#  <music21.note.Rest 2.25ql>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Note C>,
#  <music21.note.Note D>,
#  <music21.note.Note C>,
#  <music21.note.Note D>,
#  <music21.note.Note B>,
#  <music21.note.Note D>,
#  <music21.note.Note B>,
#  <music21.note.Note D>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Note C>,
#  <music21.note.Note D>,
#  <music21.note.Note C>,
#  <music21.note.Note D>,
#  <music21.note.Note B>,
#  <music21.note.Note D>,
#  <music21.note.Note B>,
#  <music21.note.Note D>,
#  <music21.note.Note B>,
#  <music21.note.Note C>,
#  <music21.note.Note B>,
#  <music21.note.Note C>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.note.Note D>,
#  <music21.note.Note A>,
#  <music21.note.Note D>,
#  <music21.note.Note A>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.note.Note G>,
#  <music21.note.Note B->,
#  <music21.note.Note G>,
#  <music21.note.Note B->,
#  <music21.note.Note F>,
#  <music21.note.Note A>,
#  <music21.note.Note F>,
#  <music21.note.Note A>,
#  <music21.note.Note F>,
#  <music21.note.Note G#>,
#  <music21.note.Note F>,
#  <music21.note.Note G#>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note E>,
#  <music21.note.Note F>,
#  <music21.note.Note E>,
#  <music21.note.Note F>,
#  <music21.note.Note D>,
#  <music21.note.Note F>,
#  <music21.note.Note D>,
#  <music21.note.Note F>,
#  <music21.note.Note G>,
#  <music21.note.Note D>,
#  <music21.note.Note G>,
#  <music21.note.Note D>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Note C>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note G>,
#  <music21.note.Note F>,
#  <music21.note.Note F>,
#  <music21.note.Note F>,
#  <music21.note.Note F>,
#  <music21.note.Note F#>,
#  <music21.note.Note C>,
#  <music21.note.Note F#>,
#  <music21.note.Note C>,
#  <music21.note.Note G#>,
#  <music21.note.Note F>,
#  <music21.note.Note G#>,
#  <music21.note.Note F>,
#  <music21.note.Note G>,
#  <music21.note.Note F>,
#  <music21.note.Note G>,
#  <music21.note.Note F>,
#  <music21.note.Note G>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note D>,
#  <music21.note.Note G>,
#  <music21.note.Note D>,
#  <music21.note.Note G>,
#  <music21.note.Note D>,
#  <music21.note.Note G>,
#  <music21.note.Note D>,
#  <music21.note.Note G>,
#  <music21.note.Note E->,
#  <music21.note.Note G>,
#  <music21.note.Note E->,
#  <music21.note.Note G>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note D>,
#  <music21.note.Note G>,
#  <music21.note.Note D>,
#  <music21.note.Note G>,
#  <music21.note.Note D>,
#  <music21.note.Note G>,
#  <music21.note.Note D>,
#  <music21.note.Note C>,
#  <music21.note.Note C>,
#  <music21.note.Note C>,
#  <music21.note.Note C>,
#  <music21.note.Note C>,
#  <music21.note.Note C>,
#  <music21.note.Rest 16th>,
#  <music21.note.Note C>,
#  <music21.note.Note D>,
#  <music21.note.Rest 16th>,
#  <music21.chord.Chord C2 C3>,
#  <music21.note.Rest 1.25ql>]

# %% [markdown]
# ## Implication-Realization Ruleset, Assignment and Score Visualization

# %% [markdown]
# #### Functions

# %%
# IR symbol calculation function
def calculate_ir_symbol(interval1, interval2, threshold=5):
    direction = interval1 * interval2
    abs_difference = abs(interval2-interval1)
    # Process
    if direction > 0 and (abs(interval2-interval1))<threshold:
        return 'P'  
    # IR2: D (Duplication)
    elif interval1 == interval2 == 0:
        return 'D' 
    # IR3: IP (Intervallic Process)
    elif ((interval1 * interval2)<0) and (-threshold <= (abs(interval2) - abs(interval1)) <= threshold) and (abs(interval2) != abs(interval1)):
        return 'IP' 
    # IR4: ID (Intervallic Duplication)
    elif ((interval1 * interval2) < 0) and (abs(interval2) == abs(interval1)):
        return 'ID'   
    # IR5: VP (Vector Process)
    elif (interval1 * interval2 > 0) and (abs(interval2-interval1) >= threshold) and (abs(interval1) <= threshold):
        return 'VP'
    # IR6: R (Reveral)
    elif (interval1 * interval2 < 0) and (abs(abs(interval2)-abs(interval1)) >= threshold) and (abs(interval1) >= threshold):
        return 'R'
    # IR7: IR (Intervallic Reveral)
    elif (interval1 * interval2 > 0) and (abs(abs(interval2)-abs(interval1)) >= threshold) and (abs(interval1) >= threshold):
        return 'IR' 
    # IR8: VR (Vector Reveral)
    elif (interval1 * interval2 < 0) and (abs(interval2 - interval1) >= threshold) and (abs(interval1) <= threshold):
        return 'VR'
    elif interval2 == 0 and not (interval1 < -5 or interval1 > 5):
        return 'IP'
    elif interval2 == 0 and (interval1 < -5 or interval1 > 5):
        return 'R'
    elif interval1 == 0 and not (interval2 < -5 or interval2 > 5):
        return 'P'
    elif interval1 == 0 and (interval2 < -5 or interval2 > 5):
        return 'VR'

# %%
# assign IR symbol function (original; modified)
def assign_ir_symbols(score_array):

    symbols = []
    current_group = [] 
    group_pitches = []
    
    color_map = {
        'P': 'blue',        # IR1: P (Process) 
        'D': 'green',       # IR2: D (Duplication)
        'IP': 'red',        # IR3: IP (Intervallic Process)
        'ID': 'orange',     # IR4: ID (Intervallic Duplication)
        'VP': 'purple',     # IR5: VP (Vector Process)
        'R': 'cyan',        # IR6: R (Reveral)
        'IR': 'magenta',    # IR7: IR (Intervallic Reveral)
        'VR': 'yellow',     # IR8: VR (Vector Reveral)
        'M': 'pink',        # IR9: M (Monad)
        'd': 'lime',        # IR10 d (Dyad)
    }

    def evaluate_current_group():
        if len(current_group) == 3:
            interval1 = group_pitches[1] - group_pitches[0]
            interval2 = group_pitches[2] - group_pitches[1]
            symbol = calculate_ir_symbol(interval1, interval2)
            # symbols.append(symbol)
            color = color_map.get(symbol, 'black')  # Default to black if symbol is not predefined
            symbols.extend((note, symbol, color) for note in current_group)
        elif len(current_group) == 2:
            # symbols.append('d')  # Dyad
            symbols.extend((note, 'd', color_map['d']) for note in current_group)
        elif len(current_group) == 1:
            # symbols.append('M')  # Monad
            symbols.extend((note, 'M', color_map['M']) for note in current_group)
        # else:
            # symbols.append('Error: Invalid note object')
        current_group.clear()
        group_pitches.clear()

    for element in score_array:
        if isinstance(element, note.Note):
            current_group.append(element)
            group_pitches.append(element.pitch.ps)
            if len(current_group) == 3:
                evaluate_current_group()
        elif isinstance(element, chord.Chord):
            current_group.append(element)
            group_pitches.append(element.root().ps)
            if len(current_group) == 3:
                evaluate_current_group()
        elif isinstance(element, note.Rest):
            # continue
            # Remove continue for visualization
            rest_tuple = (element, 'rest', 'black') 
            evaluate_current_group()
            symbols.append(rest_tuple)
        else:
            if current_group:
                evaluate_current_group()

    # Handle any remaining notes
    if current_group:
        evaluate_current_group()

    return symbols

# %%
# Score visualization function
def visualize_notes_with_symbols(notes_with_symbols):
    s = stream.Score()
    part = stream.Part()
    for note, symbol, color in notes_with_symbols:
        print(note, symbol, color)
        note.style.color = color
        note.lyric = symbol
        part.append(note)
    s.append(part)
    s.show()

# %%
# store ir symbol in nmat function, pass narr data to nmat
def pass_ir_symbol_narr_to_nmat(note_array, note_matrix):
    pointer = 0
    for note in note_array:
        note_data, ir_symbol, color = note
        nmat.loc[pointer, 'ir_symbol'] = ir_symbol
        pointer += 1

# %% [markdown]
# #### Usage

# %%
# Usage of the above functions
try:
    narr = assign_ir_symbols(narr)
except: # temporary fix for when error occurs
    print("An erorr occured, re-importing music21")
    from music21 import *
    narr = assign_ir_symbols(narr)

# output narr with assigned ir symbols to a readable .txt file
with open("narr_assigned_ir.txt", "w") as f:
    f.write(f"Number of notes: {len(narr)}\n\n")
    for note in narr:
        f.write(f"{note}\n")

# try: # error when polyphonic
# visualize_notes_with_symbols(test_ir)
# except:
#     score = converter.parse('bach_846.mid')
#     score.show

# store ir symbol in nmat, pass narr data to nmat
pass_ir_symbol_narr_to_nmat(narr, nmat)

# output nmat to a readable .txt file
with open("nmat_assigned_ir.txt", "w") as f:
    f.write(f"Number of notes: {len(nmat)}\n\n")
    for note in nmat:
        f.write(f"{note}\n")
    f.write("\n")
    np.savetxt('nmat_assigned_ir.txt', nmat, delimiter=',', fmt='%s')
# Out:
# An erorr occured, re-importing music21

# %% [markdown]
# ## Gestalt Based Segmentation (Functions)

# %%
# onset function
def get_onset(notematrix: pd.DataFrame, timetype='beat'):
  if timetype == 'beat':
    return notematrix['onset_beats']
  elif timetype == 'sec':
    return notematrix['onset_sec']
  else:
    ValueError(f"Invalid timetype: {timetype}. Choices are only 'beat' and 'sec'")

# %%
# duration function
def get_duration(notematrix: pd.DataFrame, timetype='beat') -> pd.Series:
  if timetype == 'beat':
    return notematrix['duration_beats']
  elif timetype == 'sec':
    return notematrix['duration_sec']
  else:
    ValueError(f"Invalid timetype: {timetype}. Choices are only 'beat' and 'sec'")

# %%
# clang boundary calculation funtion
def calculate_clang_boundaries(notematrix: pd.DataFrame):
  cl = 2*(get_onset(notematrix).diff() + get_duration(notematrix).shift(-1)) + abs(notematrix['midi_pitch'].diff())
  clb = (cl.shift(-1) > cl) & (cl.shift(1) > cl)
  clind = clb.index[clb].tolist()
  return clind

# %%
# segment boundary calculation function
def calculate_segment_boundaries(notematrix, clind):
    first = [0] + clind
    last = clind + [len(notematrix) - 1]
    mean_pitch = [notematrix.iloc[first[i]:last[i]+1]['midi_pitch'].mean() for i in range(len(first))]
    segdist = []
    for i in range(1, len(first)):
        segdist.append(abs(mean_pitch[i] - mean_pitch[i - 1]) +
                       notematrix.iloc[first[i]]['onset_beats'] - notematrix.iloc[last[i - 1]]['onset_beats'] +
                       notematrix.iloc[first[i]]['duration_beats'] + notematrix.iloc[first[i - 1]]['duration_beats'] +
                       2 * (notematrix.iloc[first[i]]['onset_beats'] - notematrix.iloc[last[i - 1]]['onset_beats']))

    segb = [(segdist[i] > segdist[i-1] and segdist[i] > segdist[i+1]) for i in range(1, len(segdist)-1)]
    segind = [clind[i] for i in range(1, len(segdist)-1) if segb[i-1]]
    return segind

# %%
# gestalt segmentation function
def segmentgestalt(notematrix):
    if notematrix.empty:
        return None

    # IR Assignment function here? <------------------------------------------------------ yayayaya look here
    clind = calculate_clang_boundaries(notematrix)
    segind = calculate_segment_boundaries(notematrix, clind)

    segments = []
    start_idx = 0
    for end_idx in segind:
        segments.append(notematrix.iloc[start_idx:end_idx+1])
        start_idx = end_idx + 1

    segments.append(notematrix.iloc[start_idx:])
    return segments

# %% [markdown]
# ## Get Clang Boundaries and Segments

# %%
# show clang boundaries
clang_boundaries = calculate_clang_boundaries(nmat)
print("Clang Boundaries:", clang_boundaries)
# Out:
# Clang Boundaries: [3, 6, 10, 13, 17, 20, 24, 27, 31, 34, 38, 41, 45, 48, 52, 55, 59, 62, 66, 69, 72, 75, 79, 82, 87, 90, 94, 97, 100, 103, 107, 110, 114, 117, 121, 124, 128, 131, 135, 138, 143, 146, 150, 153, 156, 159, 163, 166, 169, 172, 175, 179, 182, 185, 188, 192, 195, 200, 203, 207, 210, 213, 216, 220, 223, 227, 230, 234, 237, 241, 244, 248, 251, 256, 259, 263, 266, 269, 272, 276, 279, 283, 286, 290, 293, 300, 307, 311, 314, 318, 321, 326, 329, 333, 336, 340, 343, 347, 350, 359, 364, 368, 371, 375, 378, 382, 385, 389, 392, 396, 399, 403, 406, 413, 423, 425, 428, 431, 433, 436, 440, 443, 447, 450, 455, 480, 484, 487, 489, 491, 493, 495, 497, 499, 502, 504, 509, 511, 513, 515, 517, 519, 522, 525, 527, 529, 533, 538, 540, 542, 547, 549, 551, 554, 556, 558, 563, 565, 568, 570, 573, 579, 582, 584, 586, 591, 593, 595, 597, 599, 602, 605, 607, 610, 614, 616, 618, 622, 625, 627, 629, 631, 633, 635, 637, 639, 641, 643, 645, 647, 649, 651, 653, 655, 657, 659, 663, 665, 667, 669, 671, 673, 675, 677, 679, 681, 683, 685, 687, 689, 691, 695, 697, 701, 703, 705, 707, 709, 713, 715, 717, 719, 721, 723, 725, 727, 729, 731, 733, 735, 737, 739, 741, 743, 745, 747, 751, 754]

# %%
# Get segments
segments = segmentgestalt(nmat)

# Store viz related properties (score title, color), labelling the segment
labeled_segments = []
assigned_color = 'red' # HARDCODED temporary since multiple scores not impremented yet
# color_list = ['blue', 'green', 'red', 'orange', 'purple', 'cyan', 'magenta', 'yellow', 'pink', 'lime']
label = (score_title, assigned_color)
for segment in segments:
    labeled_segments.append((label, segment))


# output to a readable .txt file
with open("labeled_segments.txt", "w") as f:
    f.write(f"Number of segments: {len(labeled_segments)}\n\n")
    for idx, tuple in enumerate(labeled_segments):
        label, segment = tuple
        title, color = label
        f.write(f"{title} Segment {idx+1} ({color}):\n")
        f.write(f"{segment}\n")
        f.write("--------------------------------------------\n\n")

# %% [markdown]
# ## DTW Distance Using TSLearn

# %%
def segments_to_distance_matrix(segments: list[pd.DataFrame], cores=None):
    if __name__ == '__main__':
        
        if cores is not None and cores > cpu_count():
            raise ValueError(f"You don't have enough cores! Please specify a value within your system's number of cores. \n Core Count: {cpu_count()}")
        
        seg_np = [segment.to_numpy() for segment in segments]
    
        num_segments = len(seg_np)
        distance_matrix = np.zeros((num_segments, num_segments))
    
        # Create argument list for multiprocessing
        args_list = []
        for i in range(num_segments):
            for j in range(i + 1, num_segments):
                args_list.append((i, j, segments[i], segments[j]))
    
        with Manager() as manager:
            message_list = manager.list()
    
            def log_message(message):
                message_list.append(message)
    
            # Use multiprocessing Pool to parallelize the calculations
            with Pool() as pool:
                results = pool.map(worker.calculate_distance, args_list)
    
            # Update distance matrix with the results
            for i, j, distance, message in results:
                distance_matrix[i, j] = distance
                distance_matrix[j, i] = distance  # Reflect along the diagonal
                log_message(message)
    
            # Print messages from the shared list
            for message in message_list:
                print(message)
    
        return distance_matrix

# %%
# segments to distance matrix
dist_mat = segments_to_distance_matrix(segments)
print(f"there are {len(dist_mat)} elements in dist mat")
# Out:
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "C:\Users\oyutn\AppData\Local\Programs\Python\Python312\Lib\multiprocessing\pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\oyutn\AppData\Local\Programs\Python\Python312\Lib\multiprocessing\pool.py", line 48, in mapstar
#     return list(map(*args))
#            ^^^^^^^^^^^^^^^^
#   File "C:\.School\Thesisv2\worker.py", line 6, in calculate_distance
#     distance = dtw(segment_i, segment_j)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\.School\CSC142\csci42_group4\.venv\Lib\site-packages\tslearn\metrics\dtw_variants.py", line 775, in dtw
#     s1 = to_time_series(s1, remove_nans=True, be=be)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\.School\CSC142\csci42_group4\.venv\Lib\site-packages\tslearn\utils\utils.py", line 163, in to_time_series
#     ts_out = be.cast(ts_out, dtype=float)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\.School\CSC142\csci42_group4\.venv\Lib\site-packages\tslearn\backend\numpy_backend.py", line 90, in cast
#     return x.astype(dtype)
#            ^^^^^^^^^^^^^^^
# ValueError: could not convert string to float: 'rest'
# """
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 2
#       1 # segments to distance matrix
# ----> 2 dist_mat = segments_to_distance_matrix(segments)
#       3 print(f"there are {len(dist_mat)} elements in dist mat")
#
# Cell In[21], line 26, in segments_to_distance_matrix(segments, cores)
#      24 # Use multiprocessing Pool to parallelize the calculations
#      25 with Pool() as pool:
# ---> 26     results = pool.map(worker.calculate_distance, args_list)
#      28 # Update distance matrix with the results
#      29 for i, j, distance, message in results:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\multiprocessing\pool.py:367, in Pool.map(self, func, iterable, chunksize)
#     362 def map(self, func, iterable, chunksize=None):
#     363     '''
#     364     Apply `func` to each element in `iterable`, collecting the results
#     365     in a list that is returned.
#     366     '''
# --> 367     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\multiprocessing\pool.py:774, in ApplyResult.get(self, timeout)
#     772     return self._value
#     773 else:
# --> 774     raise self._value
#
# ValueError: could not convert string to float: 'rest'

# %% [markdown]
# ## Building the KNN Graph

# %%
# building KNN Graph
k = 3
distance_matrix = dist_mat
knn_graph = kneighbors_graph(distance_matrix, n_neighbors=k, mode='connectivity')

G = nx.from_scipy_sparse_array(knn_graph)

# Detect if the graph is disjoint
if not nx.is_connected(G):
    print("The KNN graph is disjoint. Ensuring connectivity...")

    # Calculate the connected components
    components = list(nx.connected_components(G))

    # Connect the components
    for i in range(len(components) - 1):
        min_dist = np.inf
        closest_pair = None
        for node1 in components[i]:
            for node2 in components[i + 1]:
                dist = distance_matrix[node1, node2]
                if dist < min_dist:
                    min_dist = dist
                    closest_pair = (node1, node2)

        # Add an edge between the closest pair of nodes from different components
        G.add_edge(closest_pair[0], closest_pair[1])

# Plot the final connected graph
pos = nx.spring_layout(G, seed=42, iterations=50)
pos_dict = {i: pos[i] for i in range(len(pos))}
nx.draw(G, node_size=50, pos=pos_dict)
plt.title('Bach Prelude in C')
plt.show()

# %%
# distance matrix to knn graph function
def distance_matrix_to_knn_graph(k: int, distance_matrix: np.array, graph_title: str,
                                 seed: int, iterations: int):
  knn_graph = kneighbors_graph(distance_matrix, n_neighbors=k, mode='connectivity')

  G = nx.from_scipy_sparse_array(knn_graph)

  # Detect if the graph is disjoint
  if not nx.is_connected(G):
      print("The KNN graph is disjoint. Ensuring connectivity...")

      # Calculate the connected components
      components = list(nx.connected_components(G))

      # Connect the components
      for i in range(len(components) - 1):
          min_dist = np.inf
          closest_pair = None
          for node1 in components[i]:
              for node2 in components[i + 1]:
                  dist = distance_matrix[node1, node2]
                  if dist < min_dist:
                      min_dist = dist
                      closest_pair = (node1, node2)

          # Add an edge between the closest pair of nodes from different components
          G.add_edge(closest_pair[0], closest_pair[1])

  # Plot the final connected graph
  pos = nx.spring_layout(G, seed=seed, iterations=iterations)
  nx.draw(G, node_size=50, pos=pos)
  plt.title(graph_title + f" (K={k})")
  plt.show()

# %%
# show graph
distance_matrix_to_knn_graph(3, dist_mat, "Bach Prelude in C", 42, 50)

# %% [markdown]
# ### Currently Trying to Put The Segment Data Into The Node so we can analyze grouped segments

# %%
# segments to graph function
def segments_to_graph(k: int, segments: list[pd.DataFrame], labeled_segments, cores=None):
  # Convert segments to a distance matrix
  distance_matrix = segments_to_distance_matrix(segments, cores=cores)

  # Compute the k-NN graph
  knn_graph = kneighbors_graph(distance_matrix, n_neighbors=k, mode='connectivity')

  # Convert the k-NN graph to a NetworkX graph
  G = nx.from_scipy_sparse_array(knn_graph)

  # Add segment data as attributes to each node
  for i in range(len(segments)):
    G.nodes[i]['segment'] = labeled_segments[i] # print shit

  # Detect if the graph is disjoint
  if not nx.is_connected(G):
      print("The KNN graph is disjoint. Ensuring connectivity...")

      # Calculate the connected components
      components = list(nx.connected_components(G))

      # Connect the components
      for i in range(len(components) - 1):
          min_dist = np.inf
          closest_pair = None
          for node1 in components[i]:
              for node2 in components[i + 1]:
                  dist = distance_matrix[node1, node2]
                  if dist < min_dist:
                      min_dist = dist
                      closest_pair = (node1, node2)

          # Add an edge between the closest pair of nodes from different components
          G.add_edge(closest_pair[0], closest_pair[1])

  return G, distance_matrix

# %%
# segments to graph
graph, distance_matrix = segments_to_graph(5, segments, labeled_segments)

# %% [markdown]
# ## Trying to find ways to validate "Graph Identity"
#
# besides average dtw distance Im trying to see if I can make something of a graph "silhouette score".
#
# Basically get the communities in the graph then calculate the following:
#
# * homogeneity: intra-cluster distance
#
# * heterogeneity: inter-cluster distance
#
# * "Graph Silhoette Score:" $\frac{Heterogeneity - Homogeneity} {max(Hetero, Homo)}$
#
# Also might take a look at clustering coefficients

# %%
# graph metrics function
def graph_metrics(graph: nx.classes.graph.Graph, distance_matrix: np.array,
                  seed: int):
  avg_dtw_distance = distance_matrix.mean()
  avg_clustering_coef = nx.average_clustering(graph)

  communities = nx.community.louvain_communities(graph, seed)

  silhouette_scores = []
  for cluster in communities:
    for i in cluster:
      cluster_distances = distance_matrix[i, list(cluster - {i})]
      homogeneity = np.mean(cluster_distances)
      other_cluster_distances = [np.mean(distance_matrix[i, list(other_cluster)]) for other_cluster in communities if other_cluster != cluster]
      heterogeneity = min(other_cluster_distances) if other_cluster_distances else homogeneity
      silhouette_score = (heterogeneity - homogeneity) / max(heterogeneity, homogeneity)
      silhouette_scores.append(silhouette_score)

  # Average silhouette score for all nodes
  average_silhouette_score = np.mean(silhouette_scores)

  conductance_scores = []
  for cluster in communities:
    cluster_conductance = conductance(graph, cluster)
    conductance_scores.append(cluster_conductance)

  average_conductance = np.mean(conductance_scores)

  print("Average DTW Distance:", avg_dtw_distance)
  print("Average Clustering Coefficient:", avg_clustering_coef)
  print("Average Silhouette Score", average_silhouette_score)
  print("Average Conductance:", average_conductance)

# %%
# show graph metrics and segment data
graph_metrics(graph, distance_matrix, 42)
print(f"Graph Length: {len(graph)}")

for node in graph.nodes(data=True):
  node_id = node[0]
  segment_data = node[1]['segment']
  print(f"Node {node_id} segment data:")
  print(segment_data)

# %%
# plot graph function
def plot_graph(graph: nx.classes.graph.Graph,
               seed: int,
               iterations: int,
               title: str,
               node_size: int):
  pos = nx.spring_layout(graph, seed=seed, iterations=iterations)
  for node in graph.nodes(data=True):
    segment_data = node[1]['segment']
    label, matrix = segment_data
    title, color = label
    print(color)
    # G.nodes[node]['color'] = color
  nx.draw(G, node_size=node_size, node_color='red' ,pos=pos)
  plt.title(title)
  plt.show()

# %%
# show graph
plot_graph(graph, 3, 50, "Bach Prelud in C (K=5)", 50)

# %%
for i in range(len(graph.nodes())):
  graph.nodes[i]['segment'] = graph.nodes[i]['segment'].to_json(default_handler=str)

nt = Network('1000px', '1000px', notebook=True, cdn_resources = 'remote')
nt.from_nx(graph)
nt.show('sample_graph.html')   ### Still need to figure out the labels
display(HTML('sample_graph.html'))
